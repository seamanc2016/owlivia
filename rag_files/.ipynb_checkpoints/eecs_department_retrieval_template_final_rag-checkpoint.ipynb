# %%
import pandas as pd
import math
import numpy as np
from collections import Counter
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
import gradio as gr
import faiss
from rank_bm25 import BM25Okapi
import re
import warnings
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from pathlib import Path
import zipfile
import json

try:
    from pypdf import PdfReader
except ImportError:
    PdfReader = None

warnings.filterwarnings('ignore')

# Create common project folders used throughout the notebook.
DATA_DIR = Path("data")
OUTPUT_DIR = Path("outputs")
SEARCH_REVIEW_DIR = Path("search_review")
DATA_DIR.mkdir(exist_ok=True)
OUTPUT_DIR.mkdir(exist_ok=True)
SEARCH_REVIEW_DIR.mkdir(exist_ok=True)

# NLTK stop words are helpful for BM25 and word-overlap scoring.
# This keeps the notebook runnable even on a fresh machine.
try:
    stop_words = set(stopwords.words("english"))
except LookupError:
    nltk.download("stopwords")
    stop_words = set(stopwords.words("english"))

stemmer = PorterStemmer()

# %%
DEPARTMENT_NAME = "Computer Science and Electrical Engineering"
SOURCE_ROOT = Path("DepCourseInfo")
ZIP_PATH_CANDIDATES = [Path("DepCourseInfo.zip"), Path("/mnt/data/DepCourseInfo.zip")]
PDF_FOLDER_NAME = "downloaded_forms_and_worksheets"

# Prefixes that are common in CS, CE, cybersecurity, networking, data science, AI, and EE/engineering course material.
# Keep this broad because the EECS pages may contain interdisciplinary course documents too.
EECS_PREFIXES = {
    "CAP", "CDA", "CEN", "CGS", "CIS", "CNT", "COP", "COT", "CSC",
    "EEE", "EEL", "EGN", "EGS", "EIN", "EML", "IDC", "ISC", "STA", "MAP", "MAD"
}

# Avoid carrying over biomedical/healthcare-oriented documents from the old topic.
# A CS/EE course with a bioinformatics title is still kept if its prefix is part of EECS_PREFIXES.
BIOMEDICAL_EXCLUDE_TERMS = {
    "bme", "biomedical", "bioengineering", "bio-systems", "stem cell", "tissue engineering"
}

def normalize_whitespace(text):
    return " ".join(str(text).replace("\x00", " ").split())


def clean_title_from_filename(filename):
    stem = Path(filename).stem
    stem = re.sub(r"[_-]+", " ", stem)
    stem = re.sub(r"\s+", " ", stem).strip()
    return stem.title()


def ensure_source_files_available(source_root=SOURCE_ROOT):
    """Use an existing DepCourseInfo folder, or unzip DepCourseInfo.zip if needed."""
    if source_root.exists():
        print(f"Using existing source folder: {source_root.resolve()}")
        return source_root

    zip_path = next((p for p in ZIP_PATH_CANDIDATES if p.exists()), None)
    if zip_path is None:
        raise FileNotFoundError(
            "Could not find DepCourseInfo folder or DepCourseInfo.zip. "
            "Place the ZIP next to this notebook or update ZIP_PATH_CANDIDATES."
        )

    print(f"Extracting {zip_path} ...")
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(Path("."))

    if not source_root.exists():
        raise FileNotFoundError(f"Expected extracted folder was not found: {source_root}")

    print(f"Extracted source folder: {source_root.resolve()}")
    return source_root


def guess_document_type(filename, linked_url="", title=""):
    text = f"{filename} {linked_url} {title}".lower()

    if any(word in text for word in ["worksheet", "application", "audit", "form"]):
        return "program_form_or_worksheet"
    if "certificate" in text or "minor" in text or "concentration" in text:
        return "certificate_minor_or_concentration"
    if re.search(r"\b[a-z]{3}\s*[-_ ]?\d{4}", text):
        return "course_syllabus"
    if "syllab" in text:
        return "course_syllabus"
    return "department_document"


def is_relevant_eecs_document(prefix="", title="", filename="", doc_type=""):
    """Return True for CS/EE department material and False for biomedical/healthcare carryover."""
    prefix = str(prefix).upper().strip()
    combined = f"{title} {filename}".lower()

    if prefix:
        return prefix in EECS_PREFIXES

    if any(term in combined for term in BIOMEDICAL_EXCLUDE_TERMS):
        return False

    # Keep program forms, worksheets, certificates, and general department files that do not have a course prefix.
    return True


def extract_pdf_text(pdf_path, max_pages=None):
    """Extract text from a PDF. Returns an empty string for scanned/unreadable PDFs."""
    if PdfReader is None:
        raise ImportError("pypdf is required. Install it with: pip install pypdf")

    try:
        reader = PdfReader(str(pdf_path))
        pages = reader.pages if max_pages is None else reader.pages[:max_pages]
        page_text = []
        for page in pages:
            try:
                page_text.append(page.extract_text() or "")
            except Exception:
                page_text.append("")
        return normalize_whitespace("\n".join(page_text))
    except Exception as exc:
        print(f"Warning: could not read PDF {pdf_path.name}: {exc}")
        return ""


def build_department_corpus(source_root=SOURCE_ROOT, data_dir=DATA_DIR):
    """
    Build a retrieval corpus for CS/EE department information.

    Output columns intentionally include the original template's required columns:
    - doc_id
    - text

    Additional metadata columns are kept for better summaries and inspection.
    """
    source_root = ensure_source_files_available(source_root)
    data_dir.mkdir(exist_ok=True)

    course_csv = source_root / "course_listings.csv"
    pdf_dir = source_root / PDF_FOLDER_NAME

    rows = []
    linked_file_lookup = {}

    if course_csv.exists():
        courses_df = pd.read_csv(course_csv)
        courses_df = courses_df.fillna("")

        # Map downloaded PDF filenames back to their source URLs when possible.
        for _, row in courses_df.iterrows():
            linked = str(row.get("linked_file_or_page", "")).strip()
            if linked.lower().endswith(".pdf"):
                linked_file_lookup[Path(linked).name.lower()] = linked

        # Add one clean course-listing document per unique course/title/source combination.
        course_docs = courses_df.copy()
        course_docs["course_key"] = (
            course_docs["course_code"].astype(str) + " | " +
            course_docs["title_or_context"].astype(str) + " | " +
            course_docs["level"].astype(str)
        )
        course_docs = course_docs.drop_duplicates("course_key")

        for i, row in course_docs.iterrows():
            prefix = str(row.get("prefix", "")).upper().strip()
            course_code = str(row.get("course_code", "")).strip()
            title = str(row.get("title_or_context", "")).strip()

            if not is_relevant_eecs_document(prefix=prefix, title=title, filename="", doc_type="course_listing"):
                continue
            level = str(row.get("level", "")).strip()
            source_page = str(row.get("source_page", "")).strip()
            linked = str(row.get("linked_file_or_page", "")).strip()
            raw_text = str(row.get("raw_text", "")).strip()

            # Keep broad EECS results, but avoid empty/noisy rows.
            if not course_code and not title and not raw_text:
                continue

            doc_id = f"course_{len(rows)+1:04d}_{course_code.replace(' ', '_') or 'unknown'}"
            labeled_text = normalize_whitespace(f"""
Document_Type = course_listing,
Title = {title},
Course_Code = {course_code},
Prefix = {prefix},
Number = {row.get('number', '')},
Level = {level},
Source_Page = {source_page},
Linked_File_or_Page = {linked},
File_Name = ,
Content = {raw_text if raw_text else f'{course_code} {title}'}
""")
            rows.append({
                "doc_id": doc_id,
                "document_type": "course_listing",
                "title": title,
                "course_code": course_code,
                "prefix": prefix,
                "number": str(row.get("number", "")).strip(),
                "level": level,
                "source_page": source_page,
                "linked_file_or_page": linked,
                "file_name": "",
                "text": labeled_text,
            })
    else:
        print(f"Warning: course listings file was not found: {course_csv}")

    if pdf_dir.exists():
        pdf_paths = sorted(pdf_dir.rglob("*.pdf"))
        print(f"Reading {len(pdf_paths)} PDFs from {pdf_dir} ...")

        for pdf_path in pdf_paths:
            file_name = pdf_path.name
            linked = linked_file_lookup.get(file_name.lower(), "")
            title = clean_title_from_filename(file_name)
            doc_type = guess_document_type(file_name, linked, title)
            pdf_text = extract_pdf_text(pdf_path)

            # Try to identify course code metadata from the filename or extracted text.
            course_match = re.search(r"\b([A-Z]{3})\s*[-_ ]?(\d{4})\b", f"{file_name} {pdf_text[:500]}", flags=re.IGNORECASE)
            prefix = course_match.group(1).upper() if course_match else ""
            number = course_match.group(2) if course_match else ""
            course_code = f"{prefix} {number}".strip()
            level = "graduate" if number.startswith(("5", "6")) else "undergraduate" if number.startswith(("1", "2", "3", "4")) else ""

            if not is_relevant_eecs_document(prefix=prefix, title=title, filename=file_name, doc_type=doc_type):
                continue

            content = pdf_text if pdf_text else "No extractable PDF text was found. Use the filename and metadata for retrieval."
            doc_id = f"pdf_{len(rows)+1:04d}_{Path(file_name).stem[:60]}"
            labeled_text = normalize_whitespace(f"""
Document_Type = {doc_type},
Title = {title},
Course_Code = {course_code},
Prefix = {prefix},
Number = {number},
Level = {level},
Source_Page = ,
Linked_File_or_Page = {linked},
File_Name = {file_name},
Content = {content}
""")
            rows.append({
                "doc_id": doc_id,
                "document_type": doc_type,
                "title": title,
                "course_code": course_code,
                "prefix": prefix,
                "number": number,
                "level": level,
                "source_page": "",
                "linked_file_or_page": linked,
                "file_name": file_name,
                "text": labeled_text,
            })
    else:
        print(f"Warning: PDF folder was not found: {pdf_dir}")

    corpus_df = pd.DataFrame(rows)
    if corpus_df.empty:
        raise ValueError("No department documents were found. Check SOURCE_ROOT and PDF_FOLDER_NAME.")

    corpus_path = data_dir / "corpus.csv"
    corpus_df.to_csv(corpus_path, index=False)
    print(f"Department corpus saved to: {corpus_path}")
    print(f"Documents created: {len(corpus_df)}")
    print(corpus_df["document_type"].value_counts())
    return corpus_df


def load_corpus(corpus_name="corpus", rebuild=False):
    corpus_fullcsvname = DATA_DIR / f"{corpus_name}.csv"

    if rebuild or not corpus_fullcsvname.exists():
        print("Building a new CS/EE department corpus...")
        corpus_df = build_department_corpus()
    else:
        corpus_df = pd.read_csv(corpus_fullcsvname).fillna("")

    print(f"Corpus: {len(corpus_df)} documents")
    print(f"Columns: {list(corpus_df.columns)}")
    print()
    print("First 3 documents:")
    for _, row in corpus_df.head(3).iterrows():
        preview = str(row["text"])[:220] + "..." if len(str(row["text"])) > 220 else str(row["text"])
        print(f"  {row['doc_id']}: {preview}")
    print()

    return corpus_df

# %%
corpus_name = "corpus"

# Use True the first time you switch from the old healthcare corpus to the CS/EE corpus.
# After data/corpus.csv has been created, you can set this to False for faster reruns.
REBUILD_CORPUS = True

corpus_df = load_corpus(corpus_name, rebuild=REBUILD_CORPUS)
# Out:
# Building a new CS/EE department corpus...
# Using existing source folder: C:\Users\xande\Projects_Py\EE\eecs_search_review_update\DepCourseInfo
# Reading 266 PDFs from DepCourseInfo\downloaded_forms_and_worksheets ...
# Department corpus saved to: data\corpus.csv
# Documents created: 530
# document_type
# course_listing               275
# course_syllabus              173
# program_form_or_worksheet     72
# department_document           10
# Name: count, dtype: int64
# Corpus: 530 documents
# Columns: ['doc_id', 'document_type', 'title', 'course_code', 'prefix', 'number', 'level', 'source_page', 'linked_file_or_page', 'file_name', 'text']
#
# First 3 documents:
#   course_0001_CAP_5615: Document_Type = course_listing, Title = Intro to Neural Networks, Course_Code = CAP 5615, Prefix = CAP, Number = 5615, Level = graduate, Source_Page = https://www.fau.edu/engineering/eecs/research/nrt/faculty/collaborato...
#   course_0002_CAP_5615: Document_Type = course_listing, Title = Introduction to Neural Networks, Course_Code = CAP 5615, Prefix = CAP, Number = 5615, Level = graduate, Source_Page = https://www.fau.edu/engineering/eecs/graduate/syllabi-ce-cs/, ...
#   course_0003_CAP_5625: Document_Type = course_listing, Title = , Course_Code = CAP 5625, Prefix = CAP, Number = 5625, Level = graduate, Source_Page = https://www.fau.edu/engineering/eecs/graduate/professional-programs/professional-ms-ai/, Link...

# %%
DEFAULT_DEPARTMENT_QUERIES = [('q01', 'Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements.'), ('q02', 'Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor.'), ('q03', 'Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements.'), ('q04', 'Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements.'), ('q05', 'Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements.'), ('q06', 'Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements.'), ('q07', 'Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security.'), ('q08', 'Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses.'), ('q09', 'Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi.'), ('q10', 'Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi.'), ('q11', 'Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.'), ('q12', 'Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics.'), ('q13', 'Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi.'), ('q14', 'Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms.')]


def create_default_queries(query_path):
    query_path = Path(query_path)
    query_path.parent.mkdir(parents=True, exist_ok=True)
    query_df = pd.DataFrame(DEFAULT_DEPARTMENT_QUERIES, columns=["query_id", "query_text"])
    query_df.to_csv(query_path, index=False)
    print(f"Default CS/EE department queries saved to: {query_path}")
    return query_df


def load_premade_queries(query_path=None, rebuild=False):
    """Load the starter EECS query list from search_review/eecs_queries.csv."""
    query_path = Path(query_path) if query_path is not None else SEARCH_REVIEW_DIR / "eecs_queries.csv"

    if rebuild or not query_path.exists():
        queries_df = create_default_queries(query_path)
    else:
        queries_df = pd.read_csv(query_path)

    print(f"Queries loaded from: {query_path}")
    print(f"Queries: {len(queries_df)} queries")
    for _, row in queries_df.iterrows():
        print(f"  {row['query_id']}: {row['query_text']}")
    return queries_df


QUERY_PATH = SEARCH_REVIEW_DIR / "eecs_queries.csv"

# Keep False when using the reviewed starter CSVs in search_review/.
# Set True only when you intentionally want to regenerate the starter query list.
REBUILD_QUERIES = False

queries_df = load_premade_queries(QUERY_PATH, rebuild=REBUILD_QUERIES)
# Out:
# Queries loaded from: search_review\eecs_queries.csv
# Queries: 14 queries
#   q01: Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements.
#   q02: Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor.
#   q03: Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements.
#   q04: Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements.
#   q05: Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements.
#   q06: Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements.
#   q07: Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security.
#   q08: Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses.
#   q09: Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi.
#   q10: Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi.
#   q11: Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.
#   q12: Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics.
#   q13: Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi.
#   q14: Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms.

# %%
QUERY_PATH = SEARCH_REVIEW_DIR / "eecs_queries.csv"

# Keep False when using the reviewed starter CSVs in search_review/.
# Set True only when you intentionally want to regenerate the starter query list.
REBUILD_QUERIES = False

queries_df = load_premade_queries(QUERY_PATH, rebuild=REBUILD_QUERIES)
# Out:
# Queries loaded from: search_review\eecs_queries.csv
# Queries: 14 queries
#   q01: Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements.
#   q02: Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor.
#   q03: Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements.
#   q04: Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements.
#   q05: Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements.
#   q06: Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements.
#   q07: Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security.
#   q08: Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses.
#   q09: Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi.
#   q10: Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi.
#   q11: Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.
#   q12: Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics.
#   q13: Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi.
#   q14: Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms.

# %%
MODEL_NAME = "all-MiniLM-L6-v2"

print(f"Loading model: {MODEL_NAME}")
model = SentenceTransformer(MODEL_NAME)
print(f"Model loaded. Embedding dimension: {model.get_sentence_embedding_dimension()}")
# Out:
# Loading model: all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded. Embedding dimension: 384

# %%
def faiss_embedding_process(corpus_df):
    doc_ids = corpus_df['doc_id'].tolist()
    doc_texts = corpus_df['text'].astype(str).tolist()
    
    print(f"Encoding {len(doc_texts)} documents...")
    doc_embeddings = model.encode(
        doc_texts,
        batch_size=64,
        show_progress_bar=True,
        convert_to_numpy=True,
        normalize_embeddings=True,  # L2 normalize for cosine similarity
    )
    
    print(f"Embedding shape: {doc_embeddings.shape}")
    print(f"Sample vector (first 10 dims): {doc_embeddings[0][:10]}")

    return doc_ids, doc_texts, doc_embeddings

# %%
doc_ids, doc_texts, doc_embeddings = faiss_embedding_process(corpus_df)
# Out:
# Encoding 530 documents...
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Embedding shape: (530, 384)
# Sample vector (first 10 dims): [-0.08601955 -0.05820242 -0.01651547  0.02603499  0.05125582  0.02605188
#  -0.01550748  0.05264784 -0.09018142 -0.02698193]

# %%
def faiss_index_process(doc_embeddings):
    dim = doc_embeddings.shape[1]  # 384
    index = faiss.IndexFlatIP(dim)
    index.add(doc_embeddings.astype(np.float32))
    
    print(f"FAISS index built: {index.ntotal} vectors, dimension={dim}")

    return index

# %%
index = faiss_index_process(doc_embeddings)
# Out:
# FAISS index built: 530 vectors, dimension=384

# %%
def dense_search(query_text, model, index, doc_ids, top_k=10):
    """
    Encode a query and return the top-k most similar documents.

    Returns: list of (doc_id, score, rank) tuples
    """
    # Encode the query with the SAME model and normalization
    query_vec = model.encode(
        [query_text],
        normalize_embeddings=True,
        convert_to_numpy=True,
    ).astype(np.float32)

    # Search the FAISS index
    scores, indices = index.search(query_vec, top_k)

    results = []
    for rank, (idx, score) in enumerate(zip(indices[0], scores[0]), start=1):
        results.append((doc_ids[idx], float(score), rank))

    return results

# %%
test_query = queries_df.iloc[0]
print(f"Query: {test_query['query_id']} — \"{test_query['query_text']}\"\n")

results = dense_search(test_query['query_text'], model, index, doc_ids, top_k=5)

for doc_id, score, rank in results:
    doc_text = corpus_df[corpus_df['doc_id'] == doc_id]['text'].values[0]
    preview = str(doc_text)[:200] + '...' if len(str(doc_text)) > 200 else str(doc_text)
    print(f"  Rank {rank} | Score: {score:.4f} | {doc_id}")
    print(f"    {preview}\n")
# Out:
# Query: q01 — "Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements."
#
#   Rank 1 | Score: 0.6445 | pdf_0511_professional-ai-certificate-program-application
#     Document_Type = program_form_or_worksheet, Title = Professional Ai Certificate Program Application, Course_Code = , Prefix = , Number = , Level = , Source_Page = , Linked_File_or_Page = , File_Name = ...
#
#   Rank 2 | Score: 0.6298 | pdf_0311_cap6635artificial-intelligence
#     Document_Type = course_syllabus, Title = Cap6635Artificial Intelligence, Course_Code = CAP 6635, Prefix = CAP, Number = 6635, Level = graduate, Source_Page = , Linked_File_or_Page = https://www.fau.ed...
#
#   Rank 3 | Score: 0.6141 | pdf_0298_cap4630artificial-intelligence
#     Document_Type = course_syllabus, Title = Cap4630Artificial Intelligence, Course_Code = CAP 4630, Prefix = CAP, Number = 4630, Level = undergraduate, Source_Page = , Linked_File_or_Page = https://www.f...
#
#   Rank 4 | Score: 0.6134 | pdf_0281_artificial-intelligence-certificate-program-application-jan6
#     Document_Type = program_form_or_worksheet, Title = Artificial Intelligence Certificate Program Application Jan6, Course_Code = , Prefix = , Number = , Level = , Source_Page = , Linked_File_or_Page = ,...
#
#   Rank 5 | Score: 0.6109 | pdf_0342_certificate-artificial-intelligence--program-worksheet
#     Document_Type = program_form_or_worksheet, Title = Certificate Artificial Intelligence Program Worksheet, Course_Code = , Prefix = , Number = , Level = , Source_Page = , Linked_File_or_Page = , File_N...

# %%
TOP_K = 100
all_results = []

for _, qrow in queries_df.iterrows():
    qid = qrow['query_id']
    qtext = qrow['query_text']
    results = dense_search(qtext, model, index, doc_ids, top_k=TOP_K)
    for doc_id, score, rank in results:
        all_results.append({
            'query_id': qid,
            'doc_id': doc_id,
            'rank': rank,
            'score': round(score, 4),
        })

run_dense_df = pd.DataFrame(all_results)
run_dense_df.to_csv('outputs/run_dense.csv', index=False)

print(f"Dense retrieval results saved: {len(run_dense_df)} rows")
print(f"Queries processed: {run_dense_df['query_id'].nunique()}")
run_dense_df.head(20)
# Out:
# Dense retrieval results saved: 1400 rows
# Queries processed: 14
#    query_id                                             doc_id  rank   score
# 0       q01  pdf_0511_professional-ai-certificate-program-a...     1  0.6445
# 1       q01            pdf_0311_cap6635artificial-intelligence     2  0.6298
# 2       q01            pdf_0298_cap4630artificial-intelligence     3  0.6141
# 3       q01  pdf_0281_artificial-intelligence-certificate-p...     4  0.6134
# 4       q01  pdf_0342_certificate-artificial-intelligence--...     5  0.6109
# 5       q01  pdf_0343_certificate-artificial-intelligence-p...     6  0.6066
# 6       q01  pdf_0282_artificial-intelligence-minor-program...     7  0.5824
# 7       q01                               course_0005_CAP_5625     8  0.5670
# 8       q01              pdf_0517_professional-ms-ai-worksheet     9  0.5648
# 9       q01  pdf_0280_artificial-intelligence-cert-program-...    10  0.5639
# 10      q01  pdf_0509_newcertificate-artificial-intelligenc...    11  0.5617
# 11      q01  pdf_0278_artificial-inteligence-certificate-wo...    12  0.5562
# 12      q01     pdf_0512_professional-certificate-ai-worksheet    13  0.5535
# 13      q01                               course_0025_CAP_6635    14  0.5510
# 14      q01  pdf_0279_artificial-inteligence-minor-workshee...    15  0.5372
# 15      q01                               course_0024_CAP_6635    16  0.5338
# 16      q01                               course_0004_CAP_5625    17  0.5314
# 17      q01                               course_0146_CAP_4630    18  0.5308
# 18      q01  pdf_0530_syllabus-trustworthy-artificial-intel...    19  0.5256
# 19      q01                               course_0030_CAP_6673    20  0.5211

# %%
def tokenize_for_bm25(text):
    words = re.findall(r"[A-Za-z0-9]+", str(text).lower())
    return [
        stemmer.stem(word)
        for word in words
        if word not in stop_words and len(word) > 1
    ]


def bm25_tokenize_corpus(corpus_df):
    tokenized_corpus = [tokenize_for_bm25(doc) for doc in corpus_df["text"]]
    return tokenized_corpus


def bm25_corpus(tokenized_corpus):
    bm25 = BM25Okapi(tokenized_corpus, k1=1.5, b=0.8)
    return bm25

# %%
tokenized_corpus = bm25_tokenize_corpus(corpus_df)
bm25 = bm25_corpus(tokenized_corpus)

# %%
bm25_results = []
for _, qrow in queries_df.iterrows():
    qid = qrow['query_id']
    qtext = tokenize_for_bm25(qrow['query_text'])
    scores = bm25.get_scores(qtext)
    top_indices = np.argsort(scores)[::-1][:TOP_K]
    for rank, idx in enumerate(top_indices, start=1):
        bm25_results.append({
            'query_id': qid,
            'doc_id': doc_ids[idx],
            'rank': rank,
            'score': round(float(scores[idx]), 4),
        })

run_bm25_df = pd.DataFrame(bm25_results)
run_bm25_df.to_csv('outputs/run_bm25.csv', index=False)
print(f"BM25 results: {len(run_bm25_df)} rows")
run_bm25_df.head(10)
# Out:
# BM25 results: 1400 rows
#   query_id                                             doc_id  rank    score
# 0      q01  pdf_0511_professional-ai-certificate-program-a...     1  46.5127
# 1      q01     pdf_0512_professional-certificate-ai-worksheet     2  44.9963
# 2      q01  pdf_0482_minor--artificial-intelligence-applic...     3  35.8678
# 3      q01  pdf_0282_artificial-intelligence-minor-program...     4  35.2644
# 4      q01  pdf_0279_artificial-inteligence-minor-workshee...     5  35.1598
# 5      q01  pdf_0341_certificate-artificial--intelligence-...     6  35.0532
# 6      q01  pdf_0281_artificial-intelligence-certificate-p...     7  34.8929
# 7      q01  pdf_0513_professional-certificate-big-data-ana...     8  33.9873
# 8      q01  pdf_0514_professional-certificate-big-data-ana...     9  33.1466
# 9      q01  pdf_0343_certificate-artificial-intelligence-p...    10  32.5266

# %%
comparison_rows = []

for qid in queries_df['query_id']:
    bm25_q = run_bm25_df[run_bm25_df['query_id'] == qid].head(5)
    dense_q = run_dense_df[run_dense_df['query_id'] == qid].head(5)

    for rank in range(1, 6):
        bm25_row = bm25_q[bm25_q['rank'] == rank]
        dense_row = dense_q[dense_q['rank'] == rank]

        comparison_rows.append({
            'query_id': qid,
            'rank': rank,
            'bm25_doc_id': bm25_row['doc_id'].values[0] if len(bm25_row) > 0 else '',
            'bm25_score': round(bm25_row['score'].values[0], 4) if len(bm25_row) > 0 else '',
            'dense_doc_id': dense_row['doc_id'].values[0] if len(dense_row) > 0 else '',
            'dense_score': round(dense_row['score'].values[0], 4) if len(dense_row) > 0 else '',
        })

comparison_df = pd.DataFrame(comparison_rows)
comparison_df.to_csv('outputs/comparison.csv', index=False)

print("Side-by-side comparison saved to comparison.csv")
comparison_df.head(10)
# Out:
# Side-by-side comparison saved to comparison.csv
#   query_id  rank                                        bm25_doc_id  \
# 0      q01     1  pdf_0511_professional-ai-certificate-program-a...
# 1      q01     2     pdf_0512_professional-certificate-ai-worksheet
# 2      q01     3  pdf_0482_minor--artificial-intelligence-applic...
# 3      q01     4  pdf_0282_artificial-intelligence-minor-program...
# 4      q01     5  pdf_0279_artificial-inteligence-minor-workshee...
# 5      q02     1  pdf_0482_minor--artificial-intelligence-applic...
# 6      q02     2  pdf_0282_artificial-intelligence-minor-program...
# 7      q02     3  pdf_0279_artificial-inteligence-minor-workshee...
# 8      q02     4  pdf_0342_certificate-artificial-intelligence--...
# 9      q02     5  pdf_0343_certificate-artificial-intelligence-p...
#
#    bm25_score                                       dense_doc_id  dense_score
# 0     46.5127  pdf_0511_professional-ai-certificate-program-a...       0.6445
# 1     44.9963            pdf_0311_cap6635artificial-intelligence       0.6298
# 2     35.8678            pdf_0298_cap4630artificial-intelligence       0.6141
# 3     35.2644  pdf_0281_artificial-intelligence-certificate-p...       0.6134
# 4     35.1598  pdf_0342_certificate-artificial-intelligence--...       0.6109
# 5     46.1493  pdf_0282_artificial-intelligence-minor-program...       0.7190
# 6     46.0614  pdf_0342_certificate-artificial-intelligence--...       0.7109
# 7     40.9564  pdf_0279_artificial-inteligence-minor-workshee...       0.6895
# 8     38.5206  pdf_0343_certificate-artificial-intelligence-p...       0.6887
# 9     37.7823  pdf_0482_minor--artificial-intelligence-applic...       0.6566

# %%
doc_lookup = dict(zip(corpus_df['doc_id'], corpus_df['text'].astype(str)))

for _, qrow in queries_df.iterrows():
    qid = qrow['query_id']
    qtext = qrow['query_text']
    print(f"\n{'='*80}")
    print(f"Query {qid}: \"{qtext}\"")
    print(f"{'='*80}")

    bm25_q = run_bm25_df[run_bm25_df['query_id'] == qid].head(5)
    dense_q = run_dense_df[run_dense_df['query_id'] == qid].head(5)

    print(f"\n{'BM25 Results':<40} | {'Dense Retrieval Results':<40}")
    print(f"{'-'*40} | {'-'*40}")

    for rank in range(5):
        # BM25 side
        if rank < len(bm25_q):
            b = bm25_q.iloc[rank]
            b_text = doc_lookup.get(b['doc_id'], '')[:60]
            bm25_str = f"#{b['rank']} {b['doc_id']} ({b['score']:.2f}) {b_text}"
        else:
            bm25_str = ""

        # Dense side
        if rank < len(dense_q):
            d = dense_q.iloc[rank]
            d_text = doc_lookup.get(d['doc_id'], '')[:60]
            dense_str = f"#{d['rank']} {d['doc_id']} ({d['score']:.4f}) {d_text}"
        else:
            dense_str = ""

        print(f"{bm25_str:<40} | {dense_str:<40}")

    # Overlap analysis
    bm25_docs = set(bm25_q['doc_id'])
    dense_docs = set(dense_q['doc_id'])
    overlap = bm25_docs & dense_docs
    print(f"\nOverlap: {len(overlap)} / 5 docs appear in both top-5")
    if overlap:
        print(f"  Shared docs: {overlap}")
    print(f"  BM25-only: {bm25_docs - dense_docs}")
    print(f"  Dense-only: {dense_docs - bm25_docs}")
# Out:
# ================================================================================
# Query q01: "Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0511_professional-ai-certificate-program-application (46.51) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0511_professional-ai-certificate-program-application (0.6445) Document_Type = program_form_or_worksheet, Title = Professio
# #2 pdf_0512_professional-certificate-ai-worksheet (45.00) Document_Type = program_form_or_worksheet, Title = Professio | #2 pdf_0311_cap6635artificial-intelligence (0.6298) Document_Type = course_syllabus, Title = Cap6635Artificial I
# #3 pdf_0482_minor--artificial-intelligence-application (35.87) Document_Type = program_form_or_worksheet, Title = Minor Art | #3 pdf_0298_cap4630artificial-intelligence (0.6141) Document_Type = course_syllabus, Title = Cap4630Artificial I
# #4 pdf_0282_artificial-intelligence-minor-program-application-jan6 (35.26) Document_Type = program_form_or_worksheet, Title = Artificia | #4 pdf_0281_artificial-intelligence-certificate-program-application-jan6 (0.6134) Document_Type = program_form_or_worksheet, Title = Artificia
# #5 pdf_0279_artificial-inteligence-minor-worksheet-jan6 (35.16) Document_Type = program_form_or_worksheet, Title = Artificia | #5 pdf_0342_certificate-artificial-intelligence--program-worksheet (0.6109) Document_Type = program_form_or_worksheet, Title = Certifica
#
# Overlap: 1 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0511_professional-ai-certificate-program-application'}
#   BM25-only: {'pdf_0512_professional-certificate-ai-worksheet', 'pdf_0482_minor--artificial-intelligence-application', 'pdf_0279_artificial-inteligence-minor-worksheet-jan6', 'pdf_0282_artificial-intelligence-minor-program-application-jan6'}
#   Dense-only: {'pdf_0342_certificate-artificial-intelligence--program-worksheet', 'pdf_0281_artificial-intelligence-certificate-program-application-jan6', 'pdf_0298_cap4630artificial-intelligence', 'pdf_0311_cap6635artificial-intelligence'}
#
# ================================================================================
# Query q02: "Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0482_minor--artificial-intelligence-application (46.15) Document_Type = program_form_or_worksheet, Title = Minor Art | #1 pdf_0282_artificial-intelligence-minor-program-application-jan6 (0.7190) Document_Type = program_form_or_worksheet, Title = Artificia
# #2 pdf_0282_artificial-intelligence-minor-program-application-jan6 (46.06) Document_Type = program_form_or_worksheet, Title = Artificia | #2 pdf_0342_certificate-artificial-intelligence--program-worksheet (0.7109) Document_Type = program_form_or_worksheet, Title = Certifica
# #3 pdf_0279_artificial-inteligence-minor-worksheet-jan6 (40.96) Document_Type = program_form_or_worksheet, Title = Artificia | #3 pdf_0279_artificial-inteligence-minor-worksheet-jan6 (0.6895) Document_Type = program_form_or_worksheet, Title = Artificia
# #4 pdf_0342_certificate-artificial-intelligence--program-worksheet (38.52) Document_Type = program_form_or_worksheet, Title = Certifica | #4 pdf_0343_certificate-artificial-intelligence-program-worksheet (0.6887) Document_Type = program_form_or_worksheet, Title = Certifica
# #5 pdf_0343_certificate-artificial-intelligence-program-worksheet (37.78) Document_Type = program_form_or_worksheet, Title = Certifica | #5 pdf_0482_minor--artificial-intelligence-application (0.6566) Document_Type = program_form_or_worksheet, Title = Minor Art
#
# Overlap: 5 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0482_minor--artificial-intelligence-application', 'pdf_0343_certificate-artificial-intelligence-program-worksheet', 'pdf_0342_certificate-artificial-intelligence--program-worksheet', 'pdf_0279_artificial-inteligence-minor-worksheet-jan6', 'pdf_0282_artificial-intelligence-minor-program-application-jan6'}
#   BM25-only: set()
#   Dense-only: set()
#
# ================================================================================
# Query q03: "Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0514_professional-certificate-big-data-analytics-worksheet (62.31) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0513_professional-certificate-big-data-analytics-application (0.6519) Document_Type = program_form_or_worksheet, Title = Professio
# #2 pdf_0513_professional-certificate-big-data-analytics-application (60.90) Document_Type = program_form_or_worksheet, Title = Professio | #2 pdf_0514_professional-certificate-big-data-analytics-worksheet (0.6204) Document_Type = program_form_or_worksheet, Title = Professio
# #3 pdf_0344_certificate-big-data-analytics-application (52.71) Document_Type = program_form_or_worksheet, Title = Certifica | #3 pdf_0283_big-data-analytics-cert-program-worksheet (0.5930) Document_Type = program_form_or_worksheet, Title = Big Data
# #4 pdf_0283_big-data-analytics-cert-program-worksheet (49.95) Document_Type = program_form_or_worksheet, Title = Big Data  | #4 pdf_0344_certificate-big-data-analytics-application (0.5392) Document_Type = program_form_or_worksheet, Title = Certifica
# #5 pdf_0305_cap6315social-networks-big-data-analytics (44.12) Document_Type = course_syllabus, Title = Cap6315Social Netwo | #5 pdf_0317_cap6780big-data-analytics (0.5174) Document_Type = course_syllabus, Title = Cap6780Big Data Ana
#
# Overlap: 4 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0283_big-data-analytics-cert-program-worksheet', 'pdf_0513_professional-certificate-big-data-analytics-application', 'pdf_0344_certificate-big-data-analytics-application', 'pdf_0514_professional-certificate-big-data-analytics-worksheet'}
#   BM25-only: {'pdf_0305_cap6315social-networks-big-data-analytics'}
#   Dense-only: {'pdf_0317_cap6780big-data-analytics'}
#
# ================================================================================
# Query q04: "Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0518_professional-ms-cs-worksheet (31.06) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0490_ms-cse-worksheet-new (0.5789) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo
# #2 pdf_0520_professional-ms-itm-csda-concentration-worksheet (30.00) Document_Type = program_form_or_worksheet, Title = Professio | #2 pdf_0496_ms-in-computer-science-program-worksheet-6-2025 (0.5778) Document_Type = program_form_or_worksheet, Title = Ms In Com
# #3 pdf_0517_professional-ms-ai-worksheet (29.28) Document_Type = program_form_or_worksheet, Title = Professio | #3 pdf_0408_data-science-certificate-program-application (0.5639) Document_Type = program_form_or_worksheet, Title = Data Scie
# #4 pdf_0490_ms-cse-worksheet-new (28.82) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo | #4 pdf_0501_ms-in-information-technology-management-computer-science-dat (0.5616) Document_Type = program_form_or_worksheet, Title = Ms In Inf
# #5 pdf_0519_professional-ms-itm-adv-info-tech-concentration-worksheet (28.52) Document_Type = program_form_or_worksheet, Title = Professio | #5 pdf_0520_professional-ms-itm-csda-concentration-worksheet (0.5439) Document_Type = program_form_or_worksheet, Title = Professio
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0490_ms-cse-worksheet-new', 'pdf_0520_professional-ms-itm-csda-concentration-worksheet'}
#   BM25-only: {'pdf_0517_professional-ms-ai-worksheet', 'pdf_0519_professional-ms-itm-adv-info-tech-concentration-worksheet', 'pdf_0518_professional-ms-cs-worksheet'}
#   Dense-only: {'pdf_0496_ms-in-computer-science-program-worksheet-6-2025', 'pdf_0408_data-science-certificate-program-application', 'pdf_0501_ms-in-information-technology-management-computer-science-dat'}
#
# ================================================================================
# Query q05: "Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025 (24.21) Document_Type = department_document, Title = Ms In Computer  | #1 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025 (0.5297) Document_Type = department_document, Title = Ms In Computer
# #2 pdf_0486_ms--coen-worksheet (24.20) Document_Type = program_form_or_worksheet, Title = Ms Coen W | #2 pdf_0334_cen5035sw-eng (0.5227) Document_Type = course_syllabus, Title = Cen5035Sw Eng, Cour
# #3 pdf_0411_eecs-low-residency-phd-form (21.20) Document_Type = program_form_or_worksheet, Title = Eecs Low  | #3 course_0271_EGN_1002 (0.5057) Document_Type = course_listing, Title = Fundamentals of Engi
# #4 pdf_0484_minor-in-business-worksheet (20.89) Document_Type = program_form_or_worksheet, Title = Minor In  | #4 pdf_0496_ms-in-computer-science-program-worksheet-6-2025 (0.5011) Document_Type = program_form_or_worksheet, Title = Ms In Com
# #5 pdf_0502_ms-in-information-technology-management-cybersecurity-progra (20.40) Document_Type = program_form_or_worksheet, Title = Ms In Inf | #5 pdf_0486_ms--coen-worksheet (0.4934) Document_Type = program_form_or_worksheet, Title = Ms Coen W
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0495_ms-in-computer-engineering-program-sheet-6-2025', 'pdf_0486_ms--coen-worksheet'}
#   BM25-only: {'pdf_0411_eecs-low-residency-phd-form', 'pdf_0484_minor-in-business-worksheet', 'pdf_0502_ms-in-information-technology-management-cybersecurity-progra'}
#   Dense-only: {'pdf_0334_cen5035sw-eng', 'pdf_0496_ms-in-computer-science-program-worksheet-6-2025', 'course_0271_EGN_1002'}
#
# ================================================================================
# Query q06: "Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025 (31.16) Document_Type = department_document, Title = Ms In Electrica | #1 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025 (0.5625) Document_Type = department_document, Title = Ms In Electrica
# #2 pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet (29.91) Document_Type = program_form_or_worksheet, Title = Ms Electr | #2 course_0251_EEL_4216 (0.5388) Document_Type = course_listing, Title = Electric Power Syste
# #3 pdf_0498_ms-in-eel-worksheet (27.88) Document_Type = program_form_or_worksheet, Title = Ms In Eel | #3 pdf_0436_eel4220electrical-machines (0.5247) Document_Type = course_syllabus, Title = Eel4220Electrical M
# #4 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025 (26.45) Document_Type = department_document, Title = Ms In Computer  | #4 course_0242_EEL_3012 (0.5233) Document_Type = course_listing, Title = Electrical Engineeri
# #5 pdf_0507_ms-to-phd-electrical-engineering-worksheet1.13.2026 (26.21) Document_Type = program_form_or_worksheet, Title = Ms To Phd | #5 pdf_0498_ms-in-eel-worksheet (0.5142) Document_Type = program_form_or_worksheet, Title = Ms In Eel
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025', 'pdf_0498_ms-in-eel-worksheet'}
#   BM25-only: {'pdf_0507_ms-to-phd-electrical-engineering-worksheet1.13.2026', 'pdf_0495_ms-in-computer-engineering-program-sheet-6-2025', 'pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet'}
#   Dense-only: {'pdf_0436_eel4220electrical-machines', 'course_0242_EEL_3012', 'course_0251_EEL_4216'}
#
# ================================================================================
# Query q07: "Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0405_cybersecurity-certificate-worksheet-2023 (52.14) Document_Type = program_form_or_worksheet, Title = Cybersecu | #1 pdf_0403_cyber-security-cert-program-worksheet (0.6903) Document_Type = program_form_or_worksheet, Title = Cyber Sec
# #2 pdf_0407_cybersecurity-minor-worksheet (51.39) Document_Type = program_form_or_worksheet, Title = Cybersecu | #2 pdf_0406_cybersecurity-minor-program-application (0.5488) Document_Type = program_form_or_worksheet, Title = Cybersecu
# #3 pdf_0403_cyber-security-cert-program-worksheet (49.48) Document_Type = program_form_or_worksheet, Title = Cyber Sec | #3 pdf_0353_cis6370computer-data-security (0.5273) Document_Type = course_syllabus, Title = Cis6370Computer Dat
# #4 pdf_0345_certificate-cyber-security-application (37.72) Document_Type = program_form_or_worksheet, Title = Certifica | #4 pdf_0505_ms-phd-cybersecurity-concn12.09.2025 (0.5191) Document_Type = department_document, Title = Ms Phd Cybersec
# #5 pdf_0502_ms-in-information-technology-management-cybersecurity-progra (34.34) Document_Type = program_form_or_worksheet, Title = Ms In Inf | #5 pdf_0523_syllabus-ai-data-sci-cybersecurity-ethics-fall-2024 (0.5136) Document_Type = course_syllabus, Title = Syllabus Ai Data Sc
#
# Overlap: 1 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0403_cyber-security-cert-program-worksheet'}
#   BM25-only: {'pdf_0405_cybersecurity-certificate-worksheet-2023', 'pdf_0407_cybersecurity-minor-worksheet', 'pdf_0345_certificate-cyber-security-application', 'pdf_0502_ms-in-information-technology-management-cybersecurity-progra'}
#   Dense-only: {'pdf_0406_cybersecurity-minor-program-application', 'pdf_0523_syllabus-ai-data-sci-cybersecurity-ethics-fall-2024', 'pdf_0505_ms-phd-cybersecurity-concn12.09.2025', 'pdf_0353_cis6370computer-data-security'}
#
# ================================================================================
# Query q08: "Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0514_professional-certificate-big-data-analytics-worksheet (40.67) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0514_professional-certificate-big-data-analytics-worksheet (0.6153) Document_Type = program_form_or_worksheet, Title = Professio
# #2 pdf_0277_4-plus-1-itm-csda (36.34) Document_Type = department_document, Title = 4 Plus 1 Itm Cs | #2 pdf_0283_big-data-analytics-cert-program-worksheet (0.5751) Document_Type = program_form_or_worksheet, Title = Big Data
# #3 pdf_0513_professional-certificate-big-data-analytics-application (33.03) Document_Type = program_form_or_worksheet, Title = Professio | #3 pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025 (0.5727) Document_Type = program_form_or_worksheet, Title = Ms In Dat
# #4 pdf_0487_ms--dsa--worksheet (32.43) Document_Type = program_form_or_worksheet, Title = Ms Dsa Wo | #4 pdf_0408_data-science-certificate-program-application (0.5620) Document_Type = program_form_or_worksheet, Title = Data Scie
# #5 pdf_0283_big-data-analytics-cert-program-worksheet (31.90) Document_Type = program_form_or_worksheet, Title = Big Data  | #5 pdf_0501_ms-in-information-technology-management-computer-science-dat (0.5580) Document_Type = program_form_or_worksheet, Title = Ms In Inf
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0283_big-data-analytics-cert-program-worksheet', 'pdf_0514_professional-certificate-big-data-analytics-worksheet'}
#   BM25-only: {'pdf_0513_professional-certificate-big-data-analytics-application', 'pdf_0277_4-plus-1-itm-csda', 'pdf_0487_ms--dsa--worksheet'}
#   Dense-only: {'pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025', 'pdf_0408_data-science-certificate-program-application', 'pdf_0501_ms-in-information-technology-management-computer-science-dat'}
#
# ================================================================================
# Query q09: "Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0343_certificate-artificial-intelligence-program-worksheet (28.92) Document_Type = program_form_or_worksheet, Title = Certifica | #1 course_0030_CAP_6673 (0.5490) Document_Type = course_listing, Title = Data Mining and Mach
# #2 pdf_0342_certificate-artificial-intelligence--program-worksheet (28.90) Document_Type = program_form_or_worksheet, Title = Certifica | #2 pdf_0311_cap6635artificial-intelligence (0.5396) Document_Type = course_syllabus, Title = Cap6635Artificial I
# #3 pdf_0300_cap5615intro-neural-networks (27.80) Document_Type = course_syllabus, Title = Cap5615Intro Neural | #3 pdf_0298_cap4630artificial-intelligence (0.5296) Document_Type = course_syllabus, Title = Cap4630Artificial I
# #4 pdf_0306_cap6411foundations-vision (27.10) Document_Type = course_syllabus, Title = Cap6411Foundations  | #4 course_0005_CAP_5625 (0.5194) Document_Type = course_listing, Title = Computational Founda
# #5 pdf_0310_cap6619deep-learning (27.06) Document_Type = course_syllabus, Title = Cap6619Deep Learnin | #5 course_0020_CAP_6619 (0.5128) Document_Type = course_listing, Title = Deep Learning CAP 66
#
# Overlap: 0 / 5 docs appear in both top-5
#   BM25-only: {'pdf_0343_certificate-artificial-intelligence-program-worksheet', 'pdf_0300_cap5615intro-neural-networks', 'pdf_0306_cap6411foundations-vision', 'pdf_0342_certificate-artificial-intelligence--program-worksheet', 'pdf_0310_cap6619deep-learning'}
#   Dense-only: {'course_0005_CAP_5625', 'course_0020_CAP_6619', 'course_0030_CAP_6673', 'pdf_0311_cap6635artificial-intelligence', 'pdf_0298_cap4630artificial-intelligence'}
#
# ================================================================================
# Query q10: "Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0283_big-data-analytics-cert-program-worksheet (35.45) Document_Type = program_form_or_worksheet, Title = Big Data  | #1 pdf_0299_cap4770intro-data-mining-machine-intelligence (0.6029) Document_Type = course_syllabus, Title = Cap4770Intro Data M
# #2 pdf_0317_cap6780big-data-analytics (32.85) Document_Type = course_syllabus, Title = Cap6780Big Data Ana | #2 course_0029_CAP_6673 (0.5962) Document_Type = course_listing, Title = Data Mining and Mach
# #3 pdf_0305_cap6315social-networks-big-data-analytics (27.81) Document_Type = course_syllabus, Title = Cap6315Social Netwo | #3 pdf_0317_cap6780big-data-analytics (0.5952) Document_Type = course_syllabus, Title = Cap6780Big Data Ana
# #4 pdf_0315_cap6777web-mining (26.92) Document_Type = course_syllabus, Title = Cap6777Web Mining,  | #4 pdf_0315_cap6777web-mining (0.5947) Document_Type = course_syllabus, Title = Cap6777Web Mining,
# #5 pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025 (26.82) Document_Type = program_form_or_worksheet, Title = Ms In Dat | #5 course_0038_CAP_6778 (0.5876) Document_Type = course_listing, Title = Advanced Data Mining
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0317_cap6780big-data-analytics', 'pdf_0315_cap6777web-mining'}
#   BM25-only: {'pdf_0283_big-data-analytics-cert-program-worksheet', 'pdf_0305_cap6315social-networks-big-data-analytics', 'pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025'}
#   Dense-only: {'pdf_0299_cap4770intro-data-mining-machine-intelligence', 'course_0038_CAP_6778', 'course_0029_CAP_6673'}
#
# ================================================================================
# Query q11: "Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0336_cen6027sw-maint-evolution (39.50) Document_Type = course_syllabus, Title = Cen6027Sw Maint Evo | #1 pdf_0334_cen5035sw-eng (0.6509) Document_Type = course_syllabus, Title = Cen5035Sw Eng, Cour
# #2 pdf_0339_cen6085sw-architecture-patterns (35.07) Document_Type = course_syllabus, Title = Cen6085Sw Architect | #2 pdf_0331_cen4010principles-sw-engineering (0.6374) Document_Type = course_syllabus, Title = Cen4010Principles S
# #3 pdf_0338_cen6076sw-testing (35.02) Document_Type = course_syllabus, Title = Cen6076Sw Testing,  | #3 course_0164_CEN_4010 (0.6193) Document_Type = course_listing, Title = Principles of Softwa
# #4 pdf_0334_cen5035sw-eng (34.65) Document_Type = course_syllabus, Title = Cen5035Sw Eng, Cour | #4 pdf_0338_cen6076sw-testing (0.6186) Document_Type = course_syllabus, Title = Cen6076Sw Testing,
# #5 pdf_0331_cen4010principles-sw-engineering (34.25) Document_Type = course_syllabus, Title = Cen4010Principles S | #5 course_0166_CEN_4214 (0.6072) Document_Type = course_listing, Title = Software Hardware Co
#
# Overlap: 3 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0334_cen5035sw-eng', 'pdf_0331_cen4010principles-sw-engineering', 'pdf_0338_cen6076sw-testing'}
#   BM25-only: {'pdf_0336_cen6027sw-maint-evolution', 'pdf_0339_cen6085sw-architecture-patterns'}
#   Dense-only: {'course_0166_CEN_4214', 'course_0164_CEN_4010'}
#
# ================================================================================
# Query q12: "Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0451_eel4930renewable-energy (34.35) Document_Type = course_syllabus, Title = Eel4930Renewable En | #1 course_0251_EEL_4216 (0.6589) Document_Type = course_listing, Title = Electric Power Syste
# #2 pdf_0459_eel6291smart-grid (34.13) Document_Type = course_syllabus, Title = Eel6291Smart Grid,  | #2 course_0254_EEL_4421C (0.6207) Document_Type = course_listing, Title = RF Devices and Circu
# #3 pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet (32.94) Document_Type = program_form_or_worksheet, Title = Ms Electr | #3 course_0117_EEE_6374 (0.5953) Document_Type = course_listing, Title = RF Devices and Circu
# #4 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025 (28.43) Document_Type = department_document, Title = Ms In Electrica | #4 course_0244_EEL_3111 (0.5867) Document_Type = course_listing, Title = Circuits 1, Course_C
# #5 pdf_0460_eel6468smart-antennas (28.18) Document_Type = course_syllabus, Title = Eel6468Smart Antenn | #5 course_0245_EEL_3112 (0.5781) Document_Type = course_listing, Title = Circuits 2, Course_C
#
# Overlap: 0 / 5 docs appear in both top-5
#   BM25-only: {'pdf_0451_eel4930renewable-energy', 'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025', 'pdf_0459_eel6291smart-grid', 'pdf_0460_eel6468smart-antennas', 'pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet'}
#   Dense-only: {'course_0117_EEE_6374', 'course_0245_EEL_3112', 'course_0251_EEL_4216', 'course_0254_EEL_4421C', 'course_0244_EEL_3111'}
#
# ================================================================================
# Query q13: "Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0328_cda6214structured-vlsi-design (25.85) Document_Type = course_syllabus, Title = Cda6214Structured V | #1 pdf_0327_cda6132multip-architecture (0.6117) Document_Type = course_syllabus, Title = Cda6132Multip Archi
# #2 pdf_0322_cda4204cad-based-computer-design (20.23) Document_Type = course_syllabus, Title = Cda4204Cad Based Co | #2 course_0166_CEN_4214 (0.5989) Document_Type = course_listing, Title = Software Hardware Co
# #3 pdf_0320_cda3331c-intro-microprocessor-system (18.18) Document_Type = course_syllabus, Title = Cda3331C Intro Micr | #3 course_0152_CDA_3331C (0.5711) Document_Type = course_listing, Title = Introduction to Micr
# #4 pdf_0319_cda3201c-intro-logic-design (17.74) Document_Type = course_syllabus, Title = Cda3201C Intro Logi | #4 course_0158_CDA_4210 (0.5301) Document_Type = course_listing, Title = Introduction to VLSI
# #5 pdf_0327_cda6132multip-architecture (17.43) Document_Type = course_syllabus, Title = Cda6132Multip Archi | #5 pdf_0328_cda6214structured-vlsi-design (0.5294) Document_Type = course_syllabus, Title = Cda6214Structured V
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0327_cda6132multip-architecture', 'pdf_0328_cda6214structured-vlsi-design'}
#   BM25-only: {'pdf_0319_cda3201c-intro-logic-design', 'pdf_0322_cda4204cad-based-computer-design', 'pdf_0320_cda3331c-intro-microprocessor-system'}
#   Dense-only: {'course_0166_CEN_4214', 'course_0152_CDA_3331C', 'course_0158_CDA_4210'}
#
# ================================================================================
# Query q14: "Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0411_eecs-low-residency-phd-form (51.77) Document_Type = program_form_or_worksheet, Title = Eecs Low  | #1 pdf_0410_eecs-eac-conflict-of-interest (0.5967) Document_Type = department_document, Title = Eecs Eac Confli
# #2 pdf_0293_bsphd-grad-pathway-scholarship-application (43.59) Document_Type = program_form_or_worksheet, Title = Bsphd Gra | #2 pdf_0411_eecs-low-residency-phd-form (0.5670) Document_Type = program_form_or_worksheet, Title = Eecs Low
# #3 pdf_0479_grad-pathway-scholarship-application (39.93) Document_Type = program_form_or_worksheet, Title = Grad Path | #3 course_0225_COT_4930 (0.5551) Document_Type = course_listing, Title = , Course_Code = COT
# #4 pdf_0478_grad-pathway-scholarship-application-revised (39.79) Document_Type = program_form_or_worksheet, Title = Grad Path | #4 course_0085_COT_5930 (0.5436) Document_Type = course_listing, Title = /COT 4930, Course_Co
# #5 pdf_0292_bsphd-audit-form (35.32) Document_Type = program_form_or_worksheet, Title = Bsphd Aud | #5 course_0086_COT_5930 (0.5134) Document_Type = course_listing, Title = 006/007, Course_Code
#
# Overlap: 1 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0411_eecs-low-residency-phd-form'}
#   BM25-only: {'pdf_0293_bsphd-grad-pathway-scholarship-application', 'pdf_0292_bsphd-audit-form', 'pdf_0479_grad-pathway-scholarship-application', 'pdf_0478_grad-pathway-scholarship-application-revised'}
#   Dense-only: {'course_0225_COT_4930', 'pdf_0410_eecs-eac-conflict-of-interest', 'course_0085_COT_5930', 'course_0086_COT_5930'}

# %%
#bm25_weight= 2.5, dense_weight= 0.3
def rrf_process(bm25_df, dense_df, k=60, bm25_weight= 2.6, dense_weight= 0.25):
    fused_results = []

    bm_ids = set(bm25_df["query_id"])
    dense_ids = set(dense_df["query_id"])
    query_ids = sorted(bm_ids.union(dense_ids))

    for qid in query_ids:
        rrf_scores = {}

        bm25_q = bm25_df[bm25_df["query_id"] == qid]
        dense_q = dense_df[dense_df["query_id"] == qid]

        # BM25 contribution
        for _, row in bm25_q.iterrows():
            doc_id = row["doc_id"]
            rank = int(row["rank"])
            rrf_scores[doc_id] = rrf_scores.get(doc_id, 0.0) + (
                bm25_weight / (k + rank)
            )

        # Dense contribution
        for _, row in dense_q.iterrows():
            doc_id = row["doc_id"]
            rank = int(row["rank"])
            rrf_scores[doc_id] = rrf_scores.get(doc_id, 0.0) + (
                dense_weight / (k + rank)
            )

        ranked_docs = sorted(rrf_scores.items(), key=lambda x: x[1], reverse=True)

        for final_rank, (doc_id, score) in enumerate(ranked_docs, start=1):
            fused_results.append({
                "query_id": qid,
                "doc_id": doc_id,
                "rrf_score": round(score, 6),
                "rank": final_rank
            })

    fused_df = pd.DataFrame(fused_results)
    return fused_df

# %%
def preprocess_text(text):
    words = re.findall(r"[A-Za-z0-9]+", str(text).lower())
    
    cleaned_words = [
        stemmer.stem(word)
        for word in words
        if word not in stop_words and len(word) > 1
    ]
    
    return set(cleaned_words)


def simple_word_match_percent(query_text, doc_text):
    query_words = preprocess_text(query_text)
    doc_words = preprocess_text(doc_text)

    if not query_words:
        return 0.0

    overlap = query_words.intersection(doc_words)
    return (len(overlap) / len(query_words)) * 100


def semantic_similarity_score(query_text, doc_text, embedding_model):
    embeddings = embedding_model.encode(
        [str(query_text), str(doc_text)],
        normalize_embeddings=True,
        convert_to_numpy=True
    )

    query_vec = embeddings[0]
    doc_vec = embeddings[1]

    cosine_sim = float(np.dot(query_vec, doc_vec))
    cs = round(cosine_sim, 2)
    return cs

# %%
SUMMARY_MODEL_NAME = "google/flan-t5-small"

print(f"Loading summarization model: {SUMMARY_MODEL_NAME}")
summary_tokenizer = AutoTokenizer.from_pretrained(SUMMARY_MODEL_NAME)
summary_model = AutoModelForSeq2SeqLM.from_pretrained(SUMMARY_MODEL_NAME)
print("Summarization model loaded.")

# Lookup tables for doc_id -> full document text and metadata
corpus_df = corpus_df.fillna("")
doc_lookup = dict(zip(corpus_df["doc_id"], corpus_df["text"].astype(str)))
metadata_lookup = corpus_df.set_index("doc_id").to_dict(orient="index")

FIELD_NAMES = [
    "Document_Type",
    "Title",
    "Course_Code",
    "Prefix",
    "Number",
    "Level",
    "Source_Page",
    "Linked_File_or_Page",
    "File_Name",
    "Content"
]


def field_to_pattern(field_name):
    """
    Allow matching labels written with underscores or spaces.
    Example: Course_Code or Course Code
    """
    return re.escape(field_name).replace(r"\_", r"[ _]+")


def extract_structured_fields(doc_text):
    """
    Extract the labeled metadata fields from one department corpus document.
    """
    text = " ".join(str(doc_text).replace("\n", " ").split())
    extracted = {}

    for i, field in enumerate(FIELD_NAMES):
        current_label = field_to_pattern(field)

        if i < len(FIELD_NAMES) - 1:
            next_labels = [field_to_pattern(f) for f in FIELD_NAMES[i + 1:]]
            next_label_pattern = "|".join(next_labels)
            pattern = rf"{current_label}\s*=\s*(.*?)(?=,\s*(?:{next_label_pattern})\s*=|$)"
        else:
            pattern = rf"{current_label}\s*=\s*(.*)$"

        match = re.search(pattern, text, flags=re.IGNORECASE)
        extracted[field] = match.group(1).strip(" ,") if match else "Not found"

    return extracted


def summarize_document(query_text, doc_text, tokenizer, summary_model, embedding_model, doc_id=None):
    doc_text = str(doc_text).strip()

    empty_result = {
        "Document Type": "Not found",
        "Title": "Not found",
        "Course Code": "Not found",
        "Level": "Not found",
        "File Name": "Not found",
        "Source": "Not found",
        "Word Match %": 0.0,
        "Semantic Similarity": 0.0,
        "Content Summary": "No department document content available."
    }

    if not doc_text:
        return empty_result

    extracted = extract_structured_fields(doc_text)
    content_text = extracted.get("Content", "")
    if not content_text or content_text == "Not found":
        content_text = doc_text

    word_match = simple_word_match_percent(query_text, doc_text)
    semantic_sim = semantic_similarity_score(query_text, doc_text, embedding_model)

    prompt = f"""
Summarize this Computer Science and Electrical Engineering department document in 1 to 2 sentences.

Requirements:
- Focus on forms, worksheets, certificates, degree requirements, course syllabi, prerequisites, course topics, or program information.
- Explain why the document may be relevant to the query.
- Do not use healthcare or patient language.

Metadata:
Document Type = {extracted['Document_Type']}
Title = {extracted['Title']}
Course Code = {extracted['Course_Code']}
Level = {extracted['Level']}
File Name = {extracted['File_Name']}

Query:
{query_text}

Document content:
{content_text[:2500]}
"""

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=512
    )

    outputs = summary_model.generate(
        **inputs,
        max_new_tokens=90,
        do_sample=False
    )

    content_summary = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()
    if not content_summary:
        content_summary = "No concise summary was generated for this document."

    source_value = extracted["Linked_File_or_Page"]
    if source_value == "Not found" or not source_value:
        source_value = extracted["Source_Page"]

    return {
        "Document Type": extracted["Document_Type"],
        "Title": extracted["Title"],
        "Course Code": extracted["Course_Code"],
        "Level": extracted["Level"],
        "File Name": extracted["File_Name"],
        "Source": source_value if source_value else "Not found",
        "Word Match %": round(word_match, 2),
        "Semantic Similarity": round(semantic_sim, 4),
        "Content Summary": content_summary
    }
# Out:
# Loading summarization model: google/flan-t5-small
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Summarization model loaded.

# %%
run_rrf_df = rrf_process(run_bm25_df, run_dense_df, k=60)

# Save fused results
run_rrf_df.to_csv("outputs/run_rrf.csv", index=False)

# Print top 5 per query with summaries
for qid in run_rrf_df["query_id"].unique():
    print(f"\n{'='*80}")
    print(f"RRF Results for Query {qid}")
    print(f"{'='*80}")

    query_matches = queries_df.loc[queries_df["query_id"] == qid, "query_text"]
    if query_matches.empty:
        print(f"No query text found for {qid}")
        continue

    query_text = query_matches.iloc[0]
    top_5 = run_rrf_df[run_rrf_df["query_id"] == qid].head(5)

    for _, row in top_5.iterrows():
        doc_id = row["doc_id"]
        doc_text = doc_lookup.get(doc_id, "")

        doc_summary = summarize_document(
            query_text=query_text,
            doc_text=doc_text,
            tokenizer=summary_tokenizer,
            summary_model=summary_model,
            embedding_model=model,
            doc_id=doc_id
        )

        print(
            f"Rank #{row['rank']:>2} | "
            f"Doc: {doc_id} | "
            f"RRF Score: {row['rrf_score']:.6f}"
        )
        print(f"Title: {doc_summary['Title']}")
        print(f"Type: {doc_summary['Document Type']} | Course: {doc_summary['Course Code']} | Level: {doc_summary['Level']}")
        print(f"Word Match: {doc_summary['Word Match %']}% | Semantic Similarity: {doc_summary['Semantic Similarity']}")
        print(f"Summary: {doc_summary['Content Summary']}")
        print("-" * 80)
# Out:
# ================================================================================
# RRF Results for Query q01
# ================================================================================
# Rank # 1 | Doc: pdf_0511_professional-ai-certificate-program-application | RRF Score: 0.046721
# Title: Professional Ai Certificate Program Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 84.62% | Semantic Similarity: 0.64
# Summary: Applicants must complete the application form and submit a cover letter to the program.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0512_professional-certificate-ai-worksheet | RRF Score: 0.045360
# Title: Professional Certificate Ai Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 76.92% | Semantic Similarity: 0.55
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0282_artificial-intelligence-minor-program-application-jan6 | RRF Score: 0.044356
# Title: Artificial Intelligence Minor Program Application Jan6
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 76.92% | Semantic Similarity: 0.58
# Summary: Applicants must be currently pursuing an undergraduate program at FAU.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0482_minor--artificial-intelligence-application | RRF Score: 0.044319
# Title: Minor Artificial Intelligence Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 76.92% | Semantic Similarity: 0.52
# Summary: Applicants must be currently pursuing a graduate program at FAU. The minor requires four courses which have not been counted in any other minor or certificate within the College of Engineering and Computer Science. Students cannot apply for both Minor in AI and the Certificate in AI. Students must satisfy the prerequisites for each course in the program must be 3.0 or better.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0279_artificial-inteligence-minor-worksheet-jan6 | RRF Score: 0.043333
# Title: Artificial Inteligence Minor Worksheet Jan6
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 76.92% | Semantic Similarity: 0.54
# Summary: College of Engineering and Computer Science.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q02
# ================================================================================
# Rank # 1 | Doc: pdf_0482_minor--artificial-intelligence-application | RRF Score: 0.046469
# Title: Minor Artificial Intelligence Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.66
# Summary: Applicants must be currently pursuing a graduate program at FAU. The minor requires four courses which have not been counted in any other minor or certificate within the College of Engineering and Computer Science. Students cannot apply for both Minor in AI and the Certificate in AI. Students must satisfy the prerequisites for each course in the program must be 3.0 or better.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0282_artificial-intelligence-minor-program-application-jan6 | RRF Score: 0.046034
# Title: Artificial Intelligence Minor Program Application Jan6
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.72
# Summary: Applicants must be currently pursuing an undergraduate program at FAU.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0279_artificial-inteligence-minor-worksheet-jan6 | RRF Score: 0.045238
# Title: Artificial Inteligence Minor Worksheet Jan6
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.69
# Summary: FAU
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0342_certificate-artificial-intelligence--program-worksheet | RRF Score: 0.044657
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.71
# Summary: EECS.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0343_certificate-artificial-intelligence-program-worksheet | RRF Score: 0.043906
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.69
# Summary: FAU.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q03
# ================================================================================
# Rank # 1 | Doc: pdf_0514_professional-certificate-big-data-analytics-worksheet | RRF Score: 0.046655
# Title: Professional Certificate Big Data Analytics Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 83.33% | Semantic Similarity: 0.62
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0513_professional-certificate-big-data-analytics-application | RRF Score: 0.046034
# Title: Professional Certificate Big Data Analytics Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.65
# Summary: Applicants for the Big Data Analytics Certificate Program are required to complete a GPA of 3.0 or better.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0344_certificate-big-data-analytics-application | RRF Score: 0.045176
# Title: Certificate Big Data Analytics Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 75.0% | Semantic Similarity: 0.54
# Summary: Applicants for big data analytics certificate are required to complete the application.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet | RRF Score: 0.044593
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 66.67% | Semantic Similarity: 0.59
# Summary: CS Data Analytics Courses (9) credits - Course Title Credits Semester Grade ISM 6136 Data Mining and Predictive Analytics 3 ISM 6217 Database Management Systems 3 ISM 6404 Introduction to Business Analytics and Big Data 3 ISM
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: course_0035_CAP_6776 | RRF Score: 0.042819
# Title:
# Type: course_listing | Course: CAP 6776 | Level: graduate
# Word Match: 50.0% | Semantic Similarity: 0.43
# Summary: Obtain big data analytics certificate forms, big data analytics certificate worksheets, applications, and related big data analytics program requirements.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q04
# ================================================================================
# Rank # 1 | Doc: pdf_0520_professional-ms-itm-csda-concentration-worksheet | RRF Score: 0.045782
# Title: Professional Ms Itm Csda Concentration Worksheet
# Type: program_form_or_worksheet | Course: CAP 5768 | Level: graduate
# Word Match: 83.33% | Semantic Similarity: 0.54
# Summary: Applicants for the Professional Master of Science with Major in Information Technology and Management program must complete a GPA of 3.0 (out of 4.0) or better.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0518_professional-ms-cs-worksheet | RRF Score: 0.045148
# Title: Professional Ms Cs Worksheet
# Type: program_form_or_worksheet | Course: COT 5930 | Level: graduate
# Word Match: 83.33% | Semantic Similarity: 0.47
# Summary: Applicants for the Professional Master of Science with Major in Computer Science program must apply for the Professional Master of Science with Major in Computer Science program.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0490_ms-cse-worksheet-new | RRF Score: 0.044723
# Title: Ms Cse Worksheet New
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 75.0% | Semantic Similarity: 0.58
# Summary: Complete the required POS.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0517_professional-ms-ai-worksheet | RRF Score: 0.043929
# Title: Professional Ms Ai Worksheet
# Type: program_form_or_worksheet | Course: CAP 5625 | Level: graduate
# Word Match: 75.0% | Semantic Similarity: 0.48
# Summary: Applicants for the Professional Master of Science with Major in Artificial Intelligence program must complete a GPA of 3.0 (out of 4.0) or better.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0496_ms-in-computer-science-program-worksheet-6-2025 | RRF Score: 0.042838
# Title: Ms In Computer Science Program Worksheet 6 2025
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 66.67% | Semantic Similarity: 0.58
# Summary: Complete the required POS. 6-2025 M.S. in Computer Science (EG-MS-CSC) Program Worksheet (30 credit hours total) Degree Requirements Students can choose between thesis and non-thesis options. Both options require a minimum of 30 credit hours (crs). Regardless of the option chosen, all students must complete the following requirements: • Complete one course (3 crs) from Theory &
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q05
# ================================================================================
# Rank # 1 | Doc: pdf_0495_ms-in-computer-engineering-program-sheet-6-2025 | RRF Score: 0.046721
# Title: Ms In Computer Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.53
# Summary: EG-MS-COEN Program Worksheet
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0486_ms--coen-worksheet | RRF Score: 0.045782
# Title: Ms Coen Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 83.33% | Semantic Similarity: 0.49
# Summary: Complete the required coursework.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0502_ms-in-information-technology-management-cybersecurity-progra | RRF Score: 0.043205
# Title: Ms In Information Technology Management Cybersecurity Program Sheet 6 2025
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 75.0% | Semantic Similarity: 0.46
# Summary: Obtain the MS Computer Engineering program sheet and computer engineering graduate requirements.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0501_ms-in-information-technology-management-computer-science-dat | RRF Score: 0.042172
# Title: Ms In Information Technology Management Computer Science Data Analytics Program Sheet 6 2025
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 75.0% | Semantic Similarity: 0.45
# Summary: Obtain the MS Computer Engineering program sheet and program materials.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025 | RRF Score: 0.041553
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level:
# Word Match: 83.33% | Semantic Similarity: 0.45
# Summary: Complete the required degree requirements.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q06
# ================================================================================
# Rank # 1 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025 | RRF Score: 0.046721
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level:
# Word Match: 91.67% | Semantic Similarity: 0.56
# Summary: Complete the required POS. 1/2025 M.S. in Electrical Engineering Program Worksheet (30 credit hours total) Degree Requirements Students can choose between thesis and non-thesis options. Both options require a minimum of 30 credit hours (crs) Regardless of the option chosen, all students must complete the following requirements: • Complete CGS 5937 Graduate Seminar course (zero crs). • Complete a
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet | RRF Score: 0.045225
# Title: Ms Electrical Engineering With Minor In Business Worksheet
# Type: program_form_or_worksheet | Course: EEL 3470 | Level: undergraduate
# Word Match: 83.33% | Semantic Similarity: 0.47
# Summary: MAP, MAP, MAP
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0498_ms-in-eel-worksheet | RRF Score: 0.045116
# Title: Ms In Eel Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 83.33% | Semantic Similarity: 0.51
# Summary: Complete the required coursework.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0507_ms-to-phd-electrical-engineering-worksheet1.13.2026 | RRF Score: 0.043012
# Title: Ms To Phd Electrical Engineering Worksheet1.13.2026
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 75.0% | Semantic Similarity: 0.46
# Summary: Obtain the required MS Electrical Engineering degree.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0495_ms-in-computer-engineering-program-sheet-6-2025 | RRF Score: 0.042818
# Title: Ms In Computer Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level:
# Word Match: 83.33% | Semantic Similarity: 0.42
# Summary: EECS Department.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q07
# ================================================================================
# Rank # 1 | Doc: pdf_0405_cybersecurity-certificate-worksheet-2023 | RRF Score: 0.046299
# Title: Cybersecurity Certificate Worksheet 2023
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 78.57% | Semantic Similarity: 0.51
# Summary: CS Core Course Course Title Credits Semester Grade CNT 4403 Foundations of Cybersecurity 3 CS Elective Courses Course Title Credits Semester Grade CAP 4623 Trustworthy Artificial Intelligence 3 CDA 4321 Introduction to Cryptographic Engineering 3 CIS 4213 Cyber Physical Systems Security 3 CIS 4367 Operating Systems Security 3 CIS 4634 Applied Cryptography and Security 3 COP 4665 Mobile Applications 3
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0403_cyber-security-cert-program-worksheet | RRF Score: 0.045368
# Title: Cyber Security Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 64.29% | Semantic Similarity: 0.69
# Summary: Date: Summer 2025
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0407_cybersecurity-minor-worksheet | RRF Score: 0.045182
# Title: Cybersecurity Minor Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 78.57% | Semantic Similarity: 0.46
# Summary: CS Core Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS Elective Courses - CS
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0345_certificate-cyber-security-application | RRF Score: 0.044196
# Title: Certificate Cyber Security Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 57.14% | Semantic Similarity: 0.5
# Summary: Applicants must be a bachelor's degree in any academic area.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0502_ms-in-information-technology-management-cybersecurity-progra | RRF Score: 0.043788
# Title: Ms In Information Technology Management Cybersecurity Program Sheet 6 2025
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 64.29% | Semantic Similarity: 0.51
# Summary: Obtain the required POS. 6-2025 M.S. in Information Technology & Management (EG-MS-EGIT-CSEC) Concentration Program Worksheet (30 credit hours total) Degree Requirements Students can choose between thesis and non-thesis options. Both options require a minimum of 30 credit hours (crs). Regardless of the option chosen, all students must complete the following requirements: • Maintain
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q08
# ================================================================================
# Rank # 1 | Doc: pdf_0514_professional-certificate-big-data-analytics-worksheet | RRF Score: 0.046721
# Title: Professional Certificate Big Data Analytics Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 73.33% | Semantic Similarity: 0.62
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0277_4-plus-1-itm-csda | RRF Score: 0.045507
# Title: 4 Plus 1 Itm Csda
# Type: department_document | Course:  | Level:
# Word Match: 60.0% | Semantic Similarity: 0.52
# Summary: 1.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0513_professional-certificate-big-data-analytics-application | RRF Score: 0.044946
# Title: Professional Certificate Big Data Analytics Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 66.67% | Semantic Similarity: 0.53
# Summary: Applicants must complete a GPA of 3.0 or better.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet | RRF Score: 0.044032
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 66.67% | Semantic Similarity: 0.58
# Summary: CS Data Analytics Courses (9) Credits Semester Grade ISM 6136 Data Mining and Predictive Analytics 3 ISM 6217 Database Management Systems 3 ISM 6404 Introduction to Business Analytics
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0487_ms--dsa--worksheet | RRF Score: 0.043830
# Title: Ms Dsa Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 73.33% | Semantic Similarity: 0.49
# Summary: POS
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q09
# ================================================================================
# Rank # 1 | Doc: pdf_0343_certificate-artificial-intelligence-program-worksheet | RRF Score: 0.045074
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 76.92% | Semantic Similarity: 0.4
# Summary: AU is a program that focuses on machine learning, artificial intelligence, and neural networks.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0342_certificate-artificial-intelligence--program-worksheet | RRF Score: 0.044148
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 76.92% | Semantic Similarity: 0.39
# Summary: Applicants track is a program for the Department of Computer Science and Electrical Engineering.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0310_cap6619deep-learning | RRF Score: 0.043165
# Title: Cap6619Deep Learning
# Type: course_syllabus | Course: CAP 6619 | Level: graduate
# Word Match: 53.85% | Semantic Similarity: 0.47
# Summary: Describe the course.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0300_cap5615intro-neural-networks | RRF Score: 0.042959
# Title: Cap5615Intro Neural Networks
# Type: course_syllabus | Course: CAP 5615 | Level: graduate
# Word Match: 69.23% | Semantic Similarity: 0.36
# Summary: 1. Introduction to Neural Networks 2. Learning the basics of neural networks 3. Learning the basics of neural networks 4. Single Layer
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: course_0030_CAP_6673 | RRF Score: 0.041780
# Title: Data Mining and Machine Learning CAP 5768 Introduction to Data Science CAP 6619 Deep Learning CAP 6635 Artificial Intelligence CAP 6776 Info
# Type: course_listing | Course: CAP 6673 | Level: graduate
# Word Match: 46.15% | Semantic Similarity: 0.55
# Summary: Identify the course listing for Data Mining and Machine Learning CAP 5768 Introduction to Data Science CAP 6619 Deep Learning CAP 6635 Artificial Intelligence CAP 6776
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q10
# ================================================================================
# Rank # 1 | Doc: pdf_0317_cap6780big-data-analytics | RRF Score: 0.045904
# Title: Cap6780Big Data Analytics
# Type: course_syllabus | Course: CAP 6780 | Level: graduate
# Word Match: 75.0% | Semantic Similarity: 0.6
# Summary: 1. Data Mining and Machine Learning 2. Hadoop tools for data mining and machine learning 3. Big Data 4. Big Data challenges 5. High dimensionality 6. High Dimensionality 7. Feature Selection 8. Big Data 9. Big Data 10. Ensemble Learning 11. Big Data and the Hadoop ecosystem 12. Case Studies
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet | RRF Score: 0.045227
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 75.0% | Semantic Similarity: 0.46
# Summary: CS Data Analytics Courses (9) Credits Semester Grade ISM 6136 Data Mining and Predictive Analytics 3 ISM 6217 Database Management Systems 3 ISM 6404 Introduction to Business Analytics and Big Data 3
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0315_cap6777web-mining | RRF Score: 0.044531
# Title: Cap6777Web Mining
# Type: course_syllabus | Course: CAP 6777 | Level: graduate
# Word Match: 58.33% | Semantic Similarity: 0.59
# Summary: introductory course, students will learn the basics of web mining and how to mine the web.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0305_cap6315social-networks-big-data-analytics | RRF Score: 0.044177
# Title: Cap6315Social Networks Big Data Analytics
# Type: course_syllabus | Course: CAP 6315 | Level: graduate
# Word Match: 66.67% | Semantic Similarity: 0.48
# Summary: Identify the major topics in the Big Data Analytics class.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0385_cop6726new-directions-database-systems | RRF Score: 0.042278
# Title: Cop6726New Directions Database Systems
# Type: course_syllabus | Course: COP 6726 | Level: graduate
# Word Match: 58.33% | Semantic Similarity: 0.53
# Summary: 1. Introduction to Database Systems 2. Data warehousing and Data Mining 3. Spatial and Spatio-temporal Network Database Systems 4. Data Query, Indexes, and Optimization 5. Spatial and Spatio-temporal Network Database Systems 6. Graph Algorithm
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q11
# ================================================================================
# Rank # 1 | Doc: pdf_0336_cen6027sw-maint-evolution | RRF Score: 0.046411
# Title: Cen6027Sw Maint Evolution
# Type: course_syllabus | Course: CEN 6027 | Level: graduate
# Word Match: 76.92% | Semantic Similarity: 0.59
# Summary: Software Engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0339_cen6085sw-architecture-patterns | RRF Score: 0.045612
# Title: Cen6085Sw Architecture Patterns
# Type: course_syllabus | Course: CEN 6085 | Level: graduate
# Word Match: 76.92% | Semantic Similarity: 0.58
# Summary: Describe software architectures.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0338_cen6076sw-testing | RRF Score: 0.045176
# Title: Cen6076Sw Testing
# Type: course_syllabus | Course: CEN 6076 | Level: graduate
# Word Match: 61.54% | Semantic Similarity: 0.62
# Summary: CS and CE graduate programs
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0334_cen5035sw-eng | RRF Score: 0.044723
# Title: Cen5035Sw Eng
# Type: course_syllabus | Course: CEN 5035 | Level: graduate
# Word Match: 76.92% | Semantic Similarity: 0.65
# Summary: - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department - Computer Science and Electrical Engineering Department -
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0331_cen4010principles-sw-engineering | RRF Score: 0.044032
# Title: Cen4010Principles Sw Engineering
# Type: course_syllabus | Course: CEN 4010 | Level: undergraduate
# Word Match: 76.92% | Semantic Similarity: 0.64
# Summary: (i)
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q12
# ================================================================================
# Rank # 1 | Doc: pdf_0451_eel4930renewable-energy | RRF Score: 0.042623
# Title: Eel4930Renewable Energy
# Type: course_syllabus | Course: EEL 4930 | Level: undergraduate
# Word Match: 66.67% | Semantic Similarity: 0.45
# Summary: - eel4930 Renewable Energy Systems - eel4930 - eel4930 - eel4930 - eel4930 - eel4930 - eel4930 - eel4930 - eel4930 - eel4930 - eel49
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0459_eel6291smart-grid | RRF Score: 0.041935
# Title: Eel6291Smart Grid
# Type: course_syllabus | Course: EEL 6291 | Level: graduate
# Word Match: 55.56% | Semantic Similarity: 0.45
# Summary: CS is a technical engineering course.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet | RRF Score: 0.041270
# Title: Ms Electrical Engineering With Minor In Business Worksheet
# Type: program_form_or_worksheet | Course: EEL 3470 | Level: undergraduate
# Word Match: 77.78% | Semantic Similarity: 0.29
# Summary: Applicants for the degree in Electrical Engineering must complete a Master's degree in Electrical Engineering.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0435_eel4216electric-power-systems | RRF Score: 0.040980
# Title: Eel4216Electric Power Systems
# Type: course_syllabus | Course: EEL 4216 | Level: undergraduate
# Word Match: 55.56% | Semantic Similarity: 0.5
# Summary: (iii)
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025 | RRF Score: 0.040625
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level:
# Word Match: 83.33% | Semantic Similarity: 0.37
# Summary: Obtain the required POS. 1/2025 M.S. in Electrical Engineering (EG-MS-EEL) Program Worksheet (30 credit hours total) Degree Requirements Students can choose between thesis and non-thesis options. Both options require a minimum of 30 credit hours (crs) Regardless of the option chosen, all students must complete the following requirements: • Complete CGS 5937 Graduate Seminar course (
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q13
# ================================================================================
# Rank # 1 | Doc: pdf_0328_cda6214structured-vlsi-design | RRF Score: 0.046469
# Title: Cda6214Structured Vlsi Design
# Type: course_syllabus | Course: CDA 6214 | Level: graduate
# Word Match: 75.0% | Semantic Similarity: 0.53
# Summary: To be determined
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0320_cda3331c-intro-microprocessor-system | RRF Score: 0.044946
# Title: Cda3331C Intro Microprocessor System
# Type: course_syllabus | Course:  | Level:
# Word Match: 66.67% | Semantic Similarity: 0.52
# Summary: Identify the basics of microprocessor systems and how to use them.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0322_cda4204cad-based-computer-design | RRF Score: 0.044513
# Title: Cda4204Cad Based Computer Design
# Type: course_syllabus | Course: CDA 4204 | Level: undergraduate
# Word Match: 75.0% | Semantic Similarity: 0.48
# Summary: CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0319_cda3201c-intro-logic-design | RRF Score: 0.044356
# Title: Cda3201C Intro Logic Design
# Type: course_syllabus | Course:  | Level:
# Word Match: 58.33% | Semantic Similarity: 0.52
# Summary: Logic Design: Introduction to Logic Design
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0327_cda6132multip-architecture | RRF Score: 0.044098
# Title: Cda6132Multip Architecture
# Type: course_syllabus | Course: CDA 6132 | Level: graduate
# Word Match: 66.67% | Semantic Similarity: 0.61
# Summary: 1. Computer Science and Electrical Engineering Department 2. Multicore Architecture 3. Parallel Processing 4. Massive Parallel Processing 5. Digital Signal Processing 6. Multi-Tasking 7. Parallel Programming
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q14
# ================================================================================
# Rank # 1 | Doc: pdf_0411_eecs-low-residency-phd-form | RRF Score: 0.046655
# Title: Eecs Low Residency Phd Form
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 50.0% | Semantic Similarity: 0.57
# Summary: Applicants must be a graduate student of the Department of Electrical Engineering and Computer Science.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0410_eecs-eac-conflict-of-interest | RRF Score: 0.043492
# Title: Eecs Eac Conflict Of Interest
# Type: department_document | Course:  | Level:
# Word Match: 27.78% | Semantic Similarity: 0.6
# Summary: ii)
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0293_bsphd-grad-pathway-scholarship-application | RRF Score: 0.041935
# Title: Bsphd Grad Pathway Scholarship Application
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 44.44% | Semantic Similarity: 0.33
# Summary: No
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0290_bsms-audit-form | RRF Score: 0.041747
# Title: Bsms Audit Form
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 38.89% | Semantic Similarity: 0.48
# Summary: EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS - EECS -
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0292_bsphd-audit-form | RRF Score: 0.041592
# Title: Bsphd Audit Form
# Type: program_form_or_worksheet | Course:  | Level:
# Word Match: 44.44% | Semantic Similarity: 0.45
# Summary: EECS - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/PhD - BS/Ph
# --------------------------------------------------------------------------------

# %%
qrels_path = SEARCH_REVIEW_DIR / "eecs_qrels.csv"
qrels_available = qrels_path.exists()

if qrels_available:
    qrels_df = pd.read_csv(qrels_path)
else:
    qrels_df = pd.DataFrame(columns=["query_id", "doc_id", "relevance"])
    print("No search_review/eecs_qrels.csv file was found. Skipping supervised retrieval evaluation metrics.")
    print("Retrieval still works; qrels are only needed for P@K, MAP, and nDCG scoring.")


def precision_at_k(ranked_doc_ids, rel_map, k=10):
    top = ranked_doc_ids[:k]
    if len(top) == 0:
        return 0.0
    hits = sum(1 for d in top if rel_map.get(d, 0) > 0)  # relevance 1 or 2 counts as relevant
    return hits / len(top)

# Build relevance lookup: qid -> {doc_id: relevance}
rel_by_q = {}
if qrels_available:
    for qid, g in qrels_df.groupby("query_id"):
        rel_by_q[str(qid)] = {
            str(r.doc_id): int(r.relevance)
            for r in g.itertuples(index=False)
        }


def evaluate_p10(run_df, run_name, k=10):
    if not qrels_available:
        print(f"Skipping P@{k} for {run_name}; qrels are not available.")
        return 0.0

    p10_values = []

    print(f"\nP@{k} per query ({run_name}):")
    for qid, g in run_df.groupby("query_id"):
        ranked = g.sort_values("rank")["doc_id"].astype(str).tolist()
        p10 = precision_at_k(ranked, rel_by_q.get(str(qid), {}), k=k)
        p10_values.append(p10)
        print(f"{qid}: {p10:.3f}")

    mean_p10 = float(np.mean(p10_values)) if p10_values else 0.0
    print(f"Mean P@{k} for {run_name}: {mean_p10:.3f}")
    return mean_p10

# Evaluate BM25
mean_p10_bm25 = evaluate_p10(run_bm25_df, "BM25", k=10)

# Evaluate FAISS / Dense retrieval
mean_p10_faiss = evaluate_p10(run_dense_df, "FAISS Dense Search", k=10)

# Evaluate RRF
mean_p10_rrf = evaluate_p10(run_rrf_df, "RRF Fusion", k=10)
# Out:
# P@10 per query (BM25):
# q01: 0.800
# q02: 1.000
# q03: 0.600
# q04: 0.700
# q05: 0.500
# q06: 1.000
# q07: 1.000
# q08: 1.000
# q09: 0.200
# q10: 0.200
# q11: 0.900
# q12: 0.500
# q13: 0.600
# q14: 1.000
# Mean P@10 for BM25: 0.714
#
# P@10 per query (FAISS Dense Search):
# q01: 0.900
# q02: 0.800
# q03: 0.500
# q04: 0.700
# q05: 0.500
# q06: 0.200
# q07: 1.000
# q08: 1.000
# q09: 0.600
# q10: 0.500
# q11: 0.900
# q12: 0.200
# q13: 0.600
# q14: 0.200
# Mean P@10 for FAISS Dense Search: 0.614
#
# P@10 per query (RRF Fusion):
# q01: 1.000
# q02: 1.000
# q03: 0.600
# q04: 0.800
# q05: 0.600
# q06: 1.000
# q07: 1.000
# q08: 1.000
# q09: 0.400
# q10: 0.200
# q11: 1.000
# q12: 0.600
# q13: 0.700
# q14: 1.000
# Mean P@10 for RRF Fusion: 0.779

# %%
print("\n" + "=" * 50)
print("Mean P@10 Summary")
print("=" * 50)
print(f"BM25:              {mean_p10_bm25:.3f}")
print(f"FAISS Dense:       {mean_p10_faiss:.3f}")
print(f"RRF Fusion:        {mean_p10_rrf:.3f}")
# Out:
# ==================================================
# Mean P@10 Summary
# ==================================================
# BM25:              0.714
# FAISS Dense:       0.614
# RRF Fusion:        0.779

# %%
def average_precision(ranked_doc_ids, rel_map):
    # AP uses binary relevance: treat relevance 1 or 2 as relevant
    total_relevant = sum(1 for v in rel_map.values() if v > 0)
    if total_relevant == 0:
        return 0.0

    hits = 0
    ap_sum = 0.0

    for i, d in enumerate(ranked_doc_ids, start=1):
        if rel_map.get(d, 0) > 0:
            hits += 1
            ap_sum += hits / i

    return ap_sum / total_relevant


def evaluate_map(run_df, run_name):
    if not qrels_available:
        print(f"Skipping MAP for {run_name}; qrels are not available.")
        return 0.0

    ap_values = []

    print(f"\nAverage Precision (AP) per query ({run_name}):")
    for qid, g in run_df.groupby("query_id"):
        ranked = g.sort_values("rank")["doc_id"].astype(str).tolist()
        ap = average_precision(ranked, rel_by_q.get(str(qid), {}))
        ap_values.append(ap)
        print(f"{qid}: {ap:.3f}")

    map_score = float(np.mean(ap_values)) if len(ap_values) > 0 else 0.0
    print(f"\nMAP ({run_name}): {map_score:.3f}")
    return map_score


# ---- BM25 ----
map_bm25 = evaluate_map(run_bm25_df, "BM25")

# ---- FAISS / Dense ----
map_faiss = evaluate_map(run_dense_df, "FAISS Dense Search")

# ---- RRF ----
map_rrf = evaluate_map(run_rrf_df, "RRF Fusion")


print("\n" + "=" * 50)
print("MAP Summary")
print("=" * 50)
print(f"BM25:         {map_bm25:.3f}")
print(f"FAISS Dense:  {map_faiss:.3f}")
print(f"RRF Fusion:   {map_rrf:.3f}")
# Out:
# Average Precision (AP) per query (BM25):
# q01: 0.633
# q02: 0.913
# q03: 0.976
# q04: 0.691
# q05: 0.414
# q06: 0.806
# q07: 0.873
# q08: 0.806
# q09: 0.287
# q10: 0.299
# q11: 0.771
# q12: 0.457
# q13: 0.386
# q14: 0.746
#
# MAP (BM25): 0.647
#
# Average Precision (AP) per query (FAISS Dense Search):
# q01: 0.621
# q02: 0.508
# q03: 0.862
# q04: 0.431
# q05: 0.215
# q06: 0.069
# q07: 0.786
# q08: 0.678
# q09: 0.437
# q10: 0.468
# q11: 0.466
# q12: 0.114
# q13: 0.344
# q14: 0.054
#
# MAP (FAISS Dense Search): 0.432
#
# Average Precision (AP) per query (RRF Fusion):
# q01: 0.682
# q02: 0.889
# q03: 0.948
# q04: 0.704
# q05: 0.369
# q06: 0.757
# q07: 0.904
# q08: 0.821
# q09: 0.324
# q10: 0.329
# q11: 0.809
# q12: 0.472
# q13: 0.418
# q14: 0.745
#
# MAP (RRF Fusion): 0.655
#
# ==================================================
# MAP Summary
# ==================================================
# BM25:         0.647
# FAISS Dense:  0.432
# RRF Fusion:   0.655

# %%
def dcg_at_k(ranked_doc_ids, rel_map, k=10):
    dcg = 0.0
    for i, d in enumerate(ranked_doc_ids[:k], start=1):
        gain = rel_map.get(d, 0)  # graded relevance: 0, 1, 2
        dcg += gain / math.log2(i + 1)
    return dcg


def ndcg_at_k(ranked_doc_ids, rel_map, k=10):
    dcg = dcg_at_k(ranked_doc_ids, rel_map, k)

    # Ideal DCG: sort true relevance scores from highest to lowest
    ideal_gains = sorted(rel_map.values(), reverse=True)
    idcg = 0.0
    for i, gain in enumerate(ideal_gains[:k], start=1):
        idcg += gain / math.log2(i + 1)

    return (dcg / idcg) if idcg > 0 else 0.0


def evaluate_ndcg(run_df, run_name, k=10):
    if not qrels_available:
        print(f"Skipping nDCG@{k} for {run_name}; qrels are not available.")
        return 0.0

    ndcg_values = []

    print(f"\nnDCG@{k} per query ({run_name}):")
    for qid, g in run_df.groupby("query_id"):
        ranked = g.sort_values("rank")["doc_id"].astype(str).tolist()
        ndcg = ndcg_at_k(ranked, rel_by_q.get(str(qid), {}), k=k)
        ndcg_values.append(ndcg)
        print(f"{qid}: {ndcg:.3f}")

    mean_ndcg = float(np.mean(ndcg_values)) if len(ndcg_values) > 0 else 0.0
    print(f"\nMean nDCG@{k} ({run_name}): {mean_ndcg:.3f}")
    return mean_ndcg

# ---- BM25 ----
mean_ndcg_bm25 = evaluate_ndcg(run_bm25_df, "BM25", k=30)

# ---- FAISS / Dense ----
mean_ndcg_faiss = evaluate_ndcg(run_dense_df, "FAISS Dense Search", k=30)

# ---- RRF ----
mean_ndcg_rrf = evaluate_ndcg(run_rrf_df, "RRF Fusion", k=30)

print("\n" + "=" * 50)
print("nDCG@30 Summary")
print("=" * 50)
print(f"BM25:         {mean_ndcg_bm25:.3f}")
print(f"FAISS Dense:  {mean_ndcg_faiss:.3f}")
print(f"RRF Fusion:   {mean_ndcg_rrf:.3f}")
# Out:
# nDCG@30 per query (BM25):
# q01: 0.802
# q02: 0.903
# q03: 0.993
# q04: 0.734
# q05: 0.602
# q06: 0.791
# q07: 0.876
# q08: 0.841
# q09: 0.351
# q10: 0.390
# q11: 0.742
# q12: 0.589
# q13: 0.591
# q14: 0.731
#
# Mean nDCG@30 (BM25): 0.710
#
# nDCG@30 per query (FAISS Dense Search):
# q01: 0.701
# q02: 0.722
# q03: 0.892
# q04: 0.527
# q05: 0.455
# q06: 0.227
# q07: 0.817
# q08: 0.787
# q09: 0.602
# q10: 0.554
# q11: 0.622
# q12: 0.253
# q13: 0.532
# q14: 0.201
#
# Mean nDCG@30 (FAISS Dense Search): 0.564
#
# nDCG@30 per query (RRF Fusion):
# q01: 0.833
# q02: 0.878
# q03: 0.984
# q04: 0.770
# q05: 0.596
# q06: 0.736
# q07: 0.882
# q08: 0.845
# q09: 0.364
# q10: 0.415
# q11: 0.752
# q12: 0.582
# q13: 0.589
# q14: 0.731
#
# Mean nDCG@30 (RRF Fusion): 0.711
#
# ==================================================
# nDCG@30 Summary
# ==================================================
# BM25:         0.710
# FAISS Dense:  0.564
# RRF Fusion:   0.711

# %% [markdown]
# ## Final Interactive Hybrid RAG Loop
#
# This final block creates a small RAG pipeline for custom department questions. The user enters an original query, the notebook may expand that query only for hybrid retrieval, and BM25 + FAISS + RRF retrieve the top 10 documents. Those documents are inserted into the Hugging Face prompt as hidden/background context. The normal visible output is only the final contextualized LLM answer.

# %%
# ============================================================
# Final Interactive Hybrid RAG Loop
# ============================================================
# Intended behavior:
# 1. The user enters an original custom query.
# 2. The original query can be expanded only for the hybrid search step.
# 3. BM25 + FAISS dense search retrieve candidate documents.
# 4. RRF fusion selects the top 10 documents.
# 5. The top 10 documents are injected into the Hugging Face LLM prompt as hidden context.
# 6. The user sees only the final contextualized LLM answer.

RAG_TOP_K = 10                 # Number of documents silently attached as context
RAG_RETRIEVAL_POOL = 100       # Number of BM25/dense candidates before RRF fusion
RAG_RRF_K = 60                 # RRF constant
RAG_BM25_WEIGHT = 2.6          # Match tuned notebook RRF settings
RAG_DENSE_WEIGHT = 0.25        # Match tuned notebook RRF settings
RAG_MAX_CHARS_PER_DOC = 360    # Compact context from each retrieved document
RAG_MAX_INPUT_TOKENS = 1024
RAG_MAX_NEW_TOKENS = 220
RAG_DEBUG = False              # Keep False so retrieved documents are not printed

# The notebook already loads google/flan-t5-small earlier for document summaries.
# Reuse that lightweight Hugging Face model when possible.
RAG_MODEL_NAME = globals().get("SUMMARY_MODEL_NAME", "google/flan-t5-small")

try:
    rag_tokenizer = summary_tokenizer
    rag_model = summary_model
    print(f"Reusing loaded Hugging Face model: {RAG_MODEL_NAME}")
except NameError:
    print(f"Loading Hugging Face RAG model: {RAG_MODEL_NAME}")
    rag_tokenizer = AutoTokenizer.from_pretrained(RAG_MODEL_NAME)
    rag_model = AutoModelForSeq2SeqLM.from_pretrained(RAG_MODEL_NAME)
    print("RAG model loaded.")


# ============================================================
# Query Expansion for Retrieval Only
# ============================================================

EECS_RETRIEVAL_EXPANSIONS = {
    "ai": ["artificial intelligence", "machine learning", "certificate", "minor", "program", "worksheet"],
    "artificial intelligence": ["AI", "machine learning", "certificate", "minor", "program", "worksheet"],
    "ml": ["machine learning", "artificial intelligence", "course", "syllabus"],
    "machine learning": ["ML", "artificial intelligence", "course", "syllabus"],
    "big data": ["big data analytics", "data science", "certificate", "worksheet", "application"],
    "cyber": ["cybersecurity", "cyber security", "certificate", "minor", "security"],
    "cybersecurity": ["cyber security", "certificate", "minor", "security"],
    "computer science": ["CS", "CSE", "MSCS", "MS Computer Science", "program", "worksheet", "degree requirements"],
    "computer engineering": ["CpE", "COEN", "MS Computer Engineering", "program", "worksheet", "degree requirements"],
    "electrical engineering": ["EE", "EEL", "MS Electrical Engineering", "program", "worksheet", "degree requirements"],
    "certificate": ["certification", "program application", "worksheet", "requirements"],
    "minor": ["minor form", "minor worksheet", "program requirements"],
    "form": ["forms", "application", "worksheet", "degree audit", "requirements"],
    "worksheet": ["program sheet", "degree requirements", "application", "form"],
    "graduate": ["MS", "master", "masters", "degree requirements", "program sheet"],
    "prerequisite": ["prerequisites", "pre requisite", "course requirements", "syllabus"],
    "syllabus": ["course outline", "course topics", "course objectives", "prerequisites"],
}


def improve_query_for_hybrid_search(original_query, max_extra_terms=16):
    """
    Expand the user's query for retrieval only.

    The expanded query is used by BM25 and FAISS to improve recall.
    The original query is still used as the user-facing question in the LLM prompt.
    """
    original_query = str(original_query).strip()
    lowered = original_query.lower()

    extra_terms = []
    for trigger, expansions in EECS_RETRIEVAL_EXPANSIONS.items():
        if trigger in lowered:
            for term in expansions:
                if term.lower() not in lowered and term not in extra_terms:
                    extra_terms.append(term)

    # Add general department terms when the query is short or broad.
    if len(lowered.split()) <= 5:
        for term in ["computer science", "electrical engineering", "department", "form", "worksheet", "course", "program"]:
            if term not in lowered and term not in extra_terms:
                extra_terms.append(term)

    extra_terms = extra_terms[:max_extra_terms]

    if not extra_terms:
        return original_query

    return original_query + " " + " ".join(extra_terms)


# ============================================================
# Hybrid Retrieval Helpers
# ============================================================

def bm25_search_custom(query_text, bm25_model, doc_ids, top_k=100):
    """
    Run BM25 over the existing tokenized corpus.

    Returns:
        list of (doc_id, score, rank)
    """
    query_tokens = tokenize_for_bm25(query_text)
    scores = bm25_model.get_scores(query_tokens)
    top_indices = np.argsort(scores)[::-1][:top_k]

    results = []
    for rank, idx in enumerate(top_indices, start=1):
        results.append((doc_ids[idx], float(scores[idx]), rank))

    return results



def hybrid_search_custom_query(
    retrieval_query_text,
    top_k=RAG_TOP_K,
    retrieval_pool=RAG_RETRIEVAL_POOL,
    rrf_k=RAG_RRF_K,
    bm25_weight=RAG_BM25_WEIGHT,
    dense_weight=RAG_DENSE_WEIGHT
):
    """
    Run BM25 + FAISS dense search for the retrieval-optimized query and combine them with RRF.

    Important:
    - retrieval_query_text may be expanded for search.
    - The original user query is not changed for the LLM-facing prompt.
    """
    custom_qid = "custom_query"

    dense_results = dense_search(
        query_text=retrieval_query_text,
        model=model,
        index=index,
        doc_ids=doc_ids,
        top_k=retrieval_pool
    )

    dense_df = pd.DataFrame([
        {
            "query_id": custom_qid,
            "doc_id": doc_id,
            "rank": rank,
            "score": score
        }
        for doc_id, score, rank in dense_results
    ])

    bm25_results = bm25_search_custom(
        query_text=retrieval_query_text,
        bm25_model=bm25,
        doc_ids=doc_ids,
        top_k=retrieval_pool
    )

    bm25_df = pd.DataFrame([
        {
            "query_id": custom_qid,
            "doc_id": doc_id,
            "rank": rank,
            "score": score
        }
        for doc_id, score, rank in bm25_results
    ])

    fused_df = rrf_process(
        bm25_df,
        dense_df,
        k=rrf_k,
        bm25_weight=bm25_weight,
        dense_weight=dense_weight
    )

    fused_df = fused_df.sort_values("rank").head(top_k).reset_index(drop=True)

    bm25_rank_lookup = bm25_df.set_index("doc_id")["rank"].to_dict()
    bm25_score_lookup = bm25_df.set_index("doc_id")["score"].to_dict()
    dense_rank_lookup = dense_df.set_index("doc_id")["rank"].to_dict()
    dense_score_lookup = dense_df.set_index("doc_id")["score"].to_dict()

    fused_df["bm25_rank"] = fused_df["doc_id"].map(bm25_rank_lookup)
    fused_df["bm25_score"] = fused_df["doc_id"].map(bm25_score_lookup)
    fused_df["dense_rank"] = fused_df["doc_id"].map(dense_rank_lookup)
    fused_df["dense_score"] = fused_df["doc_id"].map(dense_score_lookup)

    return fused_df


# ============================================================
# Hidden Context Formatting Helpers
# ============================================================

def get_document_record(doc_id):
    """
    Return one corpus row as a dictionary.
    """
    matches = corpus_df.loc[corpus_df["doc_id"].astype(str) == str(doc_id)]

    if matches.empty:
        return {
            "doc_id": doc_id,
            "text": "",
            "document_type": "",
            "title": "",
            "course_code": "",
            "file_name": "",
            "source_page": "",
            "linked_file_or_page": ""
        }

    return matches.iloc[0].to_dict()



def safe_extract_fields(doc_text):
    """
    Use the notebook's structured field extractor when available.
    Falls back to an empty dictionary if the extractor was not run.
    """
    try:
        return extract_structured_fields(doc_text)
    except NameError:
        return {}



def get_field_with_fallback(record, extracted, column_name, extracted_name):
    """
    Prefer explicit corpus metadata, then fall back to structured text labels.
    """
    value = str(record.get(column_name, "")).strip()
    if value and value.lower() != "nan":
        return value

    value = str(extracted.get(extracted_name, "")).strip()
    if value and value.lower() not in {"not found", "nan"}:
        return value

    return ""



def clean_context_text(text, max_chars=RAG_MAX_CHARS_PER_DOC):
    """
    Clean and truncate document text for compact hidden LLM context.
    """
    text = normalize_whitespace(text)
    if len(text) <= max_chars:
        return text
    return text[:max_chars].rstrip() + "..."



def format_document_for_hidden_context(rank, doc_id, record, max_chars_per_doc=RAG_MAX_CHARS_PER_DOC):
    """
    Convert one retrieved document into compact background context for the LLM.
    This text is sent to the model but is not printed to the user.
    """
    doc_text = str(record.get("text", "")).strip()
    extracted = safe_extract_fields(doc_text) if doc_text else {}

    title = get_field_with_fallback(record, extracted, "title", "Title") or "Untitled"
    doc_type = get_field_with_fallback(record, extracted, "document_type", "Document_Type") or "Unknown document type"
    course_code = get_field_with_fallback(record, extracted, "course_code", "Course_Code") or "N/A"
    file_name = get_field_with_fallback(record, extracted, "file_name", "File_Name") or "N/A"
    source = (
        get_field_with_fallback(record, extracted, "linked_file_or_page", "Linked_File_or_Page")
        or get_field_with_fallback(record, extracted, "source_page", "Source_Page")
        or "N/A"
    )

    content = extracted.get("Content", "") if extracted else ""
    if not content or str(content).lower() == "not found":
        content = doc_text

    excerpt = clean_context_text(content, max_chars=max_chars_per_doc)

    return f"""
Document {rank}
Doc ID: {doc_id}
Title: {title}
Type: {doc_type}
Course Code: {course_code}
File Name: {file_name}
Source: {source}
Relevant text: {excerpt}
""".strip()



def build_hidden_rag_context(fused_df, max_chars_per_doc=RAG_MAX_CHARS_PER_DOC):
    """
    Build hidden LLM context from the top retrieved documents.

    The returned context is inserted into the LLM prompt.
    The returned review table is stored internally for debugging, not displayed.
    """
    context_blocks = []
    review_rows = []

    for _, row in fused_df.iterrows():
        rank = int(row["rank"])
        doc_id = str(row["doc_id"])
        record = get_document_record(doc_id)
        doc_text = str(record.get("text", "")).strip()
        extracted = safe_extract_fields(doc_text) if doc_text else {}

        title = get_field_with_fallback(record, extracted, "title", "Title") or "Untitled"
        doc_type = get_field_with_fallback(record, extracted, "document_type", "Document_Type") or "Unknown"
        course_code = get_field_with_fallback(record, extracted, "course_code", "Course_Code") or ""
        file_name = get_field_with_fallback(record, extracted, "file_name", "File_Name") or ""
        source = (
            get_field_with_fallback(record, extracted, "linked_file_or_page", "Linked_File_or_Page")
            or get_field_with_fallback(record, extracted, "source_page", "Source_Page")
            or ""
        )

        context_blocks.append(
            format_document_for_hidden_context(
                rank=rank,
                doc_id=doc_id,
                record=record,
                max_chars_per_doc=max_chars_per_doc
            )
        )

        review_rows.append({
            "rank": rank,
            "doc_id": doc_id,
            "rrf_score": row.get("rrf_score", ""),
            "bm25_rank": row.get("bm25_rank", ""),
            "dense_rank": row.get("dense_rank", ""),
            "title": title,
            "document_type": doc_type,
            "course_code": course_code,
            "file_name": file_name,
            "source": source
        })

    return "\n\n".join(context_blocks), pd.DataFrame(review_rows)


# ============================================================
# LLM Prompting and Answer Generation
# ============================================================

def build_contextualized_prompt(original_user_query, hidden_context):
    """
    Build the final prompt sent to the Hugging Face LLM.

    Important:
    - The prompt uses the original user query.
    - Retrieved documents are included only as hidden/background context.
    - The model is instructed not to expose or list the retrieved documents.
    """
    return f"""
You are a helpful assistant for a Computer Science and Electrical Engineering department.

Answer the user's question using the retrieved department context as background knowledge.
The retrieved context is provided only to improve your answer.
Do not list the retrieved documents.
Do not reveal or summarize the full hidden context.
Do not mention the retrieval process, BM25, FAISS, or RRF.
Do not mention healthcare, patients, clinical notes, diagnoses, or procedures.
If the retrieved context does not contain enough information, say that the retrieved department documents do not provide enough information.
Give a direct, student-friendly answer using relevant course codes, forms, worksheets, certificates, degree requirements, prerequisites, or source-file details when available.

Original user question:
{original_user_query}

Retrieved department context for internal use only:
{hidden_context}

Final answer for the user:
""".strip()



def generate_rag_answer(
    original_user_query,
    hidden_context,
    tokenizer=rag_tokenizer,
    llm=rag_model,
    max_input_tokens=RAG_MAX_INPUT_TOKENS,
    max_new_tokens=RAG_MAX_NEW_TOKENS
):
    """
    Generate a user-facing answer using the original query and hidden retrieved context.
    """
    prompt = build_contextualized_prompt(original_user_query, hidden_context)

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=max_input_tokens
    )

    outputs = llm.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
        num_beams=4
    )

    answer = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

    if not answer:
        answer = "The model did not generate an answer from the retrieved department context."

    return answer


# ============================================================
# User-Facing RAG Functions
# ============================================================

LAST_RAG_RESULT = None


def ask_department_rag(
    original_user_query,
    top_k=RAG_TOP_K,
    retrieval_pool=RAG_RETRIEVAL_POOL,
    return_details=False,
    debug=RAG_DEBUG
):
    """
    Full custom-query RAG pipeline.

    Visible behavior:
    - User enters the original query.
    - The notebook prints only the contextualized LLM answer.

    Hidden behavior:
    - The original query may be expanded for hybrid retrieval only.
    - Hybrid retrieval gets the top 10 documents.
    - Those documents are inserted into the LLM prompt as hidden context.
    - The LLM answers the original user query using that context.
    - Retrieved documents are stored in LAST_RAG_RESULT for optional debugging,
      but they are not displayed unless return_details=True or debug=True.
    """
    global LAST_RAG_RESULT

    original_user_query = str(original_user_query).strip()
    if not original_user_query:
        print("Please enter a non-empty query.")
        return None

    retrieval_query = improve_query_for_hybrid_search(original_user_query)

    fused_df = hybrid_search_custom_query(
        retrieval_query_text=retrieval_query,
        top_k=top_k,
        retrieval_pool=retrieval_pool
    )

    hidden_context, top_docs_df = build_hidden_rag_context(fused_df)

    answer = generate_rag_answer(
        original_user_query=original_user_query,
        hidden_context=hidden_context
    )

    LAST_RAG_RESULT = {
        "original_query": original_user_query,
        "retrieval_query": retrieval_query,
        "answer": answer,
        "top_docs": top_docs_df,
        "hidden_context": hidden_context,
        "fused_results": fused_df
    }

    print("\n" + "=" * 90)
    print("Contextualized RAG Answer")
    print("=" * 90)
    print(answer)

    if debug:
        print("\nDebug information was requested, so retrieval details are available in LAST_RAG_RESULT.")
        print("Original query:", original_user_query)
        print("Retrieval query:", retrieval_query)

    if return_details:
        return LAST_RAG_RESULT

    return answer



def rag_query_loop():
    """
    Repeatedly ask for custom user queries and answer them with the hybrid RAG pipeline.

    The top retrieved documents are used as hidden LLM context and are not displayed.
    """
    print("Interactive CS/EE Department RAG Assistant")
    print("Enter a custom question. Hybrid search will silently attach the top 10 documents as context.")
    print("Only the final contextualized LLM answer will be displayed.")
    print("Type 'exit', 'quit', or 'q' to stop.")

    while True:
        user_query = input("\nEnter your CS/EE department query: ").strip()

        if user_query.lower() in {"exit", "quit", "q"}:
            print("Stopping interactive RAG loop.")
            break

        if not user_query:
            print("Please enter a question or type 'exit' to stop.")
            continue

        _ = ask_department_rag(user_query, return_details=False, debug=False)


# ============================================================
# Start the Interactive Hybrid RAG Loop
# ============================================================

# Example queries you can try:
# - What forms are available for the AI certificate?
# - Which documents mention big data analytics certificates or worksheets?
# - What courses are related to machine learning or artificial intelligence?
# - Are there forms related to MS Computer Science degree requirements?
# - Which documents discuss electrical engineering graduate requirements?

rag_query_loop()
