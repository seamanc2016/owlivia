# %% [markdown]
# # hs_rag_qwen
#
# Complete revised hybrid RAG notebook using BGE-M3 for retrieval and Qwen2.5-3B-Instruct for answer generation.

# %%
import pandas as pd
import math
import numpy as np
from collections import Counter
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM, pipeline
import torch
import gradio as gr
import faiss
from rank_bm25 import BM25Okapi
import re
import warnings
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from pathlib import Path
import zipfile
import json

try:
    from pypdf import PdfReader
except ImportError:
    PdfReader = None

warnings.filterwarnings('ignore')

# Create common project folders used throughout the notebook.
DATA_DIR = Path("data")
OUTPUT_DIR = Path("outputs")
SEARCH_REVIEW_DIR = Path("search_review")
DATA_DIR.mkdir(exist_ok=True)
OUTPUT_DIR.mkdir(exist_ok=True)
SEARCH_REVIEW_DIR.mkdir(exist_ok=True)

# NLTK stop words are helpful for BM25 and word-overlap scoring.
# This keeps the notebook runnable even on a fresh machine.
try:
    stop_words = set(stopwords.words("english"))
except LookupError:
    nltk.download("stopwords")
    stop_words = set(stopwords.words("english"))

stemmer = PorterStemmer()

# %%
DEPARTMENT_NAME = "Computer Science and Electrical Engineering"
SOURCE_ROOT = Path("DepCourseInfo")
ZIP_PATH_CANDIDATES = [Path("DepCourseInfo.zip"), Path("/mnt/data/DepCourseInfo.zip")]
PDF_FOLDER_NAME = "downloaded_forms_and_worksheets"

# Prefixes that are common in CS, CE, cybersecurity, networking, data science, AI, and EE/engineering course material.
# Keep this broad because the EECS pages may contain interdisciplinary course documents too.
EECS_PREFIXES = {
    "CAP", "CDA", "CEN", "CGS", "CIS", "CNT", "COP", "COT", "CSC",
    "EEE", "EEL", "EGN", "EGS", "EIN", "EML", "IDC", "ISC", "STA", "MAP", "MAD"
}

# Avoid carrying over biomedical/healthcare-oriented documents from the old topic.
# A CS/EE course with a bioinformatics title is still kept if its prefix is part of EECS_PREFIXES.
BIOMEDICAL_EXCLUDE_TERMS = {
    "bme", "biomedical", "bioengineering", "bio-systems", "stem cell", "tissue engineering"
}

def normalize_whitespace(text):
    return " ".join(str(text).replace("\x00", " ").split())


def clean_title_from_filename(filename):
    stem = Path(filename).stem
    stem = re.sub(r"[_-]+", " ", stem)
    stem = re.sub(r"\s+", " ", stem).strip()
    return stem.title()


def ensure_source_files_available(source_root=SOURCE_ROOT):
    """Use an existing DepCourseInfo folder, or unzip DepCourseInfo.zip if needed."""
    if source_root.exists():
        print(f"Using existing source folder: {source_root.resolve()}")
        return source_root

    zip_path = next((p for p in ZIP_PATH_CANDIDATES if p.exists()), None)
    if zip_path is None:
        raise FileNotFoundError(
            "Could not find DepCourseInfo folder or DepCourseInfo.zip. "
            "Place the ZIP next to this notebook or update ZIP_PATH_CANDIDATES."
        )

    print(f"Extracting {zip_path} ...")
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(Path("."))

    if not source_root.exists():
        raise FileNotFoundError(f"Expected extracted folder was not found: {source_root}")

    print(f"Extracted source folder: {source_root.resolve()}")
    return source_root


def guess_document_type(filename, linked_url="", title=""):
    text = f"{filename} {linked_url} {title}".lower()

    if any(word in text for word in ["worksheet", "application", "audit", "form"]):
        return "program_form_or_worksheet"
    if "certificate" in text or "minor" in text or "concentration" in text:
        return "certificate_minor_or_concentration"
    if re.search(r"\b[a-z]{3}\s*[-_ ]?\d{4}", text):
        return "course_syllabus"
    if "syllab" in text:
        return "course_syllabus"
    return "department_document"


def is_relevant_eecs_document(prefix="", title="", filename="", doc_type=""):
    """Return True for CS/EE department material and False for biomedical/healthcare carryover."""
    prefix = str(prefix).upper().strip()
    combined = f"{title} {filename}".lower()

    if prefix:
        return prefix in EECS_PREFIXES

    if any(term in combined for term in BIOMEDICAL_EXCLUDE_TERMS):
        return False

    # Keep program forms, worksheets, certificates, and general department files that do not have a course prefix.
    return True


def extract_pdf_text(pdf_path, max_pages=None):
    """Extract text from a PDF. Returns an empty string for scanned/unreadable PDFs."""
    if PdfReader is None:
        raise ImportError("pypdf is required. Install it with: pip install pypdf")

    try:
        reader = PdfReader(str(pdf_path))
        pages = reader.pages if max_pages is None else reader.pages[:max_pages]
        page_text = []
        for page in pages:
            try:
                page_text.append(page.extract_text() or "")
            except Exception:
                page_text.append("")
        return normalize_whitespace("\n".join(page_text))
    except Exception as exc:
        print(f"Warning: could not read PDF {pdf_path.name}: {exc}")
        return ""


def build_department_corpus(source_root=SOURCE_ROOT, data_dir=DATA_DIR):
    """
    Build a retrieval corpus for CS/EE department information.

    Output columns intentionally include the original template's required columns:
    - doc_id
    - text

    Additional metadata columns are kept for better summaries and inspection.
    """
    source_root = ensure_source_files_available(source_root)
    data_dir.mkdir(exist_ok=True)

    course_csv = source_root / "course_listings.csv"
    pdf_dir = source_root / PDF_FOLDER_NAME

    rows = []
    linked_file_lookup = {}

    if course_csv.exists():
        courses_df = pd.read_csv(course_csv)
        courses_df = courses_df.fillna("")

        # Map downloaded PDF filenames back to their source URLs when possible.
        for _, row in courses_df.iterrows():
            linked = str(row.get("linked_file_or_page", "")).strip()
            if linked.lower().endswith(".pdf"):
                linked_file_lookup[Path(linked).name.lower()] = linked

        # Add one clean course-listing document per unique course/title/source combination.
        course_docs = courses_df.copy()
        course_docs["course_key"] = (
            course_docs["course_code"].astype(str) + " | " +
            course_docs["title_or_context"].astype(str) + " | " +
            course_docs["level"].astype(str)
        )
        course_docs = course_docs.drop_duplicates("course_key")

        for i, row in course_docs.iterrows():
            prefix = str(row.get("prefix", "")).upper().strip()
            course_code = str(row.get("course_code", "")).strip()
            title = str(row.get("title_or_context", "")).strip()

            if not is_relevant_eecs_document(prefix=prefix, title=title, filename="", doc_type="course_listing"):
                continue
            level = str(row.get("level", "")).strip()
            source_page = str(row.get("source_page", "")).strip()
            linked = str(row.get("linked_file_or_page", "")).strip()
            raw_text = str(row.get("raw_text", "")).strip()

            # Keep broad EECS results, but avoid empty/noisy rows.
            if not course_code and not title and not raw_text:
                continue

            doc_id = f"course_{len(rows)+1:04d}_{course_code.replace(' ', '_') or 'unknown'}"
            labeled_text = normalize_whitespace(f"""
Document_Type = course_listing,
Title = {title},
Course_Code = {course_code},
Prefix = {prefix},
Number = {row.get('number', '')},
Level = {level},
Source_Page = {source_page},
Linked_File_or_Page = {linked},
File_Name = ,
Content = {raw_text if raw_text else f'{course_code} {title}'}
""")
            rows.append({
                "doc_id": doc_id,
                "document_type": "course_listing",
                "title": title,
                "course_code": course_code,
                "prefix": prefix,
                "number": str(row.get("number", "")).strip(),
                "level": level,
                "source_page": source_page,
                "linked_file_or_page": linked,
                "file_name": "",
                "text": labeled_text,
            })
    else:
        print(f"Warning: course listings file was not found: {course_csv}")

    if pdf_dir.exists():
        pdf_paths = sorted(pdf_dir.rglob("*.pdf"))
        print(f"Reading {len(pdf_paths)} PDFs from {pdf_dir} ...")

        for pdf_path in pdf_paths:
            file_name = pdf_path.name
            linked = linked_file_lookup.get(file_name.lower(), "")
            title = clean_title_from_filename(file_name)
            doc_type = guess_document_type(file_name, linked, title)
            pdf_text = extract_pdf_text(pdf_path)

            # Try to identify course code metadata from the filename or extracted text.
            course_match = re.search(r"\b([A-Z]{3})\s*[-_ ]?(\d{4})\b", f"{file_name} {pdf_text[:500]}", flags=re.IGNORECASE)
            prefix = course_match.group(1).upper() if course_match else ""
            number = course_match.group(2) if course_match else ""
            course_code = f"{prefix} {number}".strip()
            level = "graduate" if number.startswith(("5", "6")) else "undergraduate" if number.startswith(("1", "2", "3", "4")) else ""

            if not is_relevant_eecs_document(prefix=prefix, title=title, filename=file_name, doc_type=doc_type):
                continue

            content = pdf_text if pdf_text else "No extractable PDF text was found. Use the filename and metadata for retrieval."
            doc_id = f"pdf_{len(rows)+1:04d}_{Path(file_name).stem[:60]}"
            labeled_text = normalize_whitespace(f"""
Document_Type = {doc_type},
Title = {title},
Course_Code = {course_code},
Prefix = {prefix},
Number = {number},
Level = {level},
Source_Page = ,
Linked_File_or_Page = {linked},
File_Name = {file_name},
Content = {content}
""")
            rows.append({
                "doc_id": doc_id,
                "document_type": doc_type,
                "title": title,
                "course_code": course_code,
                "prefix": prefix,
                "number": number,
                "level": level,
                "source_page": "",
                "linked_file_or_page": linked,
                "file_name": file_name,
                "text": labeled_text,
            })
    else:
        print(f"Warning: PDF folder was not found: {pdf_dir}")

    corpus_df = pd.DataFrame(rows)
    if corpus_df.empty:
        raise ValueError("No department documents were found. Check SOURCE_ROOT and PDF_FOLDER_NAME.")

    corpus_path = data_dir / "corpus.csv"
    corpus_df.to_csv(corpus_path, index=False)
    print(f"Department corpus saved to: {corpus_path}")
    print(f"Documents created: {len(corpus_df)}")
    print(corpus_df["document_type"].value_counts())
    return corpus_df


def load_corpus(corpus_name="corpus", rebuild=False):
    corpus_fullcsvname = DATA_DIR / f"{corpus_name}.csv"

    if rebuild or not corpus_fullcsvname.exists():
        print("Building a new CS/EE department corpus...")
        corpus_df = build_department_corpus()
    else:
        corpus_df = pd.read_csv(corpus_fullcsvname).fillna("")

    print(f"Corpus: {len(corpus_df)} documents")
    print(f"Columns: {list(corpus_df.columns)}")
    print()
    print("First 3 documents:")
    for _, row in corpus_df.head(3).iterrows():
        preview = str(row["text"])[:220] + "..." if len(str(row["text"])) > 220 else str(row["text"])
        print(f"  {row['doc_id']}: {preview}")
    print()

    return corpus_df

# %%
corpus_name = "corpus"

# Use True the first time you switch from the old healthcare corpus to the CS/EE corpus.
# After data/corpus.csv has been created, you can set this to False for faster reruns.
REBUILD_CORPUS = True

corpus_df = load_corpus(corpus_name, rebuild=REBUILD_CORPUS)
# Out:
# Building a new CS/EE department corpus...
# Using existing source folder: C:\Users\xande\Projects_Py\EE\eecs_search_review_update\DepCourseInfo
# Reading 266 PDFs from DepCourseInfo\downloaded_forms_and_worksheets ...
# Department corpus saved to: data\corpus.csv
# Documents created: 530
# document_type
# course_listing               275
# course_syllabus              173
# program_form_or_worksheet     72
# department_document           10
# Name: count, dtype: int64
# Corpus: 530 documents
# Columns: ['doc_id', 'document_type', 'title', 'course_code', 'prefix', 'number', 'level', 'source_page', 'linked_file_or_page', 'file_name', 'text']
#
# First 3 documents:
#   course_0001_CAP_5615: Document_Type = course_listing, Title = Intro to Neural Networks, Course_Code = CAP 5615, Prefix = CAP, Number = 5615, Level = graduate, Source_Page = https://www.fau.edu/engineering/eecs/research/nrt/faculty/collaborato...
#   course_0002_CAP_5615: Document_Type = course_listing, Title = Introduction to Neural Networks, Course_Code = CAP 5615, Prefix = CAP, Number = 5615, Level = graduate, Source_Page = https://www.fau.edu/engineering/eecs/graduate/syllabi-ce-cs/, ...
#   course_0003_CAP_5625: Document_Type = course_listing, Title = , Course_Code = CAP 5625, Prefix = CAP, Number = 5625, Level = graduate, Source_Page = https://www.fau.edu/engineering/eecs/graduate/professional-programs/professional-ms-ai/, Link...

# %% [markdown]
# ## Chunked Retrieval Corpus
#
# This block keeps the original document-level `corpus_df`, but creates a second retrieval corpus named `active_corpus_df` / `retrieval_df`.
#
# BM25 and FAISS should index `active_corpus_df`, where each row is an overlapping chunk from a source document. This lets hybrid search retrieve specific parts of longer worksheets, forms, PDFs, and course lists instead of matching only document headings or filenames.

# %%
# ============================================================
# Build a chunked retrieval corpus for BM25 + FAISS
# ============================================================
# Why this exists:
# - corpus_df keeps one row per original source document.
# - retrieval_df / active_corpus_df keeps many smaller chunks per document.
# - BM25 and FAISS index the chunks, which improves recall for long PDFs/forms.
# - Evaluation qrels are expanded from original document IDs to chunk IDs later.

CHUNKED_CORPUS_NAME = "corpus_chunks"
REBUILD_RETRIEVAL_CHUNKS = True
CHUNK_SIZE_WORDS = 220
CHUNK_OVERLAP_WORDS = 60
MIN_CHUNK_WORDS = 35


def extract_content_from_labeled_text(text):
    """Return the Content field from the labeled corpus text when possible."""
    text = normalize_whitespace(text)
    match = re.search(r"\bContent\s*=\s*(.*)$", text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        content = match.group(1).strip(" ,")
        if content:
            return content
    return text


def chunk_words_with_overlap(text, chunk_size=CHUNK_SIZE_WORDS, overlap=CHUNK_OVERLAP_WORDS, min_words=MIN_CHUNK_WORDS):
    """Split text into overlapping word chunks."""
    text = normalize_whitespace(text)
    words = text.split()

    if not words:
        return []

    if len(words) <= chunk_size:
        return [" ".join(words)] if len(words) >= min_words or len(words) > 0 else []

    chunks = []
    step = max(1, chunk_size - overlap)

    for start in range(0, len(words), step):
        end = start + chunk_size
        chunk = " ".join(words[start:end]).strip()

        # Avoid adding tiny tail chunks unless this is the only chunk.
        if len(chunk.split()) >= min_words:
            chunks.append(chunk)

        if end >= len(words):
            break

    return chunks


def looks_like_low_value_repetition(text, max_repetition_ratio=0.35):
    """Filter chunks that are mostly repeated OCR/PDF noise, such as 'phd phd phd ...'."""
    words = re.findall(r"[A-Za-z]+", str(text).lower())
    if len(words) < 40:
        return False
    counts = Counter(words)
    most_common_word, most_common_count = counts.most_common(1)[0]
    return most_common_count / max(len(words), 1) > max_repetition_ratio


def metadata_prefix_for_chunk(row, chunk_index, chunk_count):
    """Attach enough metadata for retrieval without letting metadata overwhelm the chunk text."""
    title = str(row.get("title", "")).strip()
    document_type = str(row.get("document_type", "")).strip()
    course_code = str(row.get("course_code", "")).strip()
    prefix = str(row.get("prefix", "")).strip()
    number = str(row.get("number", "")).strip()
    level = str(row.get("level", "")).strip()
    file_name = str(row.get("file_name", "")).strip()
    source_page = str(row.get("source_page", "")).strip()
    linked = str(row.get("linked_file_or_page", "")).strip()
    parent_doc_id = str(row.get("doc_id", "")).strip()

    return normalize_whitespace(f"""
Document_Type = {document_type},
Title = {title},
Course_Code = {course_code},
Prefix = {prefix},
Number = {number},
Level = {level},
Parent_Doc_ID = {parent_doc_id},
Chunk_Index = {chunk_index} of {chunk_count},
Source_Page = {source_page},
Linked_File_or_Page = {linked},
File_Name = {file_name},
Content =
""")


def build_chunked_retrieval_corpus(corpus_df, data_dir=DATA_DIR):
    """
    Create chunk-level rows for retrieval.

    Important columns:
    - doc_id: unique chunk ID used by BM25/FAISS
    - parent_doc_id: original source document ID
    - text: metadata + chunk text used for indexing
    - chunk_text: just the chunk body used for RAG context compression
    """
    rows = []

    for _, row in corpus_df.fillna("").iterrows():
        parent_doc_id = str(row.get("doc_id", "")).strip()
        full_text = str(row.get("text", ""))
        content = extract_content_from_labeled_text(full_text)
        chunks = chunk_words_with_overlap(content)

        if not chunks:
            chunks = [normalize_whitespace(full_text)]

        chunk_count = len(chunks)
        for chunk_index, chunk_text in enumerate(chunks, start=1):
            if looks_like_low_value_repetition(chunk_text):
                continue

            chunk_id = f"{parent_doc_id}::chunk_{chunk_index:03d}"
            prefix = metadata_prefix_for_chunk(row, chunk_index, chunk_count)
            index_text = normalize_whitespace(prefix + " " + chunk_text)

            rows.append({
                "doc_id": chunk_id,
                "parent_doc_id": parent_doc_id,
                "chunk_index": chunk_index,
                "chunk_count": chunk_count,
                "chunk_text": normalize_whitespace(chunk_text),
                "text": index_text,
                "document_type": str(row.get("document_type", "")).strip(),
                "title": str(row.get("title", "")).strip(),
                "course_code": str(row.get("course_code", "")).strip(),
                "prefix": str(row.get("prefix", "")).strip(),
                "number": str(row.get("number", "")).strip(),
                "level": str(row.get("level", "")).strip(),
                "source_page": str(row.get("source_page", "")).strip(),
                "linked_file_or_page": str(row.get("linked_file_or_page", "")).strip(),
                "file_name": str(row.get("file_name", "")).strip(),
            })

    retrieval_df = pd.DataFrame(rows)
    if retrieval_df.empty:
        raise ValueError("No retrieval chunks were created. Check corpus_df and chunking settings.")

    output_path = data_dir / f"{CHUNKED_CORPUS_NAME}.csv"
    retrieval_df.to_csv(output_path, index=False)

    print(f"Chunked retrieval corpus saved to: {output_path}")
    print(f"Original source documents: {len(corpus_df)}")
    print(f"Retrieval chunks created: {len(retrieval_df)}")
    print(f"Average chunks per source document: {len(retrieval_df) / max(len(corpus_df), 1):.2f}")
    print("Chunk length summary, in words:")
    print(retrieval_df["chunk_text"].astype(str).apply(lambda x: len(x.split())).describe())

    return retrieval_df


def load_or_build_retrieval_chunks(corpus_df, rebuild=REBUILD_RETRIEVAL_CHUNKS):
    chunk_path = DATA_DIR / f"{CHUNKED_CORPUS_NAME}.csv"

    if rebuild or not chunk_path.exists():
        retrieval_df = build_chunked_retrieval_corpus(corpus_df)
    else:
        retrieval_df = pd.read_csv(chunk_path).fillna("")

    print(f"Active retrieval corpus: {len(retrieval_df)} chunks")
    print(f"Columns: {list(retrieval_df.columns)}")
    print("\nFirst 3 retrieval chunks:")
    for _, row in retrieval_df.head(3).iterrows():
        preview = str(row["chunk_text"])[:220] + "..." if len(str(row["chunk_text"])) > 220 else str(row["chunk_text"])
        print(f"  {row['doc_id']}  | parent={row.get('parent_doc_id', '')}")
        print(f"    {preview}")
    print()

    return retrieval_df


retrieval_df = load_or_build_retrieval_chunks(corpus_df)

# Use active_corpus_df for retrieval, indexing, and RAG context.
# Keep corpus_df unchanged for full-document metadata and inspection.
active_corpus_df = retrieval_df
RETRIEVAL_IS_CHUNKED = "parent_doc_id" in active_corpus_df.columns
# Out:
# Chunked retrieval corpus saved to: data\corpus_chunks.csv
# Original source documents: 530
# Retrieval chunks created: 945
# Average chunks per source document: 1.78
# Chunk length summary, in words:
# count    945.000000
# mean     136.136508
# std       91.794546
# min        2.000000
# 25%        8.000000
# 50%      176.000000
# 75%      220.000000
# max      220.000000
# Name: chunk_text, dtype: float64
# Active retrieval corpus: 945 chunks
# Columns: ['doc_id', 'parent_doc_id', 'chunk_index', 'chunk_count', 'chunk_text', 'text', 'document_type', 'title', 'course_code', 'prefix', 'number', 'level', 'source_page', 'linked_file_or_page', 'file_name']
#
# First 3 retrieval chunks:
#   course_0001_CAP_5615::chunk_001  | parent=course_0001_CAP_5615
#     Instructor for CAP 5615 Intro to Neural Networks
#   course_0002_CAP_5615::chunk_001  | parent=course_0002_CAP_5615
#     CAP 5615 Introduction to Neural Networks
#   course_0003_CAP_5625::chunk_001  | parent=course_0003_CAP_5625
#     CAP 5625

# %%
DEFAULT_DEPARTMENT_QUERIES = [('q01', 'Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements.'), ('q02', 'Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor.'), ('q03', 'Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements.'), ('q04', 'Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements.'), ('q05', 'Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements.'), ('q06', 'Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements.'), ('q07', 'Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security.'), ('q08', 'Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses.'), ('q09', 'Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi.'), ('q10', 'Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi.'), ('q11', 'Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.'), ('q12', 'Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics.'), ('q13', 'Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi.'), ('q14', 'Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms.')]


def create_default_queries(query_path):
    query_path = Path(query_path)
    query_path.parent.mkdir(parents=True, exist_ok=True)
    query_df = pd.DataFrame(DEFAULT_DEPARTMENT_QUERIES, columns=["query_id", "query_text"])
    query_df.to_csv(query_path, index=False)
    print(f"Default CS/EE department queries saved to: {query_path}")
    return query_df


def load_premade_queries(query_path=None, rebuild=False):
    """Load the starter EECS query list from search_review/eecs_queries.csv."""
    query_path = Path(query_path) if query_path is not None else SEARCH_REVIEW_DIR / "eecs_queries.csv"

    if rebuild or not query_path.exists():
        queries_df = create_default_queries(query_path)
    else:
        queries_df = pd.read_csv(query_path)

    print(f"Queries loaded from: {query_path}")
    print(f"Queries: {len(queries_df)} queries")
    for _, row in queries_df.iterrows():
        print(f"  {row['query_id']}: {row['query_text']}")
    return queries_df


QUERY_PATH = SEARCH_REVIEW_DIR / "eecs_queries.csv"

# Keep False when using the reviewed starter CSVs in search_review/.
# Set True only when you intentionally want to regenerate the starter query list.
REBUILD_QUERIES = False

queries_df = load_premade_queries(QUERY_PATH, rebuild=REBUILD_QUERIES)
# Out:
# Queries loaded from: search_review\eecs_queries.csv
# Queries: 14 queries
#   q01: Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements.
#   q02: Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor.
#   q03: Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements.
#   q04: Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements.
#   q05: Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements.
#   q06: Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements.
#   q07: Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security.
#   q08: Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses.
#   q09: Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi.
#   q10: Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi.
#   q11: Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.
#   q12: Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics.
#   q13: Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi.
#   q14: Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms.

# %%
QUERY_PATH = SEARCH_REVIEW_DIR / "eecs_queries.csv"

# Keep False when using the reviewed starter CSVs in search_review/.
# Set True only when you intentionally want to regenerate the starter query list.
REBUILD_QUERIES = False

queries_df = load_premade_queries(QUERY_PATH, rebuild=REBUILD_QUERIES)
# Out:
# Queries loaded from: search_review\eecs_queries.csv
# Queries: 14 queries
#   q01: Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements.
#   q02: Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor.
#   q03: Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements.
#   q04: Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements.
#   q05: Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements.
#   q06: Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements.
#   q07: Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security.
#   q08: Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses.
#   q09: Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi.
#   q10: Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi.
#   q11: Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design.
#   q12: Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics.
#   q13: Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi.
#   q14: Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms.

# %%
# Dense embedding model used by FAISS.
# BGE-M3 is the retrieval upgrade for this notebook.
# It improves the dense FAISS retrieval side; BM25 still handles the sparse keyword side.
MODEL_NAME = globals().get("MODEL_NAME", "BAAI/bge-m3")

# BGE-M3 is larger than MiniLM, so a smaller batch size is safer on laptops/CPU.
# Increase this if you have a strong GPU.
EMBED_BATCH_SIZE = globals().get(
    "EMBED_BATCH_SIZE",
    16 if "bge-m3" in MODEL_NAME.lower() else 64
)

print(f"Loading embedding model: {MODEL_NAME}")
model = SentenceTransformer(MODEL_NAME)
print(f"Model loaded. Embedding dimension: {model.get_sentence_embedding_dimension()}")
print(f"Embedding batch size: {EMBED_BATCH_SIZE}")
# Out:
# Loading embedding model: BAAI/bge-m3
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# Model loaded. Embedding dimension: 1024
# Embedding batch size: 16

# %%
def faiss_embedding_process(corpus_df):
    doc_ids = corpus_df['doc_id'].tolist()
    doc_texts = corpus_df['text'].astype(str).tolist()
    
    print(f"Encoding {len(doc_texts)} documents...")
    doc_embeddings = model.encode(
        doc_texts,
        batch_size=EMBED_BATCH_SIZE,
        show_progress_bar=True,
        convert_to_numpy=True,
        normalize_embeddings=True,  # L2 normalize for cosine similarity
    )
    
    print(f"Embedding shape: {doc_embeddings.shape}")
    print(f"Sample vector (first 10 dims): {doc_embeddings[0][:10]}")

    return doc_ids, doc_texts, doc_embeddings

# %%
doc_ids, doc_texts, doc_embeddings = faiss_embedding_process(active_corpus_df)
# Out:
# Encoding 945 documents...
# Batches:   0%|          | 0/60 [00:00<?, ?it/s]
# Embedding shape: (945, 1024)
# Sample vector (first 10 dims): [-0.04400833 -0.0446574   0.00981059 -0.00244941 -0.01062262  0.01916227
#   0.01983805  0.02718064 -0.02253107  0.04992457]

# %%
def faiss_index_process(doc_embeddings):
    dim = doc_embeddings.shape[1]  # 384
    index = faiss.IndexFlatIP(dim)
    index.add(doc_embeddings.astype(np.float32))
    
    print(f"FAISS index built: {index.ntotal} vectors, dimension={dim}")

    return index

# %%
index = faiss_index_process(doc_embeddings)
# Out:
# FAISS index built: 945 vectors, dimension=1024

# %%
def dense_search(query_text, model, index, doc_ids, top_k=10):
    """
    Encode a query and return the top-k most similar documents.

    Returns: list of (doc_id, score, rank) tuples
    """
    # Encode the query with the SAME model and normalization
    query_vec = model.encode(
        [query_text],
        normalize_embeddings=True,
        convert_to_numpy=True,
    ).astype(np.float32)

    # Search the FAISS index
    scores, indices = index.search(query_vec, top_k)

    results = []
    for rank, (idx, score) in enumerate(zip(indices[0], scores[0]), start=1):
        results.append((doc_ids[idx], float(score), rank))

    return results

# %%
test_query = queries_df.iloc[0]
print(f"Query: {test_query['query_id']} — \"{test_query['query_text']}\"\n")

results = dense_search(test_query['query_text'], model, index, doc_ids, top_k=5)

for doc_id, score, rank in results:
    doc_text = active_corpus_df[active_corpus_df['doc_id'] == doc_id]['text'].values[0]
    preview = str(doc_text)[:200] + '...' if len(str(doc_text)) > 200 else str(doc_text)
    print(f"  Rank {rank} | Score: {score:.4f} | {doc_id}")
    print(f"    {preview}\n")
# Out:
# Query: q01 — "Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements."
#
#   Rank 1 | Score: 0.7202 | pdf_0511_professional-ai-certificate-program-application::chunk_001
#     Document_Type = program_form_or_worksheet, Title = Professional Ai Certificate Program Application, Course_Code = , Prefix = , Number = , Level = , Parent_Doc_ID = pdf_0511_professional-ai-certificate...
#
#   Rank 2 | Score: 0.7186 | pdf_0281_artificial-intelligence-certificate-program-application-jan6::chunk_001
#     Document_Type = program_form_or_worksheet, Title = Artificial Intelligence Certificate Program Application Jan6, Course_Code = , Prefix = , Number = , Level = , Parent_Doc_ID = pdf_0281_artificial-int...
#
#   Rank 3 | Score: 0.7174 | pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003
#     Document_Type = program_form_or_worksheet, Title = Certificate Artificial Intelligence Program Worksheet, Course_Code = , Prefix = , Number = , Level = , Parent_Doc_ID = pdf_0342_certificate-artificia...
#
#   Rank 4 | Score: 0.7115 | pdf_0281_artificial-intelligence-certificate-program-application-jan6::chunk_002
#     Document_Type = program_form_or_worksheet, Title = Artificial Intelligence Certificate Program Application Jan6, Course_Code = , Prefix = , Number = , Level = , Parent_Doc_ID = pdf_0281_artificial-int...
#
#   Rank 5 | Score: 0.7102 | pdf_0512_professional-certificate-ai-worksheet::chunk_001
#     Document_Type = program_form_or_worksheet, Title = Professional Certificate Ai Worksheet, Course_Code = , Prefix = , Number = , Level = , Parent_Doc_ID = pdf_0512_professional-certificate-ai-worksheet...

# %%
TOP_K = 100
all_results = []

for _, qrow in queries_df.iterrows():
    qid = qrow['query_id']
    qtext = qrow['query_text']
    results = dense_search(qtext, model, index, doc_ids, top_k=TOP_K)
    for doc_id, score, rank in results:
        all_results.append({
            'query_id': qid,
            'doc_id': doc_id,
            'rank': rank,
            'score': round(score, 4),
        })

run_dense_df = pd.DataFrame(all_results)
run_dense_df.to_csv('outputs/run_dense.csv', index=False)

print(f"Dense retrieval results saved: {len(run_dense_df)} rows")
print(f"Queries processed: {run_dense_df['query_id'].nunique()}")
run_dense_df.head(20)
# Out:
# Dense retrieval results saved: 1400 rows
# Queries processed: 14
#    query_id                                             doc_id  rank   score
# 0       q01  pdf_0511_professional-ai-certificate-program-a...     1  0.7202
# 1       q01  pdf_0281_artificial-intelligence-certificate-p...     2  0.7186
# 2       q01  pdf_0342_certificate-artificial-intelligence--...     3  0.7174
# 3       q01  pdf_0281_artificial-intelligence-certificate-p...     4  0.7115
# 4       q01  pdf_0512_professional-certificate-ai-worksheet...     5  0.7102
# 5       q01  pdf_0341_certificate-artificial--intelligence-...     6  0.7076
# 6       q01  pdf_0278_artificial-inteligence-certificate-wo...     7  0.7065
# 7       q01  pdf_0343_certificate-artificial-intelligence-p...     8  0.7055
# 8       q01  pdf_0280_artificial-intelligence-cert-program-...     9  0.7050
# 9       q01  pdf_0342_certificate-artificial-intelligence--...    10  0.7023
# 10      q01  pdf_0343_certificate-artificial-intelligence-p...    11  0.7006
# 11      q01  pdf_0342_certificate-artificial-intelligence--...    12  0.6926
# 12      q01  pdf_0509_newcertificate-artificial-intelligenc...    13  0.6917
# 13      q01  pdf_0278_artificial-inteligence-certificate-wo...    14  0.6899
# 14      q01  pdf_0343_certificate-artificial-intelligence-p...    15  0.6861
# 15      q01  pdf_0280_artificial-intelligence-cert-program-...    16  0.6808
# 16      q01  pdf_0509_newcertificate-artificial-intelligenc...    17  0.6776
# 17      q01  pdf_0280_artificial-intelligence-cert-program-...    18  0.6734
# 18      q01  pdf_0509_newcertificate-artificial-intelligenc...    19  0.6634
# 19      q01  pdf_0282_artificial-intelligence-minor-program...    20  0.6605

# %%
def tokenize_for_bm25(text):
    words = re.findall(r"[A-Za-z0-9]+", str(text).lower())
    return [
        stemmer.stem(word)
        for word in words
        if word not in stop_words and len(word) > 1
    ]


def bm25_tokenize_corpus(corpus_df):
    tokenized_corpus = [tokenize_for_bm25(doc) for doc in corpus_df["text"]]
    return tokenized_corpus


def bm25_corpus(tokenized_corpus):
    bm25 = BM25Okapi(tokenized_corpus, k1=1.5, b=0.8)
    return bm25

# %%
tokenized_corpus = bm25_tokenize_corpus(active_corpus_df)
bm25 = bm25_corpus(tokenized_corpus)

# %%
bm25_results = []
for _, qrow in queries_df.iterrows():
    qid = qrow['query_id']
    qtext = tokenize_for_bm25(qrow['query_text'])
    scores = bm25.get_scores(qtext)
    top_indices = np.argsort(scores)[::-1][:TOP_K]
    for rank, idx in enumerate(top_indices, start=1):
        bm25_results.append({
            'query_id': qid,
            'doc_id': doc_ids[idx],
            'rank': rank,
            'score': round(float(scores[idx]), 4),
        })

run_bm25_df = pd.DataFrame(bm25_results)
run_bm25_df.to_csv('outputs/run_bm25.csv', index=False)
print(f"BM25 results: {len(run_bm25_df)} rows")
run_bm25_df.head(10)
# Out:
# BM25 results: 1400 rows
#   query_id                                             doc_id  rank    score
# 0      q01  pdf_0511_professional-ai-certificate-program-a...     1  43.8979
# 1      q01  pdf_0512_professional-certificate-ai-worksheet...     2  42.2466
# 2      q01  pdf_0343_certificate-artificial-intelligence-p...     3  36.9706
# 3      q01  pdf_0342_certificate-artificial-intelligence--...     4  36.8629
# 4      q01  pdf_0279_artificial-inteligence-minor-workshee...     5  35.5328
# 5      q01  pdf_0278_artificial-inteligence-certificate-wo...     6  33.2122
# 6      q01  pdf_0341_certificate-artificial--intelligence-...     7  32.6185
# 7      q01  pdf_0281_artificial-intelligence-certificate-p...     8  32.4820
# 8      q01  pdf_0281_artificial-intelligence-certificate-p...     9  32.3537
# 9      q01  pdf_0513_professional-certificate-big-data-ana...    10  32.3106

# %%
comparison_rows = []

for qid in queries_df['query_id']:
    bm25_q = run_bm25_df[run_bm25_df['query_id'] == qid].head(5)
    dense_q = run_dense_df[run_dense_df['query_id'] == qid].head(5)

    for rank in range(1, 6):
        bm25_row = bm25_q[bm25_q['rank'] == rank]
        dense_row = dense_q[dense_q['rank'] == rank]

        comparison_rows.append({
            'query_id': qid,
            'rank': rank,
            'bm25_doc_id': bm25_row['doc_id'].values[0] if len(bm25_row) > 0 else '',
            'bm25_score': round(bm25_row['score'].values[0], 4) if len(bm25_row) > 0 else '',
            'dense_doc_id': dense_row['doc_id'].values[0] if len(dense_row) > 0 else '',
            'dense_score': round(dense_row['score'].values[0], 4) if len(dense_row) > 0 else '',
        })

comparison_df = pd.DataFrame(comparison_rows)
comparison_df.to_csv('outputs/comparison.csv', index=False)

print("Side-by-side comparison saved to comparison.csv")
comparison_df.head(10)
# Out:
# Side-by-side comparison saved to comparison.csv
#   query_id  rank                                        bm25_doc_id  \
# 0      q01     1  pdf_0511_professional-ai-certificate-program-a...
# 1      q01     2  pdf_0512_professional-certificate-ai-worksheet...
# 2      q01     3  pdf_0343_certificate-artificial-intelligence-p...
# 3      q01     4  pdf_0342_certificate-artificial-intelligence--...
# 4      q01     5  pdf_0279_artificial-inteligence-minor-workshee...
# 5      q02     1  pdf_0282_artificial-intelligence-minor-program...
# 6      q02     2  pdf_0482_minor--artificial-intelligence-applic...
# 7      q02     3  pdf_0342_certificate-artificial-intelligence--...
# 8      q02     4  pdf_0279_artificial-inteligence-minor-workshee...
# 9      q02     5  pdf_0343_certificate-artificial-intelligence-p...
#
#    bm25_score                                       dense_doc_id  dense_score
# 0     43.8979  pdf_0511_professional-ai-certificate-program-a...       0.7202
# 1     42.2466  pdf_0281_artificial-intelligence-certificate-p...       0.7186
# 2     36.9706  pdf_0342_certificate-artificial-intelligence--...       0.7174
# 3     36.8629  pdf_0281_artificial-intelligence-certificate-p...       0.7115
# 4     35.5328  pdf_0512_professional-certificate-ai-worksheet...       0.7102
# 5     42.3154  pdf_0282_artificial-intelligence-minor-program...       0.7820
# 6     42.0421  pdf_0482_minor--artificial-intelligence-applic...       0.7558
# 7     41.9209  pdf_0279_artificial-inteligence-minor-workshee...       0.7411
# 8     41.8943  pdf_0342_certificate-artificial-intelligence--...       0.7329
# 9     41.2594  pdf_0343_certificate-artificial-intelligence-p...       0.7318

# %%
doc_lookup = dict(zip(active_corpus_df['doc_id'], active_corpus_df['text'].astype(str)))

for _, qrow in queries_df.iterrows():
    qid = qrow['query_id']
    qtext = qrow['query_text']
    print(f"\n{'='*80}")
    print(f"Query {qid}: \"{qtext}\"")
    print(f"{'='*80}")

    bm25_q = run_bm25_df[run_bm25_df['query_id'] == qid].head(5)
    dense_q = run_dense_df[run_dense_df['query_id'] == qid].head(5)

    print(f"\n{'BM25 Results':<40} | {'Dense Retrieval Results':<40}")
    print(f"{'-'*40} | {'-'*40}")

    for rank in range(5):
        # BM25 side
        if rank < len(bm25_q):
            b = bm25_q.iloc[rank]
            b_text = doc_lookup.get(b['doc_id'], '')[:60]
            bm25_str = f"#{b['rank']} {b['doc_id']} ({b['score']:.2f}) {b_text}"
        else:
            bm25_str = ""

        # Dense side
        if rank < len(dense_q):
            d = dense_q.iloc[rank]
            d_text = doc_lookup.get(d['doc_id'], '')[:60]
            dense_str = f"#{d['rank']} {d['doc_id']} ({d['score']:.4f}) {d_text}"
        else:
            dense_str = ""

        print(f"{bm25_str:<40} | {dense_str:<40}")

    # Overlap analysis
    bm25_docs = set(bm25_q['doc_id'])
    dense_docs = set(dense_q['doc_id'])
    overlap = bm25_docs & dense_docs
    print(f"\nOverlap: {len(overlap)} / 5 docs appear in both top-5")
    if overlap:
        print(f"  Shared docs: {overlap}")
    print(f"  BM25-only: {bm25_docs - dense_docs}")
    print(f"  Dense-only: {dense_docs - bm25_docs}")
# Out:
# ================================================================================
# Query q01: "Find artificial intelligence certificate forms, certificate worksheets, program applications, professional AI certificate documents, and related AI certificate requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0511_professional-ai-certificate-program-application::chunk_001 (43.90) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0511_professional-ai-certificate-program-application::chunk_001 (0.7202) Document_Type = program_form_or_worksheet, Title = Professio
# #2 pdf_0512_professional-certificate-ai-worksheet::chunk_001 (42.25) Document_Type = program_form_or_worksheet, Title = Professio | #2 pdf_0281_artificial-intelligence-certificate-program-application-jan6::chunk_001 (0.7186) Document_Type = program_form_or_worksheet, Title = Artificia
# #3 pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001 (36.97) Document_Type = program_form_or_worksheet, Title = Certifica | #3 pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003 (0.7174) Document_Type = program_form_or_worksheet, Title = Certifica
# #4 pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001 (36.86) Document_Type = program_form_or_worksheet, Title = Certifica | #4 pdf_0281_artificial-intelligence-certificate-program-application-jan6::chunk_002 (0.7115) Document_Type = program_form_or_worksheet, Title = Artificia
# #5 pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001 (35.53) Document_Type = program_form_or_worksheet, Title = Artificia | #5 pdf_0512_professional-certificate-ai-worksheet::chunk_001 (0.7102) Document_Type = program_form_or_worksheet, Title = Professio
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0511_professional-ai-certificate-program-application::chunk_001', 'pdf_0512_professional-certificate-ai-worksheet::chunk_001'}
#   BM25-only: {'pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001', 'pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001', 'pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001'}
#   Dense-only: {'pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003', 'pdf_0281_artificial-intelligence-certificate-program-application-jan6::chunk_001', 'pdf_0281_artificial-intelligence-certificate-program-application-jan6::chunk_002'}
#
# ================================================================================
# Query q02: "Find artificial intelligence minor forms, AI minor worksheets, minor program applications, and requirements for students completing an AI minor."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0282_artificial-intelligence-minor-program-application-jan6::chunk_001 (42.32) Document_Type = program_form_or_worksheet, Title = Artificia | #1 pdf_0282_artificial-intelligence-minor-program-application-jan6::chunk_001 (0.7820) Document_Type = program_form_or_worksheet, Title = Artificia
# #2 pdf_0482_minor--artificial-intelligence-application::chunk_001 (42.04) Document_Type = program_form_or_worksheet, Title = Minor Art | #2 pdf_0482_minor--artificial-intelligence-application::chunk_001 (0.7558) Document_Type = program_form_or_worksheet, Title = Minor Art
# #3 pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001 (41.92) Document_Type = program_form_or_worksheet, Title = Certifica | #3 pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001 (0.7411) Document_Type = program_form_or_worksheet, Title = Artificia
# #4 pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001 (41.89) Document_Type = program_form_or_worksheet, Title = Artificia | #4 pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001 (0.7329) Document_Type = program_form_or_worksheet, Title = Certifica
# #5 pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001 (41.26) Document_Type = program_form_or_worksheet, Title = Certifica | #5 pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001 (0.7318) Document_Type = program_form_or_worksheet, Title = Certifica
#
# Overlap: 5 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001', 'pdf_0482_minor--artificial-intelligence-application::chunk_001', 'pdf_0282_artificial-intelligence-minor-program-application-jan6::chunk_001', 'pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001', 'pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001'}
#   BM25-only: set()
#   Dense-only: set()
#
# ================================================================================
# Query q03: "Find big data analytics certificate forms, professional big data analytics certificate worksheets, applications, and related big data analytics program requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001 (60.58) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0513_professional-certificate-big-data-analytics-application::chunk_001 (0.7304) Document_Type = program_form_or_worksheet, Title = Professio
# #2 pdf_0513_professional-certificate-big-data-analytics-application::chunk_001 (59.71) Document_Type = program_form_or_worksheet, Title = Professio | #2 pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001 (0.7143) Document_Type = program_form_or_worksheet, Title = Big Data
# #3 pdf_0344_certificate-big-data-analytics-application::chunk_001 (51.72) Document_Type = program_form_or_worksheet, Title = Certifica | #3 pdf_0344_certificate-big-data-analytics-application::chunk_001 (0.7126) Document_Type = program_form_or_worksheet, Title = Certifica
# #4 pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001 (48.14) Document_Type = program_form_or_worksheet, Title = Big Data  | #4 pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001 (0.7102) Document_Type = program_form_or_worksheet, Title = Professio
# #5 pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002 (45.53) Document_Type = program_form_or_worksheet, Title = Big Data  | #5 pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002 (0.7011) Document_Type = program_form_or_worksheet, Title = Big Data
#
# Overlap: 5 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002', 'pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001', 'pdf_0344_certificate-big-data-analytics-application::chunk_001', 'pdf_0513_professional-certificate-big-data-analytics-application::chunk_001', 'pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001'}
#   BM25-only: set()
#   Dense-only: set()
#
# ================================================================================
# Query q04: "Find MS Computer Science program worksheets, MS CSE worksheet documents, professional MS CS worksheets, and computer science graduate program requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0490_ms-cse-worksheet-new::chunk_006 (28.60) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo | #1 pdf_0490_ms-cse-worksheet-new::chunk_001 (0.7399) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo
# #2 pdf_0490_ms-cse-worksheet-new::chunk_001 (28.13) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo | #2 pdf_0518_professional-ms-cs-worksheet::chunk_001 (0.7389) Document_Type = program_form_or_worksheet, Title = Professio
# #3 pdf_0518_professional-ms-cs-worksheet::chunk_001 (27.01) Document_Type = program_form_or_worksheet, Title = Professio | #3 pdf_0496_ms-in-computer-science-program-worksheet-6-2025::chunk_001 (0.7381) Document_Type = program_form_or_worksheet, Title = Ms In Com
# #4 pdf_0490_ms-cse-worksheet-new::chunk_002 (27.00) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo | #4 pdf_0503_ms-phd-computer-science-worksheet12.09.2025::chunk_002 (0.7323) Document_Type = program_form_or_worksheet, Title = Ms Phd Co
# #5 pdf_0490_ms-cse-worksheet-new::chunk_003 (26.64) Document_Type = program_form_or_worksheet, Title = Ms Cse Wo | #5 pdf_0503_ms-phd-computer-science-worksheet12.09.2025::chunk_001 (0.7268) Document_Type = program_form_or_worksheet, Title = Ms Phd Co
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0518_professional-ms-cs-worksheet::chunk_001', 'pdf_0490_ms-cse-worksheet-new::chunk_001'}
#   BM25-only: {'pdf_0490_ms-cse-worksheet-new::chunk_002', 'pdf_0490_ms-cse-worksheet-new::chunk_006', 'pdf_0490_ms-cse-worksheet-new::chunk_003'}
#   Dense-only: {'pdf_0503_ms-phd-computer-science-worksheet12.09.2025::chunk_001', 'pdf_0496_ms-in-computer-science-program-worksheet-6-2025::chunk_001', 'pdf_0503_ms-phd-computer-science-worksheet12.09.2025::chunk_002'}
#
# ================================================================================
# Query q05: "Find MS Computer Engineering program sheets, MS COEN worksheets, computer engineering application forms, and computer engineering graduate requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_001 (26.07) Document_Type = department_document, Title = Ms In Computer  | #1 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_001 (0.7441) Document_Type = department_document, Title = Ms In Computer
# #2 pdf_0486_ms--coen-worksheet::chunk_006 (25.39) Document_Type = program_form_or_worksheet, Title = Ms Coen W | #2 pdf_0486_ms--coen-worksheet::chunk_001 (0.7380) Document_Type = program_form_or_worksheet, Title = Ms Coen W
# #3 pdf_0486_ms--coen-worksheet::chunk_001 (24.72) Document_Type = program_form_or_worksheet, Title = Ms Coen W | #3 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_006 (0.7114) Document_Type = department_document, Title = Ms In Computer
# #4 pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_006 (23.38) Document_Type = department_document, Title = Ms In Computer  | #4 pdf_0508_msto-phd-computer-engineering-worksheet12.09.2025::chunk_001 (0.7090) Document_Type = program_form_or_worksheet, Title = Msto Phd
# #5 pdf_0486_ms--coen-worksheet::chunk_004 (23.30) Document_Type = program_form_or_worksheet, Title = Ms Coen W | #5 pdf_0284_bs-phd-computer-engineering-worksheet-12.09.2025::chunk_001 (0.7085) Document_Type = program_form_or_worksheet, Title = Bs Phd Co
#
# Overlap: 3 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_001', 'pdf_0486_ms--coen-worksheet::chunk_001', 'pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_006'}
#   BM25-only: {'pdf_0486_ms--coen-worksheet::chunk_006', 'pdf_0486_ms--coen-worksheet::chunk_004'}
#   Dense-only: {'pdf_0284_bs-phd-computer-engineering-worksheet-12.09.2025::chunk_001', 'pdf_0508_msto-phd-computer-engineering-worksheet12.09.2025::chunk_001'}
#
# ================================================================================
# Query q06: "Find MS Electrical Engineering worksheets, EEL program sheets, electrical engineering graduate program information, and electrical engineering degree requirements."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_003 (31.86) Document_Type = department_document, Title = Ms In Electrica | #1 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_001 (0.7478) Document_Type = department_document, Title = Ms In Electrica
# #2 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_001 (31.69) Document_Type = department_document, Title = Ms In Electrica | #2 pdf_0507_ms-to-phd-electrical-engineering-worksheet1.13.2026::chunk_003 (0.7385) Document_Type = program_form_or_worksheet, Title = Ms To Phd
# #3 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_008 (31.19) Document_Type = department_document, Title = Ms In Electrica | #3 pdf_0498_ms-in-eel-worksheet::chunk_001 (0.7323) Document_Type = program_form_or_worksheet, Title = Ms In Eel
# #4 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_006 (30.42) Document_Type = department_document, Title = Ms In Electrica | #4 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_003 (0.7254) Document_Type = department_document, Title = Ms In Electrica
# #5 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_004 (29.80) Document_Type = department_document, Title = Ms In Electrica | #5 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_004 (0.7227) Document_Type = department_document, Title = Ms In Electrica
#
# Overlap: 3 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_003', 'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_001', 'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_004'}
#   BM25-only: {'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_008', 'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_006'}
#   Dense-only: {'pdf_0507_ms-to-phd-electrical-engineering-worksheet1.13.2026::chunk_003', 'pdf_0498_ms-in-eel-worksheet::chunk_001'}
#
# ================================================================================
# Query q07: "Find cybersecurity certificate and minor documents, cyber security worksheets, cybersecurity applications, and security-related courses such as cryptography, network security, and data security."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_001 (47.27) Document_Type = program_form_or_worksheet, Title = Cybersecu | #1 pdf_0407_cybersecurity-minor-worksheet::chunk_002 (0.7380) Document_Type = program_form_or_worksheet, Title = Cybersecu
# #2 pdf_0403_cyber-security-cert-program-worksheet::chunk_001 (45.76) Document_Type = program_form_or_worksheet, Title = Cyber Sec | #2 pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_002 (0.7338) Document_Type = program_form_or_worksheet, Title = Cybersecu
# #3 pdf_0407_cybersecurity-minor-worksheet::chunk_001 (45.28) Document_Type = program_form_or_worksheet, Title = Cybersecu | #3 pdf_0404_cybersecurity-certificate-program-application::chunk_001 (0.7273) Document_Type = program_form_or_worksheet, Title = Cybersecu
# #4 pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_002 (38.75) Document_Type = program_form_or_worksheet, Title = Cybersecu | #4 pdf_0403_cyber-security-cert-program-worksheet::chunk_001 (0.7205) Document_Type = program_form_or_worksheet, Title = Cyber Sec
# #5 pdf_0407_cybersecurity-minor-worksheet::chunk_002 (38.55) Document_Type = program_form_or_worksheet, Title = Cybersecu | #5 pdf_0407_cybersecurity-minor-worksheet::chunk_001 (0.7170) Document_Type = program_form_or_worksheet, Title = Cybersecu
#
# Overlap: 4 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_002', 'pdf_0407_cybersecurity-minor-worksheet::chunk_001', 'pdf_0403_cyber-security-cert-program-worksheet::chunk_001', 'pdf_0407_cybersecurity-minor-worksheet::chunk_002'}
#   BM25-only: {'pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_001'}
#   Dense-only: {'pdf_0404_cybersecurity-certificate-program-application::chunk_001'}
#
# ================================================================================
# Query q08: "Find data science and analytics certificate documents, DSA concentration worksheets, CSDA or computer science data analytics program sheets, and related data science courses."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001 (37.30) Document_Type = program_form_or_worksheet, Title = Professio | #1 pdf_0487_ms--dsa--worksheet::chunk_001 (0.7218) Document_Type = program_form_or_worksheet, Title = Ms Dsa Wo
# #2 pdf_0277_4-plus-1-itm-csda::chunk_001 (35.59) Document_Type = department_document, Title = 4 Plus 1 Itm Cs | #2 pdf_0409_data-science-certificate-worksheet::chunk_002 (0.7192) Document_Type = program_form_or_worksheet, Title = Data Scie
# #3 pdf_0277_4-plus-1-itm-csda::chunk_002 (34.29) Document_Type = department_document, Title = 4 Plus 1 Itm Cs | #3 pdf_0408_data-science-certificate-program-application::chunk_001 (0.7095) Document_Type = program_form_or_worksheet, Title = Data Scie
# #4 pdf_0501_ms-in-information-technology-management-computer-science-dat::chunk_001 (33.85) Document_Type = program_form_or_worksheet, Title = Ms In Inf | #4 pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025::chunk_003 (0.7067) Document_Type = program_form_or_worksheet, Title = Ms In Dat
# #5 pdf_0487_ms--dsa--worksheet::chunk_001 (31.56) Document_Type = program_form_or_worksheet, Title = Ms Dsa Wo | #5 pdf_0409_data-science-certificate-worksheet::chunk_001 (0.7050) Document_Type = program_form_or_worksheet, Title = Data Scie
#
# Overlap: 1 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0487_ms--dsa--worksheet::chunk_001'}
#   BM25-only: {'pdf_0501_ms-in-information-technology-management-computer-science-dat::chunk_001', 'pdf_0277_4-plus-1-itm-csda::chunk_002', 'pdf_0277_4-plus-1-itm-csda::chunk_001', 'pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001'}
#   Dense-only: {'pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025::chunk_003', 'pdf_0409_data-science-certificate-worksheet::chunk_002', 'pdf_0408_data-science-certificate-program-application::chunk_001', 'pdf_0409_data-science-certificate-worksheet::chunk_001'}
#
# ================================================================================
# Query q09: "Find machine learning, artificial intelligence, neural networks, deep learning, computer vision, and NLP course syllabi."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003 (31.10) Document_Type = program_form_or_worksheet, Title = Certifica | #1 pdf_0310_cap6619deep-learning::chunk_002 (0.6792) Document_Type = course_syllabus, Title = Cap6619Deep Learnin
# #2 pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_003 (30.91) Document_Type = program_form_or_worksheet, Title = Certifica | #2 pdf_0310_cap6619deep-learning::chunk_001 (0.6749) Document_Type = course_syllabus, Title = Cap6619Deep Learnin
# #3 pdf_0300_cap5615intro-neural-networks::chunk_002 (28.62) Document_Type = course_syllabus, Title = Cap5615Intro Neural | #3 pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_003 (0.6636) Document_Type = program_form_or_worksheet, Title = Certifica
# #4 pdf_0509_newcertificate-artificial-intelligence-worksheet::chunk_003 (28.52) Document_Type = program_form_or_worksheet, Title = Newcertif | #4 pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003 (0.6629) Document_Type = program_form_or_worksheet, Title = Certifica
# #5 pdf_0280_artificial-intelligence-cert-program-worksheet::chunk_003 (28.34) Document_Type = program_form_or_worksheet, Title = Artificia | #5 course_0020_CAP_6619::chunk_001 (0.6529) Document_Type = course_listing, Title = Deep Learning CAP 66
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003', 'pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_003'}
#   BM25-only: {'pdf_0509_newcertificate-artificial-intelligence-worksheet::chunk_003', 'pdf_0280_artificial-intelligence-cert-program-worksheet::chunk_003', 'pdf_0300_cap5615intro-neural-networks::chunk_002'}
#   Dense-only: {'pdf_0310_cap6619deep-learning::chunk_001', 'course_0020_CAP_6619::chunk_001', 'pdf_0310_cap6619deep-learning::chunk_002'}
#
# ================================================================================
# Query q10: "Find data mining, information retrieval, web mining, big data analytics, and database-related course syllabi."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001 (35.41) Document_Type = program_form_or_worksheet, Title = Big Data  | #1 course_0038_CAP_6778::chunk_001 (0.6741) Document_Type = course_listing, Title = Advanced Data Mining
# #2 pdf_0487_ms--dsa--worksheet::chunk_005 (33.57) Document_Type = program_form_or_worksheet, Title = Ms Dsa Wo | #2 pdf_0317_cap6780big-data-analytics::chunk_001 (0.6692) Document_Type = course_syllabus, Title = Cap6780Big Data Ana
# #3 pdf_0317_cap6780big-data-analytics::chunk_001 (32.62) Document_Type = course_syllabus, Title = Cap6780Big Data Ana | #3 pdf_0316_cap6778adv-data-mining-machine-learning::chunk_001 (0.6653) Document_Type = course_syllabus, Title = Cap6778Adv Data Min
# #4 pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025::chunk_004 (30.61) Document_Type = program_form_or_worksheet, Title = Ms In Dat | #4 pdf_0315_cap6777web-mining::chunk_001 (0.6653) Document_Type = course_syllabus, Title = Cap6777Web Mining,
# #5 pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002 (29.52) Document_Type = program_form_or_worksheet, Title = Big Data  | #5 course_0029_CAP_6673::chunk_001 (0.6640) Document_Type = course_listing, Title = Data Mining and Mach
#
# Overlap: 1 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0317_cap6780big-data-analytics::chunk_001'}
#   BM25-only: {'pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025::chunk_004', 'pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001', 'pdf_0487_ms--dsa--worksheet::chunk_005', 'pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002'}
#   Dense-only: {'course_0038_CAP_6778::chunk_001', 'pdf_0316_cap6778adv-data-mining-machine-learning::chunk_001', 'course_0029_CAP_6673::chunk_001', 'pdf_0315_cap6777web-mining::chunk_001'}
#
# ================================================================================
# Query q11: "Find software engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0336_cen6027sw-maint-evolution::chunk_002 (38.95) Document_Type = course_syllabus, Title = Cen6027Sw Maint Evo | #1 pdf_0337_cen6075sw-reqs-eng::chunk_004 (0.7328) Document_Type = course_syllabus, Title = Cen6075Sw Reqs Eng,
# #2 pdf_0488_ms-computer-engineering-with-minor-in-business-worksheet::chunk_002 (36.29) Document_Type = program_form_or_worksheet, Title = Ms Comput | #2 pdf_0331_cen4010principles-sw-engineering::chunk_002 (0.7293) Document_Type = course_syllabus, Title = Cen4010Principles S
# #3 pdf_0336_cen6027sw-maint-evolution::chunk_001 (35.03) Document_Type = course_syllabus, Title = Cen6027Sw Maint Evo | #3 pdf_0334_cen5035sw-eng::chunk_002 (0.7243) Document_Type = course_syllabus, Title = Cen5035Sw Eng, Cour
# #4 pdf_0338_cen6076sw-testing::chunk_001 (34.86) Document_Type = course_syllabus, Title = Cen6076Sw Testing,  | #4 pdf_0334_cen5035sw-eng::chunk_001 (0.7028) Document_Type = course_syllabus, Title = Cen5035Sw Eng, Cour
# #5 pdf_0374_cop4331object-oriented-design::chunk_002 (34.14) Document_Type = course_syllabus, Title = Cop4331Object Orien | #5 pdf_0529_syllabus-software-engineering-management-fall-2024::chunk_010 (0.7008) Document_Type = course_syllabus, Title = Syllabus Software E
#
# Overlap: 0 / 5 docs appear in both top-5
#   BM25-only: {'pdf_0336_cen6027sw-maint-evolution::chunk_002', 'pdf_0336_cen6027sw-maint-evolution::chunk_001', 'pdf_0374_cop4331object-oriented-design::chunk_002', 'pdf_0488_ms-computer-engineering-with-minor-in-business-worksheet::chunk_002', 'pdf_0338_cen6076sw-testing::chunk_001'}
#   Dense-only: {'pdf_0331_cen4010principles-sw-engineering::chunk_002', 'pdf_0529_syllabus-software-engineering-management-fall-2024::chunk_010', 'pdf_0334_cen5035sw-eng::chunk_001', 'pdf_0334_cen5035sw-eng::chunk_002', 'pdf_0337_cen6075sw-reqs-eng::chunk_004'}
#
# ================================================================================
# Query q12: "Find electrical engineering course syllabi for circuits, electronics, signal processing, communications, control systems, antennas, RF, power systems, and smart grid topics."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet::chunk_002 (37.93) Document_Type = program_form_or_worksheet, Title = Ms Electr | #1 course_0126_EEL_6297::chunk_001 (0.6752) Document_Type = course_listing, Title = Smart Grid, Course_C
# #2 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_005 (37.69) Document_Type = department_document, Title = Ms In Electrica | #2 pdf_0459_eel6291smart-grid::chunk_001 (0.6721) Document_Type = course_syllabus, Title = Eel6291Smart Grid,
# #3 pdf_0498_ms-in-eel-worksheet::chunk_005 (36.54) Document_Type = program_form_or_worksheet, Title = Ms In Eel | #3 course_0127_EEL_6468::chunk_001 (0.6696) Document_Type = course_listing, Title = Smart Antennas, Cour
# #4 pdf_0459_eel6291smart-grid::chunk_003 (33.85) Document_Type = course_syllabus, Title = Eel6291Smart Grid,  | #4 pdf_0451_eel4930renewable-energy::chunk_002 (0.6664) Document_Type = course_syllabus, Title = Eel4930Renewable En
# #5 pdf_0451_eel4930renewable-energy::chunk_002 (32.81) Document_Type = course_syllabus, Title = Eel4930Renewable En | #5 pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_005 (0.6637) Document_Type = department_document, Title = Ms In Electrica
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_005', 'pdf_0451_eel4930renewable-energy::chunk_002'}
#   BM25-only: {'pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet::chunk_002', 'pdf_0498_ms-in-eel-worksheet::chunk_005', 'pdf_0459_eel6291smart-grid::chunk_003'}
#   Dense-only: {'pdf_0459_eel6291smart-grid::chunk_001', 'course_0127_EEL_6468::chunk_001', 'course_0126_EEL_6297::chunk_001'}
#
# ================================================================================
# Query q13: "Find computer architecture, digital logic, microprocessor, embedded systems, VLSI, and computer design course syllabi."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0328_cda6214structured-vlsi-design::chunk_001 (26.03) Document_Type = course_syllabus, Title = Cda6214Structured V | #1 pdf_0328_cda6214structured-vlsi-design::chunk_001 (0.6924) Document_Type = course_syllabus, Title = Cda6214Structured V
# #2 pdf_0322_cda4204cad-based-computer-design::chunk_001 (20.70) Document_Type = course_syllabus, Title = Cda4204Cad Based Co | #2 pdf_0323_cda4210intro-vlsi-design::chunk_002 (0.6900) Document_Type = course_syllabus, Title = Cda4210Intro Vlsi D
# #3 pdf_0488_ms-computer-engineering-with-minor-in-business-worksheet::chunk_001 (18.95) Document_Type = program_form_or_worksheet, Title = Ms Comput | #3 pdf_0323_cda4210intro-vlsi-design::chunk_001 (0.6840) Document_Type = course_syllabus, Title = Cda4210Intro Vlsi D
# #4 pdf_0319_cda3201c-intro-logic-design::chunk_001 (18.60) Document_Type = course_syllabus, Title = Cda3201C Intro Logi | #4 course_0158_CDA_4210::chunk_001 (0.6760) Document_Type = course_listing, Title = Introduction to VLSI
# #5 pdf_0319_cda3201c-intro-logic-design::chunk_002 (18.01) Document_Type = course_syllabus, Title = Cda3201C Intro Logi | #5 pdf_0322_cda4204cad-based-computer-design::chunk_001 (0.6749) Document_Type = course_syllabus, Title = Cda4204Cad Based Co
#
# Overlap: 2 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0322_cda4204cad-based-computer-design::chunk_001', 'pdf_0328_cda6214structured-vlsi-design::chunk_001'}
#   BM25-only: {'pdf_0488_ms-computer-engineering-with-minor-in-business-worksheet::chunk_001', 'pdf_0319_cda3201c-intro-logic-design::chunk_001', 'pdf_0319_cda3201c-intro-logic-design::chunk_002'}
#   Dense-only: {'course_0158_CDA_4210::chunk_001', 'pdf_0323_cda4210intro-vlsi-design::chunk_001', 'pdf_0323_cda4210intro-vlsi-design::chunk_002'}
#
# ================================================================================
# Query q14: "Find general EECS student forms and administrative documents such as audit forms, application forms, graduate pathway scholarships, low residency PhD forms, and conflict of interest disclosure forms."
# ================================================================================
#
# BM25 Results                             | Dense Retrieval Results
# ---------------------------------------- | ----------------------------------------
# #1 pdf_0411_eecs-low-residency-phd-form::chunk_001 (47.77) Document_Type = program_form_or_worksheet, Title = Eecs Low  | #1 pdf_0410_eecs-eac-conflict-of-interest::chunk_002 (0.7055) Document_Type = department_document, Title = Eecs Eac Confli
# #2 pdf_0293_bsphd-grad-pathway-scholarship-application::chunk_001 (40.22) Document_Type = program_form_or_worksheet, Title = Bsphd Gra | #2 pdf_0410_eecs-eac-conflict-of-interest::chunk_001 (0.7002) Document_Type = department_document, Title = Eecs Eac Confli
# #3 pdf_0479_grad-pathway-scholarship-application::chunk_001 (37.71) Document_Type = program_form_or_worksheet, Title = Grad Path | #3 pdf_0493_ms-egit-csec-worksheet::chunk_006 (0.6593) Document_Type = program_form_or_worksheet, Title = Ms Egit C
# #4 pdf_0478_grad-pathway-scholarship-application-revised::chunk_001 (37.53) Document_Type = program_form_or_worksheet, Title = Grad Path | #4 pdf_0491_ms-egit-ait-worksheet::chunk_006 (0.6557) Document_Type = program_form_or_worksheet, Title = Ms Egit A
# #5 pdf_0410_eecs-eac-conflict-of-interest::chunk_002 (35.20) Document_Type = department_document, Title = Eecs Eac Confli | #5 pdf_0487_ms--dsa--worksheet::chunk_009 (0.6516) Document_Type = program_form_or_worksheet, Title = Ms Dsa Wo
#
# Overlap: 1 / 5 docs appear in both top-5
#   Shared docs: {'pdf_0410_eecs-eac-conflict-of-interest::chunk_002'}
#   BM25-only: {'pdf_0411_eecs-low-residency-phd-form::chunk_001', 'pdf_0479_grad-pathway-scholarship-application::chunk_001', 'pdf_0478_grad-pathway-scholarship-application-revised::chunk_001', 'pdf_0293_bsphd-grad-pathway-scholarship-application::chunk_001'}
#   Dense-only: {'pdf_0487_ms--dsa--worksheet::chunk_009', 'pdf_0410_eecs-eac-conflict-of-interest::chunk_001', 'pdf_0493_ms-egit-csec-worksheet::chunk_006', 'pdf_0491_ms-egit-ait-worksheet::chunk_006'}

# %%
#bm25_weight= 2.5, dense_weight= 0.3
def rrf_process(bm25_df, dense_df, k=60, bm25_weight= 2.6, dense_weight= 0.25):
    fused_results = []

    bm_ids = set(bm25_df["query_id"])
    dense_ids = set(dense_df["query_id"])
    query_ids = sorted(bm_ids.union(dense_ids))

    for qid in query_ids:
        rrf_scores = {}

        bm25_q = bm25_df[bm25_df["query_id"] == qid]
        dense_q = dense_df[dense_df["query_id"] == qid]

        # BM25 contribution
        for _, row in bm25_q.iterrows():
            doc_id = row["doc_id"]
            rank = int(row["rank"])
            rrf_scores[doc_id] = rrf_scores.get(doc_id, 0.0) + (
                bm25_weight / (k + rank)
            )

        # Dense contribution
        for _, row in dense_q.iterrows():
            doc_id = row["doc_id"]
            rank = int(row["rank"])
            rrf_scores[doc_id] = rrf_scores.get(doc_id, 0.0) + (
                dense_weight / (k + rank)
            )

        ranked_docs = sorted(rrf_scores.items(), key=lambda x: x[1], reverse=True)

        for final_rank, (doc_id, score) in enumerate(ranked_docs, start=1):
            fused_results.append({
                "query_id": qid,
                "doc_id": doc_id,
                "rrf_score": round(score, 6),
                "rank": final_rank
            })

    fused_df = pd.DataFrame(fused_results)
    return fused_df

# %%
def preprocess_text(text):
    words = re.findall(r"[A-Za-z0-9]+", str(text).lower())
    
    cleaned_words = [
        stemmer.stem(word)
        for word in words
        if word not in stop_words and len(word) > 1
    ]
    
    return set(cleaned_words)


def simple_word_match_percent(query_text, doc_text):
    query_words = preprocess_text(query_text)
    doc_words = preprocess_text(doc_text)

    if not query_words:
        return 0.0

    overlap = query_words.intersection(doc_words)
    return (len(overlap) / len(query_words)) * 100


def semantic_similarity_score(query_text, doc_text, embedding_model):
    embeddings = embedding_model.encode(
        [str(query_text), str(doc_text)],
        normalize_embeddings=True,
        convert_to_numpy=True
    )

    query_vec = embeddings[0]
    doc_vec = embeddings[1]

    cosine_sim = float(np.dot(query_vec, doc_vec))
    cs = round(cosine_sim, 2)
    return cs

# %%
SUMMARY_MODEL_NAME = "google/flan-t5-small"

print(f"Loading summarization model: {SUMMARY_MODEL_NAME}")
summary_tokenizer = AutoTokenizer.from_pretrained(SUMMARY_MODEL_NAME)
summary_model = AutoModelForSeq2SeqLM.from_pretrained(SUMMARY_MODEL_NAME)
print("Summarization model loaded.")

# Lookup tables for retrieval_id -> chunk text and metadata
active_corpus_df = active_corpus_df.fillna("")
doc_lookup = dict(zip(active_corpus_df["doc_id"], active_corpus_df["text"].astype(str)))
metadata_lookup = active_corpus_df.set_index("doc_id").to_dict(orient="index")

FIELD_NAMES = [
    "Document_Type",
    "Title",
    "Course_Code",
    "Prefix",
    "Number",
    "Level",
    "Source_Page",
    "Linked_File_or_Page",
    "File_Name",
    "Content"
]


def field_to_pattern(field_name):
    """
    Allow matching labels written with underscores or spaces.
    Example: Course_Code or Course Code
    """
    return re.escape(field_name).replace(r"\_", r"[ _]+")


def extract_structured_fields(doc_text):
    """
    Extract the labeled metadata fields from one department corpus document.
    """
    text = " ".join(str(doc_text).replace("\n", " ").split())
    extracted = {}

    for i, field in enumerate(FIELD_NAMES):
        current_label = field_to_pattern(field)

        if i < len(FIELD_NAMES) - 1:
            next_labels = [field_to_pattern(f) for f in FIELD_NAMES[i + 1:]]
            next_label_pattern = "|".join(next_labels)
            pattern = rf"{current_label}\s*=\s*(.*?)(?=,\s*(?:{next_label_pattern})\s*=|$)"
        else:
            pattern = rf"{current_label}\s*=\s*(.*)$"

        match = re.search(pattern, text, flags=re.IGNORECASE)
        extracted[field] = match.group(1).strip(" ,") if match else "Not found"

    return extracted


def summarize_document(query_text, doc_text, tokenizer, summary_model, embedding_model, doc_id=None):
    doc_text = str(doc_text).strip()

    empty_result = {
        "Document Type": "Not found",
        "Title": "Not found",
        "Course Code": "Not found",
        "Level": "Not found",
        "File Name": "Not found",
        "Source": "Not found",
        "Word Match %": 0.0,
        "Semantic Similarity": 0.0,
        "Content Summary": "No department document content available."
    }

    if not doc_text:
        return empty_result

    extracted = extract_structured_fields(doc_text)
    content_text = extracted.get("Content", "")
    if not content_text or content_text == "Not found":
        content_text = doc_text

    word_match = simple_word_match_percent(query_text, doc_text)
    semantic_sim = semantic_similarity_score(query_text, doc_text, embedding_model)

    prompt = f"""
Summarize this Computer Science and Electrical Engineering department document in 1 to 2 sentences.

Requirements:
- Focus on forms, worksheets, certificates, degree requirements, course syllabi, prerequisites, course topics, or program information.
- Explain why the document may be relevant to the query.
- Do not use healthcare or patient language.

Metadata:
Document Type = {extracted['Document_Type']}
Title = {extracted['Title']}
Course Code = {extracted['Course_Code']}
Level = {extracted['Level']}
File Name = {extracted['File_Name']}

Query:
{query_text}

Document content:
{content_text[:2500]}
"""

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=512
    )

    outputs = summary_model.generate(
        **inputs,
        max_new_tokens=90,
        do_sample=False
    )

    content_summary = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()
    if not content_summary:
        content_summary = "No concise summary was generated for this document."

    source_value = extracted["Linked_File_or_Page"]
    if source_value == "Not found" or not source_value:
        source_value = extracted["Source_Page"]

    return {
        "Document Type": extracted["Document_Type"],
        "Title": extracted["Title"],
        "Course Code": extracted["Course_Code"],
        "Level": extracted["Level"],
        "File Name": extracted["File_Name"],
        "Source": source_value if source_value else "Not found",
        "Word Match %": round(word_match, 2),
        "Semantic Similarity": round(semantic_sim, 4),
        "Content Summary": content_summary
    }
# Out:
# Loading summarization model: google/flan-t5-small
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Summarization model loaded.

# %%
run_rrf_df = rrf_process(run_bm25_df, run_dense_df, k=60)

# Save fused results
run_rrf_df.to_csv("outputs/run_rrf.csv", index=False)

# Print top 5 per query with summaries
for qid in run_rrf_df["query_id"].unique():
    print(f"\n{'='*80}")
    print(f"RRF Results for Query {qid}")
    print(f"{'='*80}")

    query_matches = queries_df.loc[queries_df["query_id"] == qid, "query_text"]
    if query_matches.empty:
        print(f"No query text found for {qid}")
        continue

    query_text = query_matches.iloc[0]
    top_5 = run_rrf_df[run_rrf_df["query_id"] == qid].head(5)

    for _, row in top_5.iterrows():
        doc_id = row["doc_id"]
        doc_text = doc_lookup.get(doc_id, "")

        doc_summary = summarize_document(
            query_text=query_text,
            doc_text=doc_text,
            tokenizer=summary_tokenizer,
            summary_model=summary_model,
            embedding_model=model,
            doc_id=doc_id
        )

        print(
            f"Rank #{row['rank']:>2} | "
            f"Doc: {doc_id} | "
            f"RRF Score: {row['rrf_score']:.6f}"
        )
        print(f"Title: {doc_summary['Title']}")
        print(f"Type: {doc_summary['Document Type']} | Course: {doc_summary['Course Code']} | Level: {doc_summary['Level']}")
        print(f"Word Match: {doc_summary['Word Match %']}% | Semantic Similarity: {doc_summary['Semantic Similarity']}")
        print(f"Summary: {doc_summary['Content Summary']}")
        print("-" * 80)
# Out:
# ================================================================================
# RRF Results for Query q01
# ================================================================================
# Rank # 1 | Doc: pdf_0511_professional-ai-certificate-program-application::chunk_001 | RRF Score: 0.046721
# Title: Professional Ai Certificate Program Application
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0511_professional-ai-certificate-program-application, Chunk_Index = 1 of 1
# Word Match: 84.62% | Semantic Similarity: 0.72
# Summary: Applicants for the Artificial Intelligence Certificate Program must submit a cover letter to the program.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0512_professional-certificate-ai-worksheet::chunk_001 | RRF Score: 0.045782
# Title: Professional Certificate Ai Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0512_professional-certificate-ai-worksheet, Chunk_Index = 1 of 1
# Word Match: 76.92% | Semantic Similarity: 0.71
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001 | RRF Score: 0.044791
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0343_certificate-artificial-intelligence-program-worksheet, Chunk_Index = 1 of 3
# Word Match: 76.92% | Semantic Similarity: 0.7
# Summary: Obtain the necessary information about the program.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001 | RRF Score: 0.044196
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0342_certificate-artificial-intelligence--program-worksheet, Chunk_Index = 1 of 3
# Word Match: 76.92% | Semantic Similarity: 0.7
# Summary: Obtain the necessary information about the program.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001 | RRF Score: 0.042941
# Title: Artificial Inteligence Minor Worksheet Jan6
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0279_artificial-inteligence-minor-worksheet-jan6, Chunk_Index = 1 of 3
# Word Match: 76.92% | Semantic Similarity: 0.65
# Summary: 01.06.21 Minor in Artificial Intelligence Program Advising Sheet (minimum 15 credits) Name: 01.06.21 Minor in Artificial Intelligence Program Advising Sheet (minimum 15 credits) Name: 01.06.21 Minor in Artificial Intelligence Program Advising Sheet (minimum 15 credits) Name: 01.06.21 Minor in Artificial Intelligence Program Advising Sheet (minim
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q02
# ================================================================================
# Rank # 1 | Doc: pdf_0282_artificial-intelligence-minor-program-application-jan6::chunk_001 | RRF Score: 0.046721
# Title: Artificial Intelligence Minor Program Application Jan6
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0282_artificial-intelligence-minor-program-application-jan6, Chunk_Index = 1 of 2
# Word Match: 91.67% | Semantic Similarity: 0.78
# Summary: Applicants must be currently pursuing an undergraduate program at FAU. The minor requires five courses which have not been counted in any other minor or certificate within the College of Engineering and Computer Science. Students must satisfy the prerequisites for each course in the program. All five courses must be completed with a grade of "C" or better.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0482_minor--artificial-intelligence-application::chunk_001 | RRF Score: 0.045968
# Title: Minor Artificial Intelligence Application
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0482_minor--artificial-intelligence-application, Chunk_Index = 1 of 1
# Word Match: 91.67% | Semantic Similarity: 0.76
# Summary: Applicants must be pursuing a graduate program at FAU. The minor requires four courses which have not been counted in any other minor or certificate within the College of Engineering and Computer Science. Students cannot apply for both Minor in AI and the Certificate in AI. Students must satisfy the prerequisites for each course in the program. The average GPA of all four courses counted in the program must be 3.0 or better.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_001 | RRF Score: 0.045176
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0342_certificate-artificial-intelligence--program-worksheet, Chunk_Index = 1 of 3
# Word Match: 91.67% | Semantic Similarity: 0.73
# Summary: Obtain a Master's Degree in Artificial Intelligence Program.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0279_artificial-inteligence-minor-worksheet-jan6::chunk_001 | RRF Score: 0.044593
# Title: Artificial Inteligence Minor Worksheet Jan6
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0279_artificial-inteligence-minor-worksheet-jan6, Chunk_Index = 1 of 3
# Word Match: 91.67% | Semantic Similarity: 0.74
# Summary: 01.06.21 Minor in Artificial Intelligence Program Advising Sheet (minimum 15 credits) Name: _________________________________________________________________
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_001 | RRF Score: 0.043846
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0343_certificate-artificial-intelligence-program-worksheet, Chunk_Index = 1 of 3
# Word Match: 91.67% | Semantic Similarity: 0.73
# Summary: Obtain the necessary information about the AI minor program.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q03
# ================================================================================
# Rank # 1 | Doc: pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001 | RRF Score: 0.046529
# Title: Professional Certificate Big Data Analytics Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0514_professional-certificate-big-data-analytics-worksheet, Chunk_Index = 1 of 1
# Word Match: 83.33% | Semantic Similarity: 0.71
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0513_professional-certificate-big-data-analytics-application::chunk_001 | RRF Score: 0.046034
# Title: Professional Certificate Big Data Analytics Application
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0513_professional-certificate-big-data-analytics-application, Chunk_Index = 1 of 1
# Word Match: 91.67% | Semantic Similarity: 0.73
# Summary: Applicants for the Big Data Analytics Certificate Program must complete a GPA of 3.0 or better.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0344_certificate-big-data-analytics-application::chunk_001 | RRF Score: 0.045238
# Title: Certificate Big Data Analytics Application
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0344_certificate-big-data-analytics-application, Chunk_Index = 1 of 1
# Word Match: 75.0% | Semantic Similarity: 0.71
# Summary: Applicants for big data analytics certificate are required to complete the application.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001 | RRF Score: 0.044657
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0283_big-data-analytics-cert-program-worksheet, Chunk_Index = 1 of 2
# Word Match: 58.33% | Semantic Similarity: 0.71
# Summary: CS Data Analytics Courses
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002 | RRF Score: 0.043846
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0283_big-data-analytics-cert-program-worksheet, Chunk_Index = 2 of 2
# Word Match: 58.33% | Semantic Similarity: 0.7
# Summary: Date: September
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q04
# ================================================================================
# Rank # 1 | Doc: pdf_0490_ms-cse-worksheet-new::chunk_006 | RRF Score: 0.046194
# Title: Ms Cse Worksheet New
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0490_ms-cse-worksheet-new, Chunk_Index = 6 of 6
# Word Match: 66.67% | Semantic Similarity: 0.72
# Summary: Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0490_ms-cse-worksheet-new::chunk_001 | RRF Score: 0.046034
# Title: Ms Cse Worksheet New
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0490_ms-cse-worksheet-new, Chunk_Index = 1 of 6
# Word Match: 75.0% | Semantic Similarity: 0.74
# Summary: Complete the required POS.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0518_professional-ms-cs-worksheet::chunk_001 | RRF Score: 0.045302
# Title: Professional Ms Cs Worksheet
# Type: program_form_or_worksheet | Course: COT 5930 | Level: graduate, Parent_Doc_ID = pdf_0518_professional-ms-cs-worksheet, Chunk_Index = 1 of 2
# Word Match: 83.33% | Semantic Similarity: 0.74
# Summary: Applicants must have a GPA of 3.0 (out of 4.0) or better.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0490_ms-cse-worksheet-new::chunk_002 | RRF Score: 0.043750
# Title: Ms Cse Worksheet New
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0490_ms-cse-worksheet-new, Chunk_Index = 2 of 6
# Word Match: 75.0% | Semantic Similarity: 0.7
# Summary: BSCI Programs and Programs
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0490_ms-cse-worksheet-new::chunk_003 | RRF Score: 0.043247
# Title: Ms Cse Worksheet New
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0490_ms-cse-worksheet-new, Chunk_Index = 3 of 6
# Word Match: 75.0% | Semantic Similarity: 0.71
# Summary: Complete the required coursework.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q05
# ================================================================================
# Rank # 1 | Doc: pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_001 | RRF Score: 0.046721
# Title: Ms In Computer Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0495_ms-in-computer-engineering-program-sheet-6-2025, Chunk_Index = 1 of 6
# Word Match: 75.0% | Semantic Similarity: 0.74
# Summary: Complete the required POS. 6-2025 M.S. in Computer Engineering Program Worksheet. Complete the required POS. 6-2025 M.S. in Computer Engineering Program Worksheet. Complete the required POS. 6-2025 M.S. in Computer Engineering Program Worksheet. Complete the required POS. 6-2025 M.S. in Computer Engineering Program Worksheet. Complete the required POS. 6-2025 M
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0486_ms--coen-worksheet::chunk_006 | RRF Score: 0.045723
# Title: Ms Coen Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0486_ms--coen-worksheet, Chunk_Index = 6 of 6
# Word Match: 75.0% | Semantic Similarity: 0.71
# Summary: Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0486_ms--coen-worksheet::chunk_001 | RRF Score: 0.045302
# Title: Ms Coen Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0486_ms--coen-worksheet, Chunk_Index = 1 of 6
# Word Match: 75.0% | Semantic Similarity: 0.74
# Summary: Complete the required coursework.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0495_ms-in-computer-engineering-program-sheet-6-2025::chunk_006 | RRF Score: 0.044593
# Title: Ms In Computer Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0495_ms-in-computer-engineering-program-sheet-6-2025, Chunk_Index = 6 of 6
# Word Match: 66.67% | Semantic Similarity: 0.71
# Summary: Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses. Search for EECS Department Graduate Courses.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0486_ms--coen-worksheet::chunk_004 | RRF Score: 0.043521
# Title: Ms Coen Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0486_ms--coen-worksheet, Chunk_Index = 4 of 6
# Word Match: 75.0% | Semantic Similarity: 0.7
# Summary: Obtain the MS Computer Engineering program sheet and MS COEN worksheets.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q06
# ================================================================================
# Rank # 1 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_003 | RRF Score: 0.046529
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025, Chunk_Index = 3 of 8
# Word Match: 83.33% | Semantic Similarity: 0.73
# Summary: BS/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE/EE
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_001 | RRF Score: 0.046034
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025, Chunk_Index = 1 of 8
# Word Match: 83.33% | Semantic Similarity: 0.75
# Summary: Complete the required POS. 1/2025 M.S. in Electrical Engineering Program Worksheet (30 credit hours total) Degree Requirements Students can choose between thesis and non-thesis options. Both options require a minimum of 30 credit hours (crs) Regardless of the option chosen, all students must complete the following requirements: • Complete CGS 5937 Graduate Seminar course (zero crs). • Complete a
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_008 | RRF Score: 0.044841
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025, Chunk_Index = 8 of 8
# Word Match: 75.0% | Semantic Similarity: 0.71
# Summary: Search for EECS Department Graduate Courses. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci. Search for Electrical Engin & Computer Sci.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_006 | RRF Score: 0.044050
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025, Chunk_Index = 6 of 8
# Word Match: 83.33% | Semantic Similarity: 0.71
# Summary: Review the program worksheets.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_004 | RRF Score: 0.043846
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025, Chunk_Index = 4 of 8
# Word Match: 83.33% | Semantic Similarity: 0.72
# Summary: Obtain the required information for your degree.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q07
# ================================================================================
# Rank # 1 | Doc: pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_001 | RRF Score: 0.046411
# Title: Cybersecurity Certificate Worksheet 2023
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0405_cybersecurity-certificate-worksheet-2023, Chunk_Index = 1 of 2
# Word Match: 78.57% | Semantic Similarity: 0.71
# Summary: CS Core Course Title Credits Semester Grade CNT 4403 Foundations of Cybersecurity 3 CS Elective Courses Course Title Credits Semester Grade CAP 4623 Trustworthy Artificial Intelligence 3 CDA 4321 Introduction to Cryptographic Engineering 3 CIS 4213 Cyber Physical Systems Security 3 CIS 4634 Applied Cryptography and Security 3 COP 4665 Mobile Applications 3 COP 4808 Full Stack Web Development 3
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0403_cyber-security-cert-program-worksheet::chunk_001 | RRF Score: 0.045842
# Title: Cyber Security Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0403_cyber-security-cert-program-worksheet, Chunk_Index = 1 of 1
# Word Match: 64.29% | Semantic Similarity: 0.72
# Summary: Date: Summer 2025
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0407_cybersecurity-minor-worksheet::chunk_001 | RRF Score: 0.045116
# Title: Cybersecurity Minor Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0407_cybersecurity-minor-worksheet, Chunk_Index = 1 of 2
# Word Match: 78.57% | Semantic Similarity: 0.72
# Summary: CS Core Course Title Credits Semester Grade CNT 4403 Foundations of Cybersecurity 3 CS Elective Courses – List updated periodically; see advisor for the current list Course Title Credits Semester Grade CAP 4623 Trustworthy Artificial Intelligence 3 CDA 4321 Introduction to Cryptographic Engineering 3 CIS 4213 Cyber Physical Systems Security 3 CIS 4367 Operating Systems Security 3 CIS 4634 Applied Cryptography
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0405_cybersecurity-certificate-worksheet-2023::chunk_002 | RRF Score: 0.044657
# Title: Cybersecurity Certificate Worksheet 2023
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0405_cybersecurity-certificate-worksheet-2023, Chunk_Index = 2 of 2
# Word Match: 57.14% | Semantic Similarity: 0.73
# Summary: Date:
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0407_cybersecurity-minor-worksheet::chunk_002 | RRF Score: 0.044098
# Title: Cybersecurity Minor Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0407_cybersecurity-minor-worksheet, Chunk_Index = 2 of 2
# Word Match: 57.14% | Semantic Similarity: 0.74
# Summary: Date: October 1
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q08
# ================================================================================
# Rank # 1 | Doc: pdf_0514_professional-certificate-big-data-analytics-worksheet::chunk_001 | RRF Score: 0.046246
# Title: Professional Certificate Big Data Analytics Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0514_professional-certificate-big-data-analytics-worksheet, Chunk_Index = 1 of 1
# Word Match: 73.33% | Semantic Similarity: 0.7
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0277_4-plus-1-itm-csda::chunk_001 | RRF Score: 0.044683
# Title: 4 Plus 1 Itm Csda
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0277_4-plus-1-itm-csda, Chunk_Index = 1 of 2
# Word Match: 60.0% | Semantic Similarity: 0.67
# Summary: Obtain the required degree from the Wilkes Honors College (WHC) and then receive their bachelor's degree from the Wilkes Honors College (WHC)
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0487_ms--dsa--worksheet::chunk_001 | RRF Score: 0.044098
# Title: Ms Dsa Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0487_ms--dsa--worksheet, Chunk_Index = 1 of 9
# Word Match: 73.33% | Semantic Similarity: 0.72
# Summary: Obtain a degree program.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0277_4-plus-1-itm-csda::chunk_002 | RRF Score: 0.043628
# Title: 4 Plus 1 Itm Csda
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0277_4-plus-1-itm-csda, Chunk_Index = 2 of 2
# Word Match: 60.0% | Semantic Similarity: 0.65
# Summary: Obtain the required data science and analytics certificate documents.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0501_ms-in-information-technology-management-computer-science-dat::chunk_001 | RRF Score: 0.043403
# Title: Ms In Information Technology Management Computer Science Data Analytics Program Sheet 6 2025
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0501_ms-in-information-technology-management-computer-science-dat, Chunk_Index = 1 of 6
# Word Match: 80.0% | Semantic Similarity: 0.67
# Summary: Obtain a Thesis
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q09
# ================================================================================
# Rank # 1 | Doc: pdf_0342_certificate-artificial-intelligence--program-worksheet::chunk_003 | RRF Score: 0.046529
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0342_certificate-artificial-intelligence--program-worksheet, Chunk_Index = 3 of 3
# Word Match: 76.92% | Semantic Similarity: 0.66
# Summary: Identify the requirements for the CAP and CAP.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0343_certificate-artificial-intelligence-program-worksheet::chunk_003 | RRF Score: 0.045904
# Title: Certificate Artificial Intelligence Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0343_certificate-artificial-intelligence-program-worksheet, Chunk_Index = 3 of 3
# Word Match: 76.92% | Semantic Similarity: 0.66
# Summary: Identify the courses that are required for the course.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0300_cap5615intro-neural-networks::chunk_002 | RRF Score: 0.045001
# Title: Cap5615Intro Neural Networks
# Type: course_syllabus | Course: CAP 5615 | Level: graduate, Parent_Doc_ID = pdf_0300_cap5615intro-neural-networks, Chunk_Index = 2 of 2
# Word Match: 61.54% | Semantic Similarity: 0.65
# Summary: 1. Introduction to Machine Learning 2. Deep learning 3. Deep learning 4. Single Layer Perceptrons 5. Multilayer Perceptrons 6. Radial-Basis Function Networks 7. Support Vector Machines 8. Deep learning
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0509_newcertificate-artificial-intelligence-worksheet::chunk_003 | RRF Score: 0.044003
# Title: Newcertificate Artificial Intelligence Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0509_newcertificate-artificial-intelligence-worksheet, Chunk_Index = 3 of 3
# Word Match: 76.92% | Semantic Similarity: 0.63
# Summary: Date: October 1
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0280_artificial-intelligence-cert-program-worksheet::chunk_003 | RRF Score: 0.043521
# Title: Artificial Intelligence Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0280_artificial-intelligence-cert-program-worksheet, Chunk_Index = 3 of 3
# Word Match: 76.92% | Semantic Similarity: 0.64
# Summary: Date: October 1
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q10
# ================================================================================
# Rank # 1 | Doc: pdf_0317_cap6780big-data-analytics::chunk_001 | RRF Score: 0.045302
# Title: Cap6780Big Data Analytics
# Type: course_syllabus | Course: CAP 6780 | Level: graduate, Parent_Doc_ID = pdf_0317_cap6780big-data-analytics, Chunk_Index = 1 of 1
# Word Match: 75.0% | Semantic Similarity: 0.67
# Summary: 1. Data Mining and Machine Learning 2. Hadoop tools for data mining and machine learning 3. Big Data 4. Big Data challenges 5. High dimensionality 6. High Dimensionality 7. Feature Selection 8. Big Data 9. Big Data 10. Ensemble Learning 11. Big Data and the Hadoop ecosystem 12. Case Studies
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet::chunk_001 | RRF Score: 0.045148
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0283_big-data-analytics-cert-program-worksheet, Chunk_Index = 1 of 2
# Word Match: 75.0% | Semantic Similarity: 0.62
# Summary: CS Data Analytics Courses(9 credits): Ch oose three courses from the list below.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0487_ms--dsa--worksheet::chunk_005 | RRF Score: 0.045022
# Title: Ms Dsa Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0487_ms--dsa--worksheet, Chunk_Index = 5 of 9
# Word Match: 75.0% | Semantic Similarity: 0.64
# Summary: Identify the requirements for a database-related program.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025::chunk_004 | RRF Score: 0.043257
# Title: Ms In Data Science Analytics Program Worksheet 6 2025
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0497_ms-in-data-science-analytics-program-worksheet-6-2025, Chunk_Index = 4 of 8
# Word Match: 66.67% | Semantic Similarity: 0.62
# Summary: Obtain a program for your program.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0283_big-data-analytics-cert-program-worksheet::chunk_002 | RRF Score: 0.042941
# Title: Big Data Analytics Cert Program Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0283_big-data-analytics-cert-program-worksheet, Chunk_Index = 2 of 2
# Word Match: 58.33% | Semantic Similarity: 0.63
# Summary: Date: September
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q11
# ================================================================================
# Rank # 1 | Doc: pdf_0336_cen6027sw-maint-evolution::chunk_002 | RRF Score: 0.045255
# Title: Cen6027Sw Maint Evolution
# Type: course_syllabus | Course: CEN 6027 | Level: graduate, Parent_Doc_ID = pdf_0336_cen6027sw-maint-evolution, Chunk_Index = 2 of 2
# Word Match: 69.23% | Semantic Similarity: 0.62
# Summary: Software Engineering courses and syllabi covering software requirements engineering, software testing, software architecture, software maintenance, and object-oriented design
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0488_ms-computer-engineering-with-minor-in-business-worksheet::chunk_002 | RRF Score: 0.044188
# Title: Ms Computer Engineering With Minor In Business Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0488_ms-computer-engineering-with-minor-in-business-worksheet, Chunk_Index = 2 of 4
# Word Match: 76.92% | Semantic Similarity: 0.61
# Summary: Identify the requirements for software engineering and software maintenance.
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0338_cen6076sw-testing::chunk_001 | RRF Score: 0.043790
# Title: Cen6076Sw Testing
# Type: course_syllabus | Course: CEN 6076 | Level: graduate, Parent_Doc_ID = pdf_0338_cen6076sw-testing, Chunk_Index = 1 of 1
# Word Match: 61.54% | Semantic Similarity: 0.64
# Summary: CS and CE graduate programs
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0336_cen6027sw-maint-evolution::chunk_001 | RRF Score: 0.043721
# Title: Cen6027Sw Maint Evolution
# Type: course_syllabus | Course: CEN 6027 | Level: graduate, Parent_Doc_ID = pdf_0336_cen6027sw-maint-evolution, Chunk_Index = 1 of 2
# Word Match: 61.54% | Semantic Similarity: 0.62
# Summary: syllabi
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0374_cop4331object-oriented-design::chunk_002 | RRF Score: 0.042976
# Title: Cop4331Object Oriented Design
# Type: course_syllabus | Course: COP 4331 | Level: undergraduate, Parent_Doc_ID = pdf_0374_cop4331object-oriented-design, Chunk_Index = 2 of 2
# Word Match: 69.23% | Semantic Similarity: 0.64
# Summary: • Introduction to Java • Object Oriented Design Process • Class Design • Interfaces and Polymorphism • Patterns and GUI Programming • Inheritance and Abstract Classes • The Java Object Model • Frameworks • Multithreading
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q12
# ================================================================================
# Rank # 1 | Doc: pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025::chunk_005 | RRF Score: 0.045782
# Title: Ms In Electrical Engineering Program Sheet 6 2025
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0499_ms-in-electrical-engineering-program-sheet-6-2025, Chunk_Index = 5 of 8
# Word Match: 72.22% | Semantic Similarity: 0.66
# Summary: Obtain a phd degree in electrical engineering.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet::chunk_002 | RRF Score: 0.045255
# Title: Ms Electrical Engineering With Minor In Business Worksheet
# Type: program_form_or_worksheet | Course: EEL 3470 | Level: undergraduate, Parent_Doc_ID = pdf_0494_ms-electrical-engineering-with-minor-in-business-worksheet, Chunk_Index = 2 of 4
# Word Match: 72.22% | Semantic Similarity: 0.63
# Summary: ELECTRICAL ENGINEERING GRADUATE COURSES: Grade Semester Course Number/Name CDA 6214 Structured VLSI Design 1 EEE 5321 CMOS Amplifiers EEE 5371 High Frequency Amplifiers 2 7.27.20 EEE 5502 Digital Processing of Signals EEE 5557 Introduction to Radar Systems EEE 6323 RF
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0459_eel6291smart-grid::chunk_003 | RRF Score: 0.044301
# Title: Eel6291Smart Grid
# Type: course_syllabus | Course: EEL 6291 | Level: graduate, Parent_Doc_ID = pdf_0459_eel6291smart-grid, Chunk_Index = 3 of 3
# Word Match: 55.56% | Semantic Similarity: 0.66
# Summary: - Electrical engineering course - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi - syllabi
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0451_eel4930renewable-energy::chunk_002 | RRF Score: 0.043906
# Title: Eel4930Renewable Energy
# Type: course_syllabus | Course: EEL 4930 | Level: undergraduate, Parent_Doc_ID = pdf_0451_eel4930renewable-energy, Chunk_Index = 2 of 2
# Word Match: 61.11% | Semantic Similarity: 0.67
# Summary: Electronics and Electronics Engineering course syllabi
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0498_ms-in-eel-worksheet::chunk_005 | RRF Score: 0.043606
# Title: Ms In Eel Worksheet
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0498_ms-in-eel-worksheet, Chunk_Index = 5 of 8
# Word Match: 72.22% | Semantic Similarity: 0.63
# Summary: eel Graduate Course Numbers Title Semester Taken Grade CDA 6214 Structured VLSI Design 1 EEE 5321 CMOS Amplifiers EEE 5371 High Frequency Amplifiers EEE 5502 Digital Processing of Signals EEE 5557 Introduction to Radar Systems EEE 6323 RF CMOS VLSI Devices for Wireless Communications
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q13
# ================================================================================
# Rank # 1 | Doc: pdf_0328_cda6214structured-vlsi-design::chunk_001 | RRF Score: 0.046721
# Title: Cda6214Structured Vlsi Design
# Type: course_syllabus | Course: CDA 6214 | Level: graduate, Parent_Doc_ID = pdf_0328_cda6214structured-vlsi-design, Chunk_Index = 1 of 1
# Word Match: 75.0% | Semantic Similarity: 0.69
# Summary: To be determined
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0322_cda4204cad-based-computer-design::chunk_001 | RRF Score: 0.045782
# Title: Cda4204Cad Based Computer Design
# Type: course_syllabus | Course: CDA 4204 | Level: undergraduate, Parent_Doc_ID = pdf_0322_cda4204cad-based-computer-design, Chunk_Index = 1 of 2
# Word Match: 75.0% | Semantic Similarity: 0.67
# Summary: CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design Course Code CDA 4204 CAD-based Computer Design
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0319_cda3201c-intro-logic-design::chunk_001 | RRF Score: 0.044050
# Title: Cda3201C Intro Logic Design
# Type: course_syllabus | Course:  | Level: Parent_Doc_ID = pdf_0319_cda3201c-intro-logic-design, Chunk_Index = 1 of 2
# Word Match: 58.33% | Semantic Similarity: 0.64
# Summary: Logic Design: Introduction to Logic Design
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0319_cda3201c-intro-logic-design::chunk_002 | RRF Score: 0.043676
# Title: Cda3201C Intro Logic Design
# Type: course_syllabus | Course:  | Level: Parent_Doc_ID = pdf_0319_cda3201c-intro-logic-design, Chunk_Index = 2 of 2
# Word Match: 58.33% | Semantic Similarity: 0.66
# Summary: Identify the basics of computer architecture and digital logic.
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0323_cda4210intro-vlsi-design::chunk_001 | RRF Score: 0.043362
# Title: Cda4210Intro Vlsi Design
# Type: course_syllabus | Course: CDA 4210 | Level: undergraduate, Parent_Doc_ID = pdf_0323_cda4210intro-vlsi-design, Chunk_Index = 1 of 2
# Word Match: 50.0% | Semantic Similarity: 0.68
# Summary: Describe the course syllabus for the computer science and electrical engineering department.
# --------------------------------------------------------------------------------
#
# ================================================================================
# RRF Results for Query q14
# ================================================================================
# Rank # 1 | Doc: pdf_0411_eecs-low-residency-phd-form::chunk_001 | RRF Score: 0.046095
# Title: Eecs Low Residency Phd Form
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0411_eecs-low-residency-phd-form, Chunk_Index = 1 of 1
# Word Match: 50.0% | Semantic Similarity: 0.63
# Summary: Applicants must be enrolled in the EECS program.
# --------------------------------------------------------------------------------
# Rank # 2 | Doc: pdf_0410_eecs-eac-conflict-of-interest::chunk_002 | RRF Score: 0.044098
# Title: Eecs Eac Conflict Of Interest
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0410_eecs-eac-conflict-of-interest, Chunk_Index = 2 of 2
# Word Match: 27.78% | Semantic Similarity: 0.71
# Summary: EECS Executive Advisory Council
# --------------------------------------------------------------------------------
# Rank # 3 | Doc: pdf_0293_bsphd-grad-pathway-scholarship-application::chunk_001 | RRF Score: 0.043801
# Title: Bsphd Grad Pathway Scholarship Application
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0293_bsphd-grad-pathway-scholarship-application, Chunk_Index = 1 of 1
# Word Match: 44.44% | Semantic Similarity: 0.57
# Summary: Applicants must be enrolled in a combined or advanced standing program.
# --------------------------------------------------------------------------------
# Rank # 4 | Doc: pdf_0479_grad-pathway-scholarship-application::chunk_001 | RRF Score: 0.043697
# Title: Grad Pathway Scholarship Application
# Type: program_form_or_worksheet | Course:  | Level: Parent_Doc_ID = pdf_0479_grad-pathway-scholarship-application, Chunk_Index = 1 of 1
# Word Match: 38.89% | Semantic Similarity: 0.58
# Summary: No
# --------------------------------------------------------------------------------
# Rank # 5 | Doc: pdf_0410_eecs-eac-conflict-of-interest::chunk_001 | RRF Score: 0.043426
# Title: Eecs Eac Conflict Of Interest
# Type: department_document | Course:  | Level: Parent_Doc_ID = pdf_0410_eecs-eac-conflict-of-interest, Chunk_Index = 1 of 2
# Word Match: 27.78% | Semantic Similarity: 0.7
# Summary: ii)
# --------------------------------------------------------------------------------

# %%
qrels_path = SEARCH_REVIEW_DIR / "eecs_qrels.csv"
qrels_available = qrels_path.exists()

if qrels_available:
    qrels_original_df = pd.read_csv(qrels_path).fillna("")
    qrels_df = qrels_original_df.copy()

    # If retrieval is chunked, qrels written for original source documents need to be expanded
    # so evaluation compares retrieved chunk IDs against chunk-level relevance labels.
    if globals().get("RETRIEVAL_IS_CHUNKED", False) and "parent_doc_id" in active_corpus_df.columns:
        chunk_map = active_corpus_df[["doc_id", "parent_doc_id"]].copy()
        chunk_map = chunk_map.rename(columns={"doc_id": "chunk_doc_id"})

        expanded_qrels = qrels_original_df.merge(
            chunk_map,
            left_on="doc_id",
            right_on="parent_doc_id",
            how="inner"
        )

        if not expanded_qrels.empty:
            qrels_df = (
                expanded_qrels[["query_id", "chunk_doc_id", "relevance"]]
                .rename(columns={"chunk_doc_id": "doc_id"})
                .drop_duplicates()
                .reset_index(drop=True)
            )
            print(
                f"Expanded qrels from {len(qrels_original_df)} document-level rows "
                f"to {len(qrels_df)} chunk-level rows for evaluation."
            )
        else:
            print("Warning: qrels could not be expanded to chunk IDs. Metrics may be zero if IDs do not overlap.")
else:
    qrels_original_df = pd.DataFrame(columns=["query_id", "doc_id", "relevance"])
    qrels_df = pd.DataFrame(columns=["query_id", "doc_id", "relevance"])
    print("No search_review/eecs_qrels.csv file was found. Skipping supervised retrieval evaluation metrics.")
    print("Retrieval still works; qrels are only needed for P@K, MAP, and nDCG scoring.")


def precision_at_k(ranked_doc_ids, rel_map, k=10):
    top = ranked_doc_ids[:k]
    if len(top) == 0:
        return 0.0
    hits = sum(1 for d in top if rel_map.get(d, 0) > 0)  # relevance 1 or 2 counts as relevant
    return hits / len(top)

# Build relevance lookup: qid -> {doc_id: relevance}
rel_by_q = {}
if qrels_available:
    for qid, g in qrels_df.groupby("query_id"):
        rel_by_q[str(qid)] = {
            str(r.doc_id): int(r.relevance)
            for r in g.itertuples(index=False)
        }


def evaluate_p10(run_df, run_name, k=10):
    if not qrels_available:
        print(f"Skipping P@{k} for {run_name}; qrels are not available.")
        return 0.0

    p10_values = []

    print(f"\nP@{k} per query ({run_name}):")
    for qid, g in run_df.groupby("query_id"):
        ranked = g.sort_values("rank")["doc_id"].astype(str).tolist()
        p10 = precision_at_k(ranked, rel_by_q.get(str(qid), {}), k=k)
        p10_values.append(p10)
        print(f"{qid}: {p10:.3f}")

    mean_p10 = float(np.mean(p10_values)) if p10_values else 0.0
    print(f"Mean P@{k} for {run_name}: {mean_p10:.3f}")
    return mean_p10

# Evaluate BM25
mean_p10_bm25 = evaluate_p10(run_bm25_df, "BM25", k=10)

# Evaluate FAISS / Dense retrieval
mean_p10_faiss = evaluate_p10(run_dense_df, "FAISS Dense Search", k=10)

# Evaluate RRF
mean_p10_rrf = evaluate_p10(run_rrf_df, "RRF Fusion", k=10)
# Out:
# Expanded qrels from 388 document-level rows to 1058 chunk-level rows for evaluation.
#
# P@10 per query (BM25):
# q01: 0.900
# q02: 1.000
# q03: 0.800
# q04: 0.900
# q05: 0.800
# q06: 1.000
# q07: 1.000
# q08: 1.000
# q09: 0.200
# q10: 0.100
# q11: 0.900
# q12: 0.600
# q13: 0.500
# q14: 1.000
# Mean P@10 for BM25: 0.764
#
# P@10 per query (FAISS Dense Search):
# q01: 1.000
# q02: 1.000
# q03: 0.500
# q04: 0.800
# q05: 1.000
# q06: 1.000
# q07: 1.000
# q08: 1.000
# q09: 0.400
# q10: 0.500
# q11: 1.000
# q12: 0.600
# q13: 0.900
# q14: 1.000
# Mean P@10 for FAISS Dense Search: 0.836
#
# P@10 per query (RRF Fusion):
# q01: 1.000
# q02: 1.000
# q03: 0.800
# q04: 0.900
# q05: 0.800
# q06: 1.000
# q07: 1.000
# q08: 1.000
# q09: 0.200
# q10: 0.100
# q11: 0.900
# q12: 0.600
# q13: 0.500
# q14: 1.000
# Mean P@10 for RRF Fusion: 0.771

# %%
print("\n" + "=" * 50)
print("Mean P@10 Summary")
print("=" * 50)
print(f"BM25:              {mean_p10_bm25:.3f}")
print(f"FAISS Dense:       {mean_p10_faiss:.3f}")
print(f"RRF Fusion:        {mean_p10_rrf:.3f}")
# Out:
# ==================================================
# Mean P@10 Summary
# ==================================================
# BM25:              0.764
# FAISS Dense:       0.836
# RRF Fusion:        0.771

# %%
def average_precision(ranked_doc_ids, rel_map):
    # AP uses binary relevance: treat relevance 1 or 2 as relevant
    total_relevant = sum(1 for v in rel_map.values() if v > 0)
    if total_relevant == 0:
        return 0.0

    hits = 0
    ap_sum = 0.0

    for i, d in enumerate(ranked_doc_ids, start=1):
        if rel_map.get(d, 0) > 0:
            hits += 1
            ap_sum += hits / i

    return ap_sum / total_relevant


def evaluate_map(run_df, run_name):
    if not qrels_available:
        print(f"Skipping MAP for {run_name}; qrels are not available.")
        return 0.0

    ap_values = []

    print(f"\nAverage Precision (AP) per query ({run_name}):")
    for qid, g in run_df.groupby("query_id"):
        ranked = g.sort_values("rank")["doc_id"].astype(str).tolist()
        ap = average_precision(ranked, rel_by_q.get(str(qid), {}))
        ap_values.append(ap)
        print(f"{qid}: {ap:.3f}")

    map_score = float(np.mean(ap_values)) if len(ap_values) > 0 else 0.0
    print(f"\nMAP ({run_name}): {map_score:.3f}")
    return map_score


# ---- BM25 ----
map_bm25 = evaluate_map(run_bm25_df, "BM25")

# ---- FAISS / Dense ----
map_faiss = evaluate_map(run_dense_df, "FAISS Dense Search")

# ---- RRF ----
map_rrf = evaluate_map(run_rrf_df, "RRF Fusion")


print("\n" + "=" * 50)
print("MAP Summary")
print("=" * 50)
print(f"BM25:         {map_bm25:.3f}")
print(f"FAISS Dense:  {map_faiss:.3f}")
print(f"RRF Fusion:   {map_rrf:.3f}")
# Out:
# Average Precision (AP) per query (BM25):
# q01: 0.405
# q02: 0.425
# q03: 1.000
# q04: 0.505
# q05: 0.339
# q06: 0.578
# q07: 0.545
# q08: 0.702
# q09: 0.136
# q10: 0.204
# q11: 0.651
# q12: 0.260
# q13: 0.301
# q14: 0.218
#
# MAP (BM25): 0.448
#
# Average Precision (AP) per query (FAISS Dense Search):
# q01: 0.639
# q02: 0.416
# q03: 0.707
# q04: 0.357
# q05: 0.571
# q06: 0.509
# q07: 0.571
# q08: 0.702
# q09: 0.185
# q10: 0.411
# q11: 0.582
# q12: 0.274
# q13: 0.543
# q14: 0.303
#
# MAP (FAISS Dense Search): 0.484
#
# Average Precision (AP) per query (RRF Fusion):
# q01: 0.512
# q02: 0.509
# q03: 0.975
# q04: 0.580
# q05: 0.404
# q06: 0.656
# q07: 0.637
# q08: 0.777
# q09: 0.164
# q10: 0.250
# q11: 0.703
# q12: 0.345
# q13: 0.380
# q14: 0.324
#
# MAP (RRF Fusion): 0.515
#
# ==================================================
# MAP Summary
# ==================================================
# BM25:         0.448
# FAISS Dense:  0.484
# RRF Fusion:   0.515

# %%
def dcg_at_k(ranked_doc_ids, rel_map, k=10):
    dcg = 0.0
    for i, d in enumerate(ranked_doc_ids[:k], start=1):
        gain = rel_map.get(d, 0)  # graded relevance: 0, 1, 2
        dcg += gain / math.log2(i + 1)
    return dcg


def ndcg_at_k(ranked_doc_ids, rel_map, k=10):
    dcg = dcg_at_k(ranked_doc_ids, rel_map, k)

    # Ideal DCG: sort true relevance scores from highest to lowest
    ideal_gains = sorted(rel_map.values(), reverse=True)
    idcg = 0.0
    for i, gain in enumerate(ideal_gains[:k], start=1):
        idcg += gain / math.log2(i + 1)

    return (dcg / idcg) if idcg > 0 else 0.0


def evaluate_ndcg(run_df, run_name, k=10):
    if not qrels_available:
        print(f"Skipping nDCG@{k} for {run_name}; qrels are not available.")
        return 0.0

    ndcg_values = []

    print(f"\nnDCG@{k} per query ({run_name}):")
    for qid, g in run_df.groupby("query_id"):
        ranked = g.sort_values("rank")["doc_id"].astype(str).tolist()
        ndcg = ndcg_at_k(ranked, rel_by_q.get(str(qid), {}), k=k)
        ndcg_values.append(ndcg)
        print(f"{qid}: {ndcg:.3f}")

    mean_ndcg = float(np.mean(ndcg_values)) if len(ndcg_values) > 0 else 0.0
    print(f"\nMean nDCG@{k} ({run_name}): {mean_ndcg:.3f}")
    return mean_ndcg

# ---- BM25 ----
mean_ndcg_bm25 = evaluate_ndcg(run_bm25_df, "BM25", k=30)

# ---- FAISS / Dense ----
mean_ndcg_faiss = evaluate_ndcg(run_dense_df, "FAISS Dense Search", k=30)

# ---- RRF ----
mean_ndcg_rrf = evaluate_ndcg(run_rrf_df, "RRF Fusion", k=30)

print("\n" + "=" * 50)
print("nDCG@30 Summary")
print("=" * 50)
print(f"BM25:         {mean_ndcg_bm25:.3f}")
print(f"FAISS Dense:  {mean_ndcg_faiss:.3f}")
print(f"RRF Fusion:   {mean_ndcg_rrf:.3f}")
# Out:
# nDCG@30 per query (BM25):
# q01: 0.755
# q02: 0.782
# q03: 1.000
# q04: 0.879
# q05: 0.558
# q06: 1.000
# q07: 0.799
# q08: 0.907
# q09: 0.209
# q10: 0.136
# q11: 0.784
# q12: 0.403
# q13: 0.548
# q14: 0.661
#
# Mean nDCG@30 (BM25): 0.673
#
# nDCG@30 per query (FAISS Dense Search):
# q01: 0.885
# q02: 0.913
# q03: 0.805
# q04: 0.856
# q05: 0.835
# q06: 1.000
# q07: 0.899
# q08: 0.988
# q09: 0.352
# q10: 0.541
# q11: 0.900
# q12: 0.535
# q13: 0.743
# q14: 0.855
#
# Mean nDCG@30 (FAISS Dense Search): 0.793
#
# nDCG@30 per query (RRF Fusion):
# q01: 0.760
# q02: 0.840
# q03: 0.993
# q04: 0.886
# q05: 0.591
# q06: 1.000
# q07: 0.802
# q08: 0.933
# q09: 0.212
# q10: 0.166
# q11: 0.833
# q12: 0.420
# q13: 0.605
# q14: 0.688
#
# Mean nDCG@30 (RRF Fusion): 0.695
#
# ==================================================
# nDCG@30 Summary
# ==================================================
# BM25:         0.673
# FAISS Dense:  0.793
# RRF Fusion:   0.695

# %% [markdown]
# ## Final Interactive Hybrid RAG Loop — Quality-Guarded Version
#
# This final block keeps the retrieval and answer-generation steps separated. The user's original question is preserved for the LLM-facing prompt, while a retrieval-optimized version is used only for BM25 + FAISS + RRF. The retrieved chunks are compressed into query-relevant background facts, inserted into the Hugging Face prompt, and hidden from normal output. Only the final contextualized answer is displayed.
#
# This version also includes answer-quality guards to reduce document-title copying, repeated-token failures, and irrelevant context leakage.

# %%
# ============================================================
# Final Interactive Hybrid RAG Loop - Quality-Guarded Version
# ============================================================
# Intended behavior:
# 1. The user enters an original custom query.
# 2. A retrieval-optimized version of that query is created only for hybrid search.
# 3. BM25 + FAISS dense search retrieve candidate chunks from the chunked index.
# 4. RRF fusion combines the retrieval results.
# 5. The top chunks are reranked and compressed into query-relevant background facts.
# 6. A lightweight Hugging Face LLM answers the original user question using those facts.
# 7. The user sees only the final answer. Retrieved documents are not printed unless debugging is enabled.

# ----------------------------
# RAG settings
# ----------------------------
RAG_TOP_K = 10  # Top retrieval chunks used as hidden context
RAG_RETRIEVAL_POOL = 150
RAG_RRF_K = 60
RAG_BM25_WEIGHT = 2.6
RAG_DENSE_WEIGHT = 0.25

# Smaller context usually improves FLAN-T5 behavior. Long raw PDFs cause copying/repetition.
RAG_MAX_FACT_CHARS = 520
RAG_MAX_TOTAL_CONTEXT_CHARS = 4200
RAG_MAX_INPUT_TOKENS = 1536
RAG_MAX_NEW_TOKENS = 180
RAG_DEBUG = False

# Lightweight answer-generation model.
# BGE-M3 handles retrieval; this model writes the final natural-language answer.
# Recommended default: Qwen2.5-3B-Instruct. It is a stronger lightweight choice
# for RAG answer generation than FLAN-T5-base, while still being practical on many local setups.
# Lower memory options: "Qwen/Qwen2.5-0.5B-Instruct" or "Qwen/Qwen2.5-1.5B-Instruct"
# Alternative lightweight option: "microsoft/Phi-3.5-mini-instruct"
# Legacy seq2seq option: "google/flan-t5-base"
# RAG_MODEL_NAME = globals().get("RAG_MODEL_NAME", "Qwen/Qwen2.5-3B-Instruct")
RAG_MODEL_NAME = globals().get("RAG_MODEL_NAME", "Qwen/Qwen2.5-1.5B-Instruct")

def is_seq2seq_rag_model(model_name):
    name = str(model_name).lower()
    return "t5" in name or "flan" in name


def load_rag_generation_model(model_name):
    print(f"Loading Hugging Face RAG answer model: {model_name}")
    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

    if is_seq2seq_rag_model(model_name):
        model_obj = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)
        model_kind = "seq2seq"
    else:
        model_kwargs = {"trust_remote_code": True}
        if torch.cuda.is_available():
            model_kwargs.update({"device_map": "auto", "torch_dtype": torch.float16})
        else:
            model_kwargs.update({"torch_dtype": torch.float32})
        model_obj = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
        model_kind = "causal"

    if tokenizer.pad_token_id is None and tokenizer.eos_token_id is not None:
        tokenizer.pad_token = tokenizer.eos_token

    if not torch.cuda.is_available():
        model_obj = model_obj.to("cpu")

    model_obj.eval()
    print(f"RAG answer model loaded as: {model_kind}")
    return tokenizer, model_obj, model_kind


rag_tokenizer, rag_model, RAG_MODEL_KIND = load_rag_generation_model(RAG_MODEL_NAME)


# ----------------------------
# Query utilities
# ----------------------------
RAG_STOPWORDS = {
    "a", "an", "and", "are", "as", "at", "be", "by", "can", "could", "do", "does", "for", "from",
    "how", "i", "in", "is", "it", "me", "my", "need", "needed", "of", "on", "or", "should", "the",
    "their", "there", "this", "to", "what", "when", "where", "which", "who", "will", "with", "would", "you",
    "your", "about", "related", "information", "student"
}


def rag_normalize_text(text):
    return " ".join(str(text).replace("\x00", " ").split())


def rag_terms(text):
    words = re.findall(r"[A-Za-z][A-Za-z0-9]+", str(text).lower())
    return [w for w in words if w not in RAG_STOPWORDS and len(w) > 2]


def classify_rag_intent(original_query):
    q = str(original_query).lower()

    if any(term in q for term in ["recommend", "classes", "class", "course", "courses", "take", "fall", "spring", "summer", "senior"]):
        if any(term in q for term in ["recommend", "take", "classes", "class", "courses", "fall", "spring", "summer", "senior"]):
            return "course_recommendation"

    if "certificate" in q or "certification" in q:
        return "certificate_requirements"

    if any(term in q for term in ["credit", "credits", "bachelor", "bachelors", "b.s.", "bs ", "undergraduate degree", "degree requirements"]):
        return "degree_requirements"

    if any(term in q for term in ["chair", "director", "advisor", "coordinator", "dean", "acting chair"]):
        return "person_lookup"

    if any(term in q for term in ["form", "worksheet", "application", "audit", "pos", "plan of study"]):
        return "forms"

    return "general"


EECS_RETRIEVAL_EXPANSIONS_BY_INTENT = {
    "course_recommendation": [
        "course listing", "course offerings", "undergraduate", "senior", "4000", "3000",
        "fall", "CAP", "CDA", "CEN", "CIS", "COP", "COT", "EEL", "EEE",
        "prerequisite", "credits"
    ],
    "certificate_requirements": [
        "certificate", "requirements", "required courses", "credits", "worksheet", "program sheet",
        "application", "big data analytics", "artificial intelligence", "cybersecurity", "data science"
    ],
    "degree_requirements": [
        "degree requirements", "program sheet", "worksheet", "bachelor of science", "BS", "BSEE",
        "undergraduate", "total credits", "required credits", "electrical engineering", "computer science"
    ],
    "person_lookup": [
        "acting chair", "department chair", "chair", "director", "faculty", "computer science engineering electrical engineering"
    ],
    "forms": [
        "form", "forms", "worksheet", "application", "degree audit", "plan of study", "POS", "requirements"
    ],
    "general": [
        "computer science", "electrical engineering", "department", "course", "program", "requirements"
    ]
}

EECS_KEYWORD_EXPANSIONS = {
    "ai": ["artificial intelligence", "machine learning"],
    "artificial intelligence": ["AI", "machine learning"],
    "ml": ["machine learning", "artificial intelligence"],
    "big data": ["big data analytics", "data analytics", "data science"],
    "cyber": ["cybersecurity", "cyber security", "security"],
    "cybersecurity": ["cyber security", "security"],
    "computer science": ["CS", "CSE", "COP", "COT", "CAP", "CEN", "computer science"],
    "computer engineering": ["computer engineering", "CpE", "CDA", "EEE", "EEL"],
    "electrical engineering": ["electrical engineering", "EE", "EEL", "EEE", "BSEE"],
    "bachelors": ["bachelor", "bachelor of science", "BS", "undergraduate", "total credits"],
    "bachelor": ["bachelor of science", "BS", "undergraduate", "total credits"],
    "credits": ["credit hours", "total credits", "required credits"],
    "fall": ["fall semester", "course offerings", "schedule"],
    "senior": ["4000", "3000", "upper division", "undergraduate"],
}


def improve_query_for_hybrid_search(original_query, max_extra_terms=24):
    """
    Expand the query for retrieval only.
    The original query is still used in the LLM-facing prompt.
    """
    original_query = str(original_query).strip()
    lowered = original_query.lower()
    intent = classify_rag_intent(original_query)

    extra_terms = []

    for term in EECS_RETRIEVAL_EXPANSIONS_BY_INTENT.get(intent, []):
        if term.lower() not in lowered and term not in extra_terms:
            extra_terms.append(term)

    for trigger, expansions in EECS_KEYWORD_EXPANSIONS.items():
        if trigger in lowered:
            for term in expansions:
                if term.lower() not in lowered and term not in extra_terms:
                    extra_terms.append(term)

    extra_terms = extra_terms[:max_extra_terms]
    return original_query if not extra_terms else original_query + " " + " ".join(extra_terms)


# ----------------------------
# Retrieval helpers
# ----------------------------
def bm25_search_custom(query_text, bm25_model, doc_ids, top_k=100):
    query_tokens = tokenize_for_bm25(query_text)
    scores = bm25_model.get_scores(query_tokens)
    top_indices = np.argsort(scores)[::-1][:top_k]

    results = []
    for rank, idx in enumerate(top_indices, start=1):
        results.append((doc_ids[idx], float(scores[idx]), rank))
    return results


def hybrid_search_custom_query(
    retrieval_query_text,
    top_k=RAG_TOP_K,
    retrieval_pool=RAG_RETRIEVAL_POOL,
    rrf_k=RAG_RRF_K,
    bm25_weight=RAG_BM25_WEIGHT,
    dense_weight=RAG_DENSE_WEIGHT
):
    custom_qid = "custom_query"

    dense_results = dense_search(
        query_text=retrieval_query_text,
        model=model,
        index=index,
        doc_ids=doc_ids,
        top_k=retrieval_pool
    )

    dense_df = pd.DataFrame([
        {"query_id": custom_qid, "doc_id": doc_id, "rank": rank, "score": score}
        for doc_id, score, rank in dense_results
    ])

    bm25_results = bm25_search_custom(
        query_text=retrieval_query_text,
        bm25_model=bm25,
        doc_ids=doc_ids,
        top_k=retrieval_pool
    )

    bm25_df = pd.DataFrame([
        {"query_id": custom_qid, "doc_id": doc_id, "rank": rank, "score": score}
        for doc_id, score, rank in bm25_results
    ])

    fused_df = rrf_process(
        bm25_df,
        dense_df,
        k=rrf_k,
        bm25_weight=bm25_weight,
        dense_weight=dense_weight
    )

    bm25_rank_lookup = bm25_df.set_index("doc_id")["rank"].to_dict()
    bm25_score_lookup = bm25_df.set_index("doc_id")["score"].to_dict()
    dense_rank_lookup = dense_df.set_index("doc_id")["rank"].to_dict()
    dense_score_lookup = dense_df.set_index("doc_id")["score"].to_dict()

    fused_df["bm25_rank"] = fused_df["doc_id"].map(bm25_rank_lookup)
    fused_df["bm25_score"] = fused_df["doc_id"].map(bm25_score_lookup)
    fused_df["dense_rank"] = fused_df["doc_id"].map(dense_rank_lookup)
    fused_df["dense_score"] = fused_df["doc_id"].map(dense_score_lookup)

    return fused_df.sort_values("rank").reset_index(drop=True)


# ----------------------------
# Metadata and context compression
# ----------------------------
def get_document_record(doc_id):
    search_df = globals().get("active_corpus_df", corpus_df)
    matches = search_df.loc[search_df["doc_id"].astype(str) == str(doc_id)]
    if matches.empty and "parent_doc_id" in search_df.columns:
        matches = search_df.loc[search_df["parent_doc_id"].astype(str) == str(doc_id)]
    if matches.empty:
        return {"doc_id": str(doc_id), "text": ""}
    return matches.iloc[0].to_dict()


def fallback_extract_structured_fields(doc_text):
    fields = [
        "Document_Type", "Title", "Course_Code", "Prefix", "Number", "Level",
        "Source_Page", "Linked_File_or_Page", "File_Name", "Content"
    ]
    text = rag_normalize_text(doc_text)
    extracted = {}
    for i, field in enumerate(fields):
        label = re.escape(field).replace(r"\_", r"[ _]+")
        if i < len(fields) - 1:
            next_labels = [re.escape(f).replace(r"\_", r"[ _]+") for f in fields[i + 1:]]
            pattern = rf"{label}\s*=\s*(.*?)(?=,\s*(?:{'|'.join(next_labels)})\s*=|$)"
        else:
            pattern = rf"{label}\s*=\s*(.*)$"
        m = re.search(pattern, text, flags=re.IGNORECASE)
        extracted[field] = m.group(1).strip(" ,") if m else ""
    return extracted


def safe_extract_fields(doc_text):
    try:
        extracted = extract_structured_fields(doc_text)
        return {k: ("" if str(v).lower() == "not found" else v) for k, v in extracted.items()}
    except Exception:
        return fallback_extract_structured_fields(doc_text)


def field_value(record, extracted, record_name, extracted_name):
    value = str(record.get(record_name, "")).strip()
    if value and value.lower() not in {"nan", "none", "not found"}:
        return value
    value = str(extracted.get(extracted_name, "")).strip()
    if value and value.lower() not in {"nan", "none", "not found"}:
        return value
    return ""


def parse_rag_document(doc_id):
    record = get_document_record(doc_id)
    text = str(record.get("text", ""))
    extracted = safe_extract_fields(text)

    content = (
        str(record.get("chunk_text", "")).strip()
        or field_value(record, extracted, "content", "Content")
        or extracted.get("Content", "")
        or text
    )

    return {
        "doc_id": str(doc_id),
        "parent_doc_id": str(record.get("parent_doc_id", doc_id)),
        "chunk_index": str(record.get("chunk_index", "")),
        "text": text,
        "content": rag_normalize_text(content),
        "title": field_value(record, extracted, "title", "Title"),
        "document_type": field_value(record, extracted, "document_type", "Document_Type"),
        "course_code": field_value(record, extracted, "course_code", "Course_Code"),
        "prefix": field_value(record, extracted, "prefix", "Prefix"),
        "number": field_value(record, extracted, "number", "Number"),
        "level": field_value(record, extracted, "level", "Level"),
        "file_name": field_value(record, extracted, "file_name", "File_Name"),
        "source": field_value(record, extracted, "linked_file_or_page", "Linked_File_or_Page") or field_value(record, extracted, "source_page", "Source_Page"),
    }


def split_into_candidate_sentences(text):
    text = rag_normalize_text(text)
    # Split on sentence boundaries and also around long PDF/list chunks.
    rough = re.split(r"(?<=[.!?])\s+|\s{2,}|\s+[•●]\s+", text)
    sentences = []
    for part in rough:
        part = part.strip(" -\t\n\r")
        if 25 <= len(part) <= 520:
            sentences.append(part)
        elif len(part) > 520:
            # Chunk long PDF text so relevant pieces can still be selected.
            for i in range(0, len(part), 360):
                chunk = part[i:i + 520].strip()
                if len(chunk) >= 25:
                    sentences.append(chunk)
    return sentences


def intent_keywords(intent):
    return {
        "course_recommendation": ["course", "prerequisite", "credits", "undergraduate", "senior", "fall", "3000", "4000", "cap", "cda", "cen", "cis", "cop", "cot", "eel", "eee"],
        "certificate_requirements": ["certificate", "requirements", "required", "credits", "course", "courses", "complete", "program", "worksheet", "application"],
        "degree_requirements": ["degree", "requirements", "credits", "credit", "bachelor", "undergraduate", "program", "curriculum", "total", "engineering"],
        "person_lookup": ["chair", "acting", "director", "coordinator", "advisor", "faculty", "professor"],
        "forms": ["form", "worksheet", "application", "audit", "plan", "study", "requirements"],
        "general": []
    }.get(intent, [])


def score_text_for_query(text, original_query, retrieval_query, intent):
    lowered = str(text).lower()
    q_terms = set(rag_terms(original_query)) | set(rag_terms(retrieval_query))
    score = 0.0

    for term in q_terms:
        if term in lowered:
            score += 2.0

    for term in intent_keywords(intent):
        if str(term).lower() in lowered:
            score += 1.5

    # Penalize obvious noise or carryover healthcare corpus material.
    noise_terms = ["patient", "diagnosis", "procedure", "medication", "clinical", "heart disease"]
    for term in noise_terms:
        if term in lowered:
            score -= 8.0

    # Penalize highly repetitive extracted text, which caused the "phd phd phd" output.
    words = rag_terms(lowered)
    if len(words) >= 30:
        most_common_count = max([words.count(w) for w in set(words)] or [0])
        if most_common_count / max(len(words), 1) > 0.18:
            score -= 6.0

    return score


def select_relevant_snippet(doc, original_query, retrieval_query, intent, max_chars=RAG_MAX_FACT_CHARS):
    candidate_text = doc.get("content", "") or doc.get("text", "")
    sentences = split_into_candidate_sentences(candidate_text)

    if not sentences:
        return rag_normalize_text(candidate_text)[:max_chars]

    scored = []
    for sent in sentences:
        scored.append((score_text_for_query(sent, original_query, retrieval_query, intent), sent))

    scored.sort(key=lambda x: x[0], reverse=True)
    selected = []
    total_chars = 0

    for score, sent in scored[:8]:
        if score <= 0 and selected:
            continue
        if sent in selected:
            continue
        if total_chars + len(sent) > max_chars and selected:
            continue
        selected.append(sent)
        total_chars += len(sent)
        if total_chars >= max_chars:
            break

    if not selected:
        selected = [sentences[0][:max_chars]]

    return rag_normalize_text(" ".join(selected))[:max_chars].rstrip()


def document_intent_boost(doc, original_query, retrieval_query, intent):
    combined = " ".join([
        doc.get("title", ""), doc.get("document_type", ""), doc.get("course_code", ""),
        doc.get("file_name", ""), doc.get("source", ""), doc.get("content", "")[:1200]
    ]).lower()

    boost = 0.0

    if intent == "course_recommendation":
        if "course_listing" in combined or "course" in combined:
            boost += 6
        if any(prefix.lower() in combined for prefix in ["cap", "cda", "cen", "cis", "cop", "cot", "eel", "eee"]):
            boost += 3
        if any(level in combined for level in ["undergraduate", "3000", "4000", "senior"]):
            boost += 3
        if any(term in combined for term in ["phd", "doctoral"]):
            boost -= 5

    elif intent == "certificate_requirements":
        if "certificate" in combined:
            boost += 8
        if any(term in combined for term in ["requirement", "required", "credits", "worksheet", "application"]):
            boost += 4
        if "big data" in original_query.lower() and "big data" in combined:
            boost += 8
        if any(term in combined for term in ["professional ms", "itm"]):
            boost -= 4

    elif intent == "degree_requirements":
        if any(term in combined for term in ["degree requirements", "program sheet", "worksheet", "curriculum"]):
            boost += 6
        if any(term in original_query.lower() for term in ["electrical", "ee"]):
            if any(term in combined for term in ["electrical engineering", "bsee", "eel", "eee"]):
                boost += 8
            if any(term in combined for term in ["computer science", "mscs", "phd"]):
                boost -= 4
        if any(term in combined for term in ["bachelor", "undergraduate", "total credits", "credits"]):
            boost += 5
        if any(term in combined for term in ["phd", "doctoral"]):
            boost -= 8

    elif intent == "person_lookup":
        if any(term in combined for term in ["chair", "acting chair", "faculty", "director"]):
            boost += 6
        if any(term in combined for term in ["syllabus", "homework", "assignment", "phd phd"]):
            boost -= 6

    elif intent == "forms":
        if any(term in combined for term in ["form", "worksheet", "application", "audit", "plan of study"]):
            boost += 6

    return boost


def rerank_fused_results(fused_df, original_query, retrieval_query, top_k=RAG_TOP_K):
    intent = classify_rag_intent(original_query)
    reranked_rows = []

    for _, row in fused_df.head(RAG_RETRIEVAL_POOL).iterrows():
        doc_id = str(row["doc_id"])
        doc = parse_rag_document(doc_id)
        base_score = float(row.get("rrf_score", 0.0)) * 100.0
        text_score = score_text_for_query(
            " ".join([doc.get("title", ""), doc.get("file_name", ""), doc.get("course_code", ""), doc.get("content", "")[:2500]]),
            original_query,
            retrieval_query,
            intent
        )
        boost = document_intent_boost(doc, original_query, retrieval_query, intent)
        final_score = base_score + text_score + boost

        new_row = row.to_dict()
        new_row["rag_rerank_score"] = final_score
        new_row["rag_intent"] = intent
        new_row["title"] = doc.get("title", "")
        new_row["course_code"] = doc.get("course_code", "")
        new_row["document_type"] = doc.get("document_type", "")
        new_row["file_name"] = doc.get("file_name", "")
        reranked_rows.append(new_row)

    reranked_df = pd.DataFrame(reranked_rows)
    if reranked_df.empty:
        return fused_df.head(top_k).copy()

    reranked_df = reranked_df.sort_values("rag_rerank_score", ascending=False).head(top_k).reset_index(drop=True)
    reranked_df["rank"] = range(1, len(reranked_df) + 1)
    return reranked_df


def build_fact_line(rank, doc, snippet):
    parts = []
    course_code = doc.get("course_code", "")
    title = doc.get("title", "")
    level = doc.get("level", "")
    doc_type = doc.get("document_type", "")

    if course_code:
        parts.append(f"course {course_code}")
    if title:
        parts.append(f"titled {title}")
    if level:
        parts.append(f"level {level}")
    if doc_type:
        parts.append(f"source type {doc_type}")

    descriptor = ", ".join(parts)
    if descriptor:
        return f"Fact {rank}: In a department source for {descriptor}, the relevant information says: {snippet}"
    return f"Fact {rank}: {snippet}"


def build_hidden_rag_context(reranked_df, original_query, retrieval_query, max_total_chars=RAG_MAX_TOTAL_CONTEXT_CHARS):
    intent = classify_rag_intent(original_query)
    fact_lines = []
    review_rows = []
    total = 0

    for _, row in reranked_df.iterrows():
        rank = int(row["rank"])
        doc_id = str(row["doc_id"])
        doc = parse_rag_document(doc_id)
        snippet = select_relevant_snippet(doc, original_query, retrieval_query, intent)

        if not snippet:
            continue

        fact_line = build_fact_line(rank, doc, snippet)
        if total + len(fact_line) > max_total_chars and fact_lines:
            break

        fact_lines.append(fact_line)
        total += len(fact_line)

        review_rows.append({
            "rank": rank,
            "doc_id": doc_id,
            "rag_rerank_score": row.get("rag_rerank_score", ""),
            "rrf_score": row.get("rrf_score", ""),
            "bm25_rank": row.get("bm25_rank", ""),
            "dense_rank": row.get("dense_rank", ""),
            "title": doc.get("title", ""),
            "document_type": doc.get("document_type", ""),
            "course_code": doc.get("course_code", ""),
            "file_name": doc.get("file_name", ""),
            "snippet": snippet
        })

    return "\n".join(fact_lines), pd.DataFrame(review_rows)


# ----------------------------
# Prompting and answer quality guard
# ----------------------------
def build_contextualized_prompt(original_user_query, hidden_context):
    return f"""
Answer the student question using only the department facts below.
Use the facts as background context. Do not mention document numbers, document IDs, file names, retrieval, BM25, FAISS, or RRF.
Give a direct advising-style answer. If the facts do not contain the answer, say: "The retrieved department documents do not provide enough information to answer that."

Student question: {original_user_query}

Department facts:
{hidden_context}

Answer:
""".strip()


def clean_generated_answer(answer):
    answer = rag_normalize_text(answer)
    # Remove common prompt echoes.
    answer = re.sub(r"^(Answer:|Final answer:|Final answer for the user:)\s*", "", answer, flags=re.IGNORECASE).strip()
    return answer


def repeated_word_problem(answer):
    words = re.findall(r"[A-Za-z]+", str(answer).lower())
    if len(words) < 20:
        return False
    counts = {w: words.count(w) for w in set(words)}
    return max(counts.values()) / len(words) > 0.22


def answer_looks_bad(answer):
    if not answer or len(str(answer).strip()) < 12:
        return True
    lowered = str(answer).lower()
    bad_markers = [
        "doc id", "document 1", "document 2", "document 3", "document 4", "document 5", "document 6",
        "rrf", "bm25", "faiss", "pdf_", "course_", "retrieved department context", "file_name", "source_page"
    ]
    if any(marker in lowered for marker in bad_markers):
        return True
    if repeated_word_problem(answer):
        return True
    # A filename-only answer is usually not useful.
    if re.fullmatch(r"[A-Za-z0-9_\- .()]+\.pdf", str(answer).strip()):
        return True
    return False


def extract_course_suggestions_from_review(top_docs_df, max_items=6):
    suggestions = []
    seen = set()

    for _, row in top_docs_df.iterrows():
        code = str(row.get("course_code", "")).strip()
        title = str(row.get("title", "")).strip()
        snippet = str(row.get("snippet", "")).strip()

        key = code or title
        if not key or key.lower() in seen:
            continue
        seen.add(key.lower())

        if code and title:
            suggestions.append(f"{code} — {title}")
        elif title:
            suggestions.append(title)
        elif code:
            suggestions.append(code)

        if len(suggestions) >= max_items:
            break

    return suggestions


def extractive_fallback_answer(original_user_query, top_docs_df):
    """
    Last-resort answer if the small LLM copies metadata or produces nonsense.
    This is intentionally concise and uses the same retrieved context.
    """
    intent = classify_rag_intent(original_user_query)

    if top_docs_df is None or len(top_docs_df) == 0:
        return "The retrieved department documents do not provide enough information to answer that."

    snippets = [str(s).strip() for s in top_docs_df.get("snippet", []) if str(s).strip()]
    if not snippets:
        return "The retrieved department documents do not provide enough information to answer that."

    if intent == "course_recommendation":
        suggestions = extract_course_suggestions_from_review(top_docs_df)
        if suggestions:
            return (
                "Based on the retrieved department course information, good options to review for a senior student include "
                + "; ".join(suggestions[:6])
                + ". The student should still check the current Fall schedule, prerequisites, and advisor guidance before registering."
            )

    if intent == "person_lookup":
        joined = " ".join(snippets[:4])
        # Try to find a person-like phrase near chair/director terms.
        m = re.search(r"(?:acting\s+chair|chair|director)\s*(?:is|:|-)?\s*([A-Z][A-Za-z.'-]+(?:\s+[A-Z][A-Za-z.'-]+){0,3})", joined)
        if m:
            return f"The retrieved department context indicates that {m.group(1)} is associated with that role."
        return "The retrieved department documents do not provide enough information to identify the acting chair."

    # General fallback: present the strongest retrieved facts without document IDs or filenames.
    strongest = []
    for s in snippets[:3]:
        s = re.sub(r"\b(Document_Type|Title|Course_Code|File_Name|Source_Page|Linked_File_or_Page)\s*=\s*", "", s)
        strongest.append(s)

    return "Based on the retrieved department context: " + " ".join(strongest)


def get_model_device(model_obj):
    try:
        return next(model_obj.parameters()).device
    except StopIteration:
        return torch.device("cuda" if torch.cuda.is_available() else "cpu")


def build_chat_or_plain_prompt(prompt):
    """Use chat formatting for instruct causal LMs when available; otherwise use plain text."""
    if RAG_MODEL_KIND != "causal":
        return prompt

    system_message = (
        "You are a helpful academic advising assistant. Use only the supplied department context. "
        "Do not mention retrieval, chunks, filenames, document IDs, BM25, FAISS, or RRF. "
        "If the context does not answer the question, say that the retrieved department documents do not provide enough information."
    )
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt},
    ]

    if hasattr(rag_tokenizer, "apply_chat_template"):
        try:
            return rag_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
        except Exception:
            return system_message + "\n\n" + prompt

    return system_message + "\n\n" + prompt


def decode_generated_tokens(outputs, inputs):
    if RAG_MODEL_KIND == "causal":
        input_len = inputs["input_ids"].shape[-1]
        generated = outputs[0][input_len:]
        return rag_tokenizer.decode(generated, skip_special_tokens=True)
    return rag_tokenizer.decode(outputs[0], skip_special_tokens=True)


def run_rag_model_once(prompt, max_input_tokens, max_new_tokens):
    formatted_prompt = build_chat_or_plain_prompt(prompt)
    inputs = rag_tokenizer(
        formatted_prompt,
        return_tensors="pt",
        truncation=True,
        max_length=max_input_tokens
    )

    device = get_model_device(rag_model)
    inputs = {key: value.to(device) for key, value in inputs.items()}

    generation_kwargs = {
        "max_new_tokens": max_new_tokens,
        "do_sample": False,
        "no_repeat_ngram_size": 3,
        "repetition_penalty": 1.15,
        "pad_token_id": rag_tokenizer.pad_token_id,
    }

    if RAG_MODEL_KIND == "seq2seq":
        generation_kwargs.update({
            "num_beams": 4,
            "early_stopping": True,
            "repetition_penalty": 1.25,
        })
    else:
        # Chat/instruct causal models usually do better with greedy decoding here.
        if rag_tokenizer.eos_token_id is not None:
            generation_kwargs["eos_token_id"] = rag_tokenizer.eos_token_id

    with torch.no_grad():
        outputs = rag_model.generate(**inputs, **generation_kwargs)

    return clean_generated_answer(decode_generated_tokens(outputs, inputs))


def generate_rag_answer(original_user_query, hidden_context, top_docs_df=None, max_input_tokens=RAG_MAX_INPUT_TOKENS, max_new_tokens=RAG_MAX_NEW_TOKENS):
    prompt = build_contextualized_prompt(original_user_query, hidden_context)

    answer = run_rag_model_once(prompt, max_input_tokens=max_input_tokens, max_new_tokens=max_new_tokens)

    if answer_looks_bad(answer):
        # Try once more with a shorter, cleaner context.
        shorter_context = "\n".join(str(hidden_context).splitlines()[:5])
        retry_prompt = build_contextualized_prompt(original_user_query, shorter_context)
        retry_answer = run_rag_model_once(retry_prompt, max_input_tokens=1024, max_new_tokens=140)
        if not answer_looks_bad(retry_answer):
            return retry_answer

        return extractive_fallback_answer(original_user_query, top_docs_df)

    return answer


# ----------------------------
# Main RAG function and loop
# ----------------------------
LAST_RAG_RESULT = None


def ask_department_rag(original_user_query, top_k=RAG_TOP_K, retrieval_pool=RAG_RETRIEVAL_POOL, return_details=False, debug=RAG_DEBUG):
    global LAST_RAG_RESULT

    original_user_query = str(original_user_query).strip()
    if not original_user_query:
        print("Please enter a non-empty query.")
        return None

    retrieval_query = improve_query_for_hybrid_search(original_user_query)

    fused_df = hybrid_search_custom_query(
        retrieval_query_text=retrieval_query,
        top_k=top_k,
        retrieval_pool=retrieval_pool
    )

    reranked_df = rerank_fused_results(
        fused_df=fused_df,
        original_query=original_user_query,
        retrieval_query=retrieval_query,
        top_k=top_k
    )

    hidden_context, top_docs_df = build_hidden_rag_context(
        reranked_df=reranked_df,
        original_query=original_user_query,
        retrieval_query=retrieval_query
    )

    if not hidden_context.strip():
        answer = "The retrieved department documents do not provide enough information to answer that."
    else:
        answer = generate_rag_answer(
            original_user_query=original_user_query,
            hidden_context=hidden_context,
            top_docs_df=top_docs_df
        )

    LAST_RAG_RESULT = {
        "original_query": original_user_query,
        "retrieval_query": retrieval_query,
        "answer": answer,
        "top_docs": top_docs_df,
        "hidden_context": hidden_context,
        "fused_results": fused_df,
        "reranked_results": reranked_df,
        "intent": classify_rag_intent(original_user_query)
    }

    print("\n" + "=" * 90)
    print("Contextualized RAG Answer")
    print("=" * 90)
    print(answer)

    if debug:
        print("\nDebug mode is on. The retrieved chunks are shown below for inspection only.")
        print("Original query:", original_user_query)
        print("Retrieval query:", retrieval_query)
        display(top_docs_df)

    if return_details:
        return LAST_RAG_RESULT

    return answer


def rag_query_loop():
    print("Interactive CS/EE Department RAG Assistant")
    print("Enter a custom question. Hybrid search silently attaches the best retrieved chunk facts as context.")
    print("Only the final contextualized answer is displayed.")
    print("Type 'exit', 'quit', or 'q' to stop.")

    while True:
        user_query = input("\nEnter your CS/EE department query: ").strip()

        if user_query.lower() in {"exit", "quit", "q"}:
            print("Stopping interactive RAG loop.")
            break

        if not user_query:
            print("Please enter a question or type 'exit' to stop.")
            continue

        _ = ask_department_rag(user_query, return_details=False, debug=False)


# Start the interactive loop.
rag_query_loop()
# Out:
# Loading Hugging Face RAG answer model: Qwen/Qwen2.5-1.5B-Instruct
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# RAG answer model loaded as: causal
# Interactive CS/EE Department RAG Assistant
# Enter a custom question. Hybrid search silently attaches the best retrieved chunk facts as context.
# Only the final contextualized answer is displayed.
# Type 'exit', 'quit', or 'q' to stop.
# Enter your CS/EE department query:  Recommend senior level computer science courses.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ==========================================================================================
# Contextualized RAG Answer
# ==========================================================================================
# For senior-level computer science electives in your department, consider taking: 1. **COT 7901 Advanced Topics in Computer Science** This is an advanced elective focusing on specialized topics within computer science. You can choose this based on areas like machine learning, cybersecurity, artificial intelligence, etc., depending on your interests and career goals. 2. **CAP 7700 Research Methods in Computing** This course provides you with research methodologies essential for conducting independent studies in computing. Ideal for those interested in pursuing further education or careers requiring strong analytical skills. These courses will help deepen your understanding of specific aspects of computer science and prepare you for more advanced study or industry roles.
# Enter your CS/EE department query:  Recommend data science oriented courses that are specifically for undergraduate students.
# ==========================================================================================
# Contextualized RAG Answer
# ==========================================================================================
# For an undergraduate student interested in pursuing a data science-oriented curriculum, I recommend taking the following courses: 1. **Introduction to Data Sciences** (CAP 5678): This foundational course will introduce you to key concepts and tools used in modern data analysis and machine learning. 2. **Software Engineering** (COP 6001): Understanding software development principles is crucial for any aspiring data scientist who wants to build robust applications from scratch. 3. **Data Mining and Machine Learning** (CGS 6200): These advanced topics cover essential techniques for extracting insights from large datasets, which are fundamental skills in today's data-driven world. These courses should provide a strong base in both theoretical knowledge and practical application, preparing you well for further studies in data science at the graduate level.
# Enter your CS/EE department query:  Those are graduate courses.
# ==========================================================================================
# Contextualized RAG Answer
# ==========================================================================================
# Based on the provided department facts, those appear to be graduate-level computer science courses in an engineering program. The courses include: - **Systems & Applications**: Courses like CAP, CIP, CND, etc. - **Software & Programming**: Courses such as COP, CEP, CEI, etc., which can also have prefixes like CEN. - Specific sections related to Computer Architecture and Design. - A Thesis Option where students complete up to 6 credits of coursework. These details suggest these courses cover advanced topics in computing theory, programming languages, software development methodologies, systems architecture, and possibly research-oriented areas depending on the specific programs offered by the department.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 879
#     875         _ = ask_department_rag(user_query, return_details=False, debug=False)
#     878 # Start the interactive loop.
# --> 879 rag_query_loop()
#
# Cell In[28], line 865, in rag_query_loop()
#     862 print("Type 'exit', 'quit', or 'q' to stop.")
#     864 while True:
# --> 865     user_query = input("\nEnter your CS/EE department query: ").strip()
#     867     if user_query.lower() in {"exit", "quit", "q"}:
#     868         print("Stopping interactive RAG loop.")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# Enter your CS/EE department query:  q
